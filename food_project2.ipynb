# %% [markdown]
# <a href="https://colab.research.google.com/github/wesha-904/Local-Food-Wastage-Management-System/blob/main/food_project2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name** - Local Food Wastage Management System

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# [Anwesha's Github](https://github.com/wesha-904/Local-Food-Wastage-Management-System)

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Food wastage is a significant issue, with many households and restaurants discarding surplus food while numerous people struggle with food insecurity. This project aims to develop a Local Food Wastage Management System, where:
# - Restaurants and individuals can list surplus food.
# - NGOs or individuals in need can claim the food.
# - SQL stores available food details and locations.
# - A Streamlit app enables interaction, filtering, CRUD operation and visualization.

# %% [markdown]
# # Business Use Cases

# %% [markdown]
# - Connecting surplus food providers to those in need through a structured platform.
# - Reducing food waste by redistributing excess food efficiently.
# -Enhancing accessibility via geolocation features to locate food easily.
# -Data analysis on food wastage trends for better decision-making.

# %% [markdown]
# # 1. Data Preparation

# %%
import pandas as pd
import sqlite3

# %%
# Load data from CSV files
receivers = pd.read_csv("https://raw.githubusercontent.com/wesha-904/Local-Food-Wastage-Management-System/refs/heads/main/receivers_data.csv")
providers = pd.read_csv("https://raw.githubusercontent.com/wesha-904/Local-Food-Wastage-Management-System/refs/heads/main/providers_data.csv")
food_listings = pd.read_csv("https://raw.githubusercontent.com/wesha-904/Local-Food-Wastage-Management-System/refs/heads/main/food_listings_data.csv")
claims = pd.read_csv("https://raw.githubusercontent.com/wesha-904/Local-Food-Wastage-Management-System/refs/heads/main/claims_data.csv")

# %% [markdown]
# #### Data Preprocessing

# %%
providers
# Out:
#      Provider_ID                         Name              Type  \
# 0              1             Gonzales-Cochran       Supermarket
# 1              2  Nielsen, Johnson and Fuller     Grocery Store
# 2              3                 Miller-Black       Supermarket
# 3              4   Clark, Prince and Williams     Grocery Store
# 4              5               Coleman-Farley     Grocery Store
# ..           ...                          ...               ...
# 995          996    Vasquez, Ruiz and Flowers        Restaurant
# 996          997               Garza-Williams  Catering Service
# 997          998                  Novak Group     Grocery Store
# 998          999                    Moody Ltd     Grocery Store
# 999         1000               Jenkins-Brooks        Restaurant
#
#                                                Address            City  \
# 0    74347 Christopher Extensions\nAndreamouth, OK ...     New Jessica
# 1             91228 Hanson Stream\nWelchtown, OR 27136     East Sheena
# 2    561 Martinez Point Suite 507\nGuzmanchester, W...  Lake Jesusview
# 3       467 Bell Trail Suite 409\nPort Jesus, IA 61188     Mendezmouth
# 4    078 Matthew Creek Apt. 319\nSaraborough, MA 53978   Valentineside
# ..                                                 ...             ...
# 995    84308 Justin Stravenue\nNew Amberside, NE 53447     Williamview
# 996  08864 Figueroa Radial Suite 948\nJennaberg, AZ...   East Rossside
# 997            934 Zachary Run\nMelissamouth, WY 02729      Joshuastad
# 998    17580 Ernest Hills\nLake Michaelmouth, OR 56416   Stevenchester
# 999  53390 Evans Rapids Suite 982\nLake Meghan, MO ...     Brendantown
#
#                   Contact
# 0         +1-600-220-0480
# 1    +1-925-283-8901x6297
# 2        001-517-295-2206
# 3        556.944.8935x401
# 4            193.714.6577
# ..                    ...
# 995  +1-319-378-7627x0682
# 996  001-924-441-3963x746
# 997    (903)642-1969x3300
# 998     637.300.3664x4880
# 999    266-324-3458x95775
#
# [1000 rows x 6 columns]

# %%
print("\nNumber of null values per column:")
print(providers.isnull().sum())

# On inspection there are no NULL values
# Out:
# Number of null values per column:
# Provider_ID    0
# Name           0
# Type           0
# Address        0
# City           0
# Contact        0
# dtype: int64

# %%
providers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Provider_ID  1000 non-null   int64
#  1   Name         1000 non-null   object
#  2   Type         1000 non-null   object
#  3   Address      1000 non-null   object
#  4   City         1000 non-null   object
#  5   Contact      1000 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB

# %%
# Identify numerical and categorical features
numerical_features_providers = providers.select_dtypes(include=['int64', 'float64']).columns
categorical_features_providers = providers.select_dtypes(include=['object']).columns

# Results to see the identified columns
print("Numerical Features:", numerical_features_providers)
print("Categorical Features:", categorical_features_providers)
# Out:
# Numerical Features: Index(['Provider_ID'], dtype='object')
# Categorical Features: Index(['Name', 'Type', 'Address', 'City', 'Contact'], dtype='object')

# %%
# Count duplicate rows
duplicate_count = providers.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 0

# %%
# Standardized contact column
import re

def standardize_phone(phone):
    # Remove all non-digit characters except 'x' for extension
    digits = re.sub(r'\D', '', phone)

    # Keep only first 10 digits for the main number
    main_number = digits[-10:]

    # Format: +1-XXX-XXX-XXXX
    formatted = f"+1-{main_number[0:3]}-{main_number[3:6]}-{main_number[6:]}"

    return formatted

# Apply to 'contact' column
providers['Contact'] = providers['Contact'].astype(str).apply(standardize_phone)

# Check result
print(providers['Contact'].head())
# Out:
# 0    +1-600-220-0480
# 1    +1-838-901-6297
# 2    +1-517-295-2206
# 3    +1-944-893-5401
# 4    +1-193-714-6577
# Name: Contact, dtype: object

# %%
providers
# Out:
#      Provider_ID                         Name              Type  \
# 0              1             Gonzales-Cochran       Supermarket
# 1              2  Nielsen, Johnson and Fuller     Grocery Store
# 2              3                 Miller-Black       Supermarket
# 3              4   Clark, Prince and Williams     Grocery Store
# 4              5               Coleman-Farley     Grocery Store
# ..           ...                          ...               ...
# 995          996    Vasquez, Ruiz and Flowers        Restaurant
# 996          997               Garza-Williams  Catering Service
# 997          998                  Novak Group     Grocery Store
# 998          999                    Moody Ltd     Grocery Store
# 999         1000               Jenkins-Brooks        Restaurant
#
#                                                Address            City  \
# 0    74347 Christopher Extensions\nAndreamouth, OK ...     New Jessica
# 1             91228 Hanson Stream\nWelchtown, OR 27136     East Sheena
# 2    561 Martinez Point Suite 507\nGuzmanchester, W...  Lake Jesusview
# 3       467 Bell Trail Suite 409\nPort Jesus, IA 61188     Mendezmouth
# 4    078 Matthew Creek Apt. 319\nSaraborough, MA 53978   Valentineside
# ..                                                 ...             ...
# 995    84308 Justin Stravenue\nNew Amberside, NE 53447     Williamview
# 996  08864 Figueroa Radial Suite 948\nJennaberg, AZ...   East Rossside
# 997            934 Zachary Run\nMelissamouth, WY 02729      Joshuastad
# 998    17580 Ernest Hills\nLake Michaelmouth, OR 56416   Stevenchester
# 999  53390 Evans Rapids Suite 982\nLake Meghan, MO ...     Brendantown
#
#              Contact
# 0    +1-600-220-0480
# 1    +1-838-901-6297
# 2    +1-517-295-2206
# 3    +1-944-893-5401
# 4    +1-193-714-6577
# ..               ...
# 995  +1-787-627-0682
# 996  +1-441-396-3746
# 997  +1-421-969-3300
# 998  +1-003-664-4880
# 999  +1-434-589-5775
#
# [1000 rows x 6 columns]

# %%
# Cleaning and standardizing the 'Name' column by removing extra spaces, unwanted characters, and converting all text to lowercase for consistency
import re
import pandas as pd

def clean_name_lower(name):
    if pd.isna(name):
        return name
    # Remove leading/trailing spaces
    name = name.strip()
    # Collapse multiple spaces
    name = re.sub(r'\s+', ' ', name)
    # Remove digits and special chars except space, hyphen, apostrophe
    name = re.sub(r"[^a-zA-Z\s\-']", "", name)
    # Convert to lowercase
    name = name.lower()
    return name

# Apply to Name column
providers['Name'] = providers['Name'].apply(clean_name_lower)

# Check results
print(providers['Name'].head(10))
# Out:
# 0              gonzales-cochran
# 1    nielsen johnson and fuller
# 2                  miller-black
# 3     clark prince and williams
# 4                coleman-farley
# 5                lawson-walters
# 6                     ortiz-lee
# 7                  curtis-lewis
# 8                    nguyen inc
# 9      hall nguyen and martinez
# Name: Name, dtype: object

# %%
print(providers['Type'].unique())
# Out:
# ['Supermarket' 'Grocery Store' 'Restaurant' 'Catering Service']

# %%
# Cleaning and standardizing the 'City' column
import re

def clean_city(name):
    if pd.isna(name):
        return name
    # Remove leading/trailing spaces
    name = name.strip()
    # Collapse multiple spaces
    name = re.sub(r'\s+', ' ', name)
    # Remove unwanted characters except letters, spaces, and hyphens
    name = re.sub(r"[^a-zA-Z\s\-]", "", name)
    # Convert to lowercase for consistency
    name = name.lower()
    return name

# Apply cleaning to the 'City' column
providers['City'] = providers['City'].apply(clean_city)

# Check unique values after cleaning
print(providers['City'].unique())
# Out:
# ['new jessica' 'east sheena' 'lake jesusview' 'mendezmouth'
#  'valentineside' 'shannonside' 'lake christopherburgh' 'washingtonville'
#  'tinamouth' 'west cherylfort' 'south robert' 'east williamburgh'
#  'nicolefort' 'garciamouth' 'west theresaberg' 'west vanessafort'
#  'west dawn' 'cassandraville' 'south melanieshire' 'east samantha'
#  'port corystad' 'port lisamouth' 'bradleyborough' 'hestermouth'
#  'anitashire' 'west adammouth' 'new natasha' 'jessestad' 'patrickmouth'
#  'west pamelaborough' 'south kellyberg' 'jameschester' 'janetborough'
#  'north garybury' 'andersonmouth' 'cindyshire' 'new amanda' 'perkinsbury'
#  'brittanyville' 'jennifertown' 'bentleyburgh' 'east nicholasbury'
#  'south karen' 'jamesville' 'east deniseborough' 'south lisaberg'
#  'east andrewland' 'timothyview' 'lake traceyburgh' 'west danielborough'
#  'rebeccabury' 'port dianaberg' 'lake allen' 'lake rachael' 'danachester'
#  'michaelview' 'port robin' 'north kevinhaven' 'marissaville' 'wilsonport'
#  'lake joelshire' 'marymouth' 'mcclainfurt' 'south michaelhaven'
#  'lake raymondton' 'lake michaelfurt' 'kentland' 'north elizabeth'
#  'cummingstown' 'lake kyle' 'ruizmouth' 'jasonstad' 'west benjamin'
#  'belindaville' 'rodneystad' 'port amandamouth' 'new rhonda' 'north susan'
#  'west danieltown' 'lake dennischester' 'north michelle'
#  'west lauraborough' 'west julianburgh' 'marthaside' 'christopherstad'
#  'new michelle' 'west adam' 'salastown' 'new richard' 'lake kristentown'
#  'north ronaldburgh' 'east melissa' 'new daniel' 'brennanstad'
#  'christinaland' 'deborahland' 'reyesshire' 'gardnerfort' 'south louis'
#  'mooreview' 'east angelafort' 'west samantha' 'port michaelshire'
#  'lake theresa' 'davidchester' 'lopezmouth' 'east austin' 'north carmen'
#  'south kellyville' 'south davidside' 'east courtneymouth'
#  'east elizabethberg' 'lake katherinechester' 'floresville' 'moseshaven'
#  'amberton' 'lake joseph' 'port kathleen' 'new lisa' 'south kelly'
#  'tyronebury' 'east meganfort' 'lake shelby' 'lake april'
#  'new rodneyville' 'jasonland' 'port mariefort' 'port emily' 'scottton'
#  'huntermouth' 'south michaelberg' 'west melissa' 'east candace'
#  'lamberttown' 'east alexisberg' 'north sherrimouth' 'port connie'
#  'watsonstad' 'port manuel' 'mitchellmouth' 'samuelville' 'bellport'
#  'kayleefort' 'jonathanhaven' 'west trevorview' 'annahaven' 'north amber'
#  'north jamesberg' 'anthonyshire' 'south jacobport' 'hawkinsmouth'
#  'new john' 'charlesview' 'west carolyn' 'bairdfort' 'north crystal'
#  'north brooke' 'port loganberg' 'perezport' 'penabury' 'annetteburgh'
#  'sylviabury' 'copelandchester' 'lake donaldmouth' 'davidport' 'wardton'
#  'lindseyland' 'north brentbury' 'williammouth' 'garciaside'
#  'myerschester' 'north carolfurt' 'katherinefurt' 'east john'
#  'south nicholasville' 'scottchester' 'south jeffrey' 'taylormouth'
#  'port jeffrey' 'south anne' 'velazquezview' 'shirleyland' 'evansmouth'
#  'port robert' 'courtneychester' 'brianside' 'barkerborough'
#  'lake jessicamouth' 'leslieville' 'north lisaland' 'lake josephton'
#  'justinhaven' 'bartonborough' 'new david' 'port karen' 'christinamouth'
#  'bradleyport' 'sandrastad' 'vazquezshire' 'port christina'
#  'lake lauraton' 'carlbury' 'port emilyburgh' 'north ronaldmouth'
#  'east garyton' 'south cassandra' 'paulmouth' 'lake james' 'port markview'
#  'andersonville' 'jamesview' 'new curtis' 'tylerburgh' 'mooremouth'
#  'lake chloeshire' 'east stephanie' 'west stephaniemouth' 'walterborough'
#  'stephanieberg' 'longland' 'east lindsayville' 'west kenneth'
#  'south thomas' 'derekport' 'andrewsmouth' 'gonzalesport' 'north melanie'
#  'north tom' 'muellermouth' 'south morganfurt' 'new joel' 'gutierrezshire'
#  'jeffreyburgh' 'frederickside' 'north julieburgh' 'south bradleyburgh'
#  'andreaborough' 'devinmouth' 'michaelport' 'west catherine' 'toddberg'
#  'lake heather' 'east stephanieview' 'port aaron' 'south michellechester'
#  'johnsonside' 'south jasmineville' 'east terrancemouth' 'phillipsfort'
#  'sharonton' 'reidland' 'crystalborough' 'north nicoleport'
#  'lake coryhaven' 'lake anthonyport' 'north briannabury' 'new samuel'
#  'south richardhaven' 'new carol' 'chambersfort' 'new douglas'
#  'port ronaldshire' 'port kevinburgh' 'nolanmouth' 'east caseyfort'
#  'cunninghambury' 'new jeremyberg' 'lake christinaborough'
#  'new dawnborough' 'brittanyport' 'port eric' 'west aliciabury'
#  'beasleyhaven' 'garciaport' 'coopermouth' 'lake nicolebury'
#  'port gregton' 'andrewstad' 'west corey' 'williamschester' 'jefferyside'
#  'maynardstad' 'toddstad' 'west margaretfort' 'mooneybury' 'joneshaven'
#  'south kendra' 'meghanfurt' 'port linda' 'markberg' 'new steven'
#  'robertton' 'lake michaelview' 'east laurashire' 'south tammy'
#  'tammystad' 'port marcland' 'fullerborough' 'north keith' 'heathborough'
#  'brittanyside' 'ambertown' 'saraburgh' 'west amanda' 'north ianbury'
#  'boylechester' 'rodriguezfurt' 'lake andrewmouth' 'williamsfort'
#  'south brandiberg' 'martinezfort' 'lake amymouth' 'lake jeffreytown'
#  'north edwinchester' 'mckinneymouth' 'jasmineberg' 'east elizabeth'
#  'west tammy' 'lake alicia' 'villaborough' 'port rubenville'
#  'port lauraville' 'jamesport' 'south jeffreyburgh' 'west whitneymouth'
#  'port heidiland' 'south jillshire' 'north gary' 'east sandra' 'new ricky'
#  'adambury' 'murrayborough' 'lake ryanbury' 'matthewbury'
#  'south christopherborough' 'north nicholas' 'north tracy' 'thomasville'
#  'louismouth' 'west ashleytown' 'valenzuelaville' 'port dustin'
#  'south stefanietown' 'north aaron' 'south alicia' 'port patrick'
#  'west michael' 'donnaborough' 'south crystalberg' 'north ashley'
#  'butlerview' 'east lauren' 'anthonychester' 'east brittanyland'
#  'lake ethanview' 'west robert' 'devinton' 'deckermouth'
#  'north lindseychester' 'brownton' 'williamsland' 'solisburgh' 'lewisberg'
#  'aprilberg' 'steeleport' 'new ryanbury' 'lake sarah' 'west omar'
#  'south johnshire' 'millerstad' 'lake christophermouth' 'martinville'
#  'ritterburgh' 'barryside' 'jamesfurt' 'new tammyland' 'wheelermouth'
#  'west juliabury' 'manuelhaven' 'davidborough' 'taylorfort'
#  'south jerryside' 'lake jefferyborough' 'heatherview' 'port glendastad'
#  'west erinport' 'heatherside' 'arnoldmouth' 'jasminechester'
#  'north alison' 'collinston' 'randallville' 'west christopher'
#  'jeremiahfort' 'brownchester' 'kevinfort' 'davisshire'
#  'north charlesside' 'riceshire' 'east roberthaven' 'thomasfurt'
#  'east darrell' 'robertland' 'north mike' 'new matthew'
#  'christopherchester' 'east anthony' 'east ashleyshire' 'deborahfurt'
#  'port peter' 'anthonyton' 'kylehaven' 'smithfort' 'south justinborough'
#  'richton' 'lake alexis' 'taylorchester' 'east amymouth' 'alexanderstad'
#  'lake benjamin' 'west thomas' 'west jeffreyland' 'carolchester'
#  'anthonyfort' 'nicoletown' 'port leahfurt' 'north christina'
#  'lake michaelchester' 'contrerasberg' 'bradleyview' 'elliottberg'
#  'chadview' 'south sarahville' 'new crystal' 'new billy' 'danaville'
#  'port richardshire' 'lake lindsay' 'north paulstad' 'robertsonfort'
#  'grahamside' 'morganside' 'new erica' 'east timothy' 'south lisabury'
#  'madisonfort' 'north katelyn' 'south linda' 'new robertland'
#  'castilloport' 'lake justin' 'new hannah' 'port lauriechester'
#  'east edwinburgh' 'port jacob' 'johnton' 'lake brendaland'
#  'east johnburgh' 'port pamelaport' 'port daniellechester' 'charlesmouth'
#  'rebeccaburgh' 'ashleyton' 'south nicole' 'bentonfurt' 'port jerome'
#  'east jacobchester' 'lake regina' 'hamiltontown' 'east kevin'
#  'owenschester' 'suzanneport' 'millerview' 'north douglasfurt'
#  'east andrea' 'bridgetside' 'west peterborough' 'stewartfurt'
#  'port erinton' 'christianfurt' 'samanthabury' 'north stephanieville'
#  'new robert' 'new denise' 'brownshire' 'west daniel' 'chelseyfort'
#  'east craig' 'jonathanstad' 'levytown' 'jordanhaven' 'liberg' 'joseville'
#  'gaineschester' 'chelseaside' 'tylerton' 'lake diane' 'walkerfurt'
#  'cordovaborough' 'adamsview' 'port davidshire' 'port timothystad'
#  'west larry' 'maxwellburgh' 'snyderton' 'new aaronberg' 'wadeville'
#  'anneville' 'keithburgh' 'port andre' 'deanport' 'torresfort'
#  'lake lorrainefort' 'west amandafurt' 'lake carlos' 'south tylerstad'
#  'bonillahaven' 'markport' 'dannybury' 'johnstonhaven' 'north kylestad'
#  'darrylchester' 'rogersmouth' 'south kayla' 'valdezborough'
#  'south donald' 'callahanside' 'jasonmouth' 'watsonton' 'henrychester'
#  'west karen' 'new johnfurt' 'east jennifer' 'richardton' 'kellyberg'
#  'new wendymouth' 'batesstad' 'lisamouth' 'east deborah' 'timothychester'
#  'east sandratown' 'pearsonchester' 'north marthaton' 'brandyberg'
#  'south brenda' 'brittanyland' 'east aaron' 'north sharonberg'
#  'new baileyfort' 'east donnafort' 'kennedychester' 'lake lauren'
#  'east angela' 'jenniferview' 'steventown' 'new rachel' 'ericfort'
#  'south russelltown' 'lake vanessa' 'baldwinshire' 'lake cathy'
#  'new thomasmouth' 'new larry' 'johnport' 'east emilyburgh' 'lake donna'
#  'port carrie' 'meyersland' 'richardfort' 'west phillip' 'west dannyland'
#  'marcstad' 'moralesside' 'port donnaton' 'jonesport' 'lake george'
#  'vazquezland' 'morganhaven' 'richchester' 'new leslieport'
#  'north brendaborough' 'tammyside' 'lake monique' 'port matthew'
#  'zimmermanville' 'karentown' 'south sarastad' 'carlborough' 'meganshire'
#  'port troychester' 'north destiny' 'west stephen' 'west tylerberg'
#  'north nathan' 'shawnborough' 'collinsmouth' 'allenton'
#  'port kendraborough' 'kimberlychester' 'petersonburgh' 'robertshire'
#  'new josemouth' 'clarkberg' 'murphyberg' 'north katelynland' 'new jason'
#  'sarahland' 'east annshire' 'latoyaberg' 'new kevintown' 'east lisa'
#  'heathermouth' 'nathanielbury' 'port jillian' 'east joseph'
#  'west matthew' 'davidville' 'fisherstad' 'colemanton' 'south jeffery'
#  'west omarside' 'east williamshire' 'jeffreyport' 'richardsonhaven'
#  'west tinamouth' 'lesterstad' 'north ebony' 'sandersshire'
#  'durhamchester' 'scotthaven' 'west kara' 'lake xavierburgh' 'garzaville'
#  'north lisamouth' 'port john' 'cameronside' 'derekland' 'jimmyberg'
#  'south tiffanyfort' 'davidland' 'north ravenfurt' 'east lori'
#  'michellechester' 'lake donaldchester' 'port lesliebury'
#  'new joshuamouth' 'jeffreyshire' 'west billborough' 'lake lisa'
#  'estradafort' 'salinasville' 'new heidi' 'lake jaclyn' 'north catherine'
#  'north mariahchester' 'new connorfort' 'anthonyhaven' 'peterhaven'
#  'lake jasmin' 'williamsmouth' 'lake travis' 'lake gary' 'hillburgh'
#  'darrellfurt' 'leonardborough' 'christinetown' 'jimmymouth' 'maysside'
#  'south kellyland' 'north james' 'pamelaburgh' 'holtmouth' 'lake cheryl'
#  'youngchester' 'south andrewport' 'raybury' 'amandashire' 'hayesville'
#  'padillatown' 'phillipsmouth' 'morriston' 'browntown' 'lake mistyton'
#  'lake jamestown' 'galvanfurt' 'east robert' 'sarahview' 'laurietown'
#  'west elizabethport' 'south kathryn' 'mikaylachester' 'lake larry'
#  'huberstad' 'smithmouth' 'north william' 'south jason' 'north ryan'
#  'pamelaberg' 'port victoria' 'east cynthia' 'francisshire'
#  'port staceymouth' 'linchester' 'jessicaland' 'port juliafort'
#  'new evanport' 'shortfurt' 'aguirreville' 'south allison' 'lake nathan'
#  'benjaminstad' 'east christophertown' 'ginaview' 'north bethanyville'
#  'port anita' 'westmouth' 'port andrea' 'west kelli' 'markborough'
#  'port marissachester' 'west anthonymouth' 'port jennifer' 'south richard'
#  'north jenniferport' 'sarahside' 'richardmouth' 'port hannah' 'lisafort'
#  'michaelton' 'east richardside' 'east heatherport' 'south randy'
#  'north sharonburgh' 'port rebekah' 'new william' 'adamsville'
#  'south joshua' 'yatesside' 'new zachary' 'west lucasville' 'josephburgh'
#  'new travisshire' 'south douglashaven' 'jonathanmouth' 'codyview'
#  'south danielle' 'carrport' 'leonfort' 'port julia' 'lake bianca'
#  'williamview' 'wilsonview' 'edwardsbury' 'new bobbytown' 'north caitlin'
#  'raymondview' 'north mary' 'port melanie' 'gibsonfort' 'lindseybury'
#  'basstown' 'lake charleston' 'new michaelmouth' 'lake maria'
#  'new willieburgh' 'west james' 'mortonfort' 'west brandon' 'woodport'
#  'brownberg' 'drakeville' 'derekshire' 'north amanda' 'east amyfurt'
#  'north joseph' 'north katherineshire' 'petersonside' 'reynoldsbury'
#  'west samuelfurt' 'williamland' 'amandaborough' 'lake jason' 'east emily'
#  'leville' 'east michael' 'allenborough' 'ashleyhaven' 'new jamesburgh'
#  'walterton' 'port brett' 'robertschester' 'new emily' 'jordanberg'
#  'lake kelly' 'south andrew' 'lopezport' 'south bryan' 'lake karenfurt'
#  'east kimberly' 'torresshire' 'mendozastad' 'west charlesborough'
#  'lewishaven' 'north richard' 'katherineborough' 'harrishaven'
#  'thorntonbury' 'new ninashire' 'south charles' 'north biancaview'
#  'port erin' 'cisnerostown' 'lake tamara' 'east janet' 'north kennethview'
#  'olsenstad' 'parksburgh' 'south thomasville' 'williamsonmouth'
#  'fowlerbury' 'north stevenbury' 'kaitlynville' 'east shanestad'
#  'east michelle' 'smithstad' 'bryantton' 'brewerfort' 'jordanborough'
#  'johnsonborough' 'frostberg' 'north valerie' 'lake kendramouth'
#  'east tammy' 'port michael' 'cabreraberg' 'new frank' 'new robertstad'
#  'judystad' 'rodriguezview' 'port hannahmouth' 'new hollyfurt'
#  'madelinechester' 'ramosville' 'east sonyaport' 'priceland'
#  'south william' 'brookeland' 'campbellchester' 'tracyfort' 'lake michael'
#  'sheenashire' 'new jenniferbury' 'jenniferville' 'new jacob'
#  'robinsonfort' 'lake stephen' 'new tiffanystad' 'strongmouth'
#  'west sharonview' 'owensstad' 'pereztown' 'charlesland' 'russellfurt'
#  'gomezfurt' 'cannonside' 'padillamouth' 'weberfurt' 'villastad'
#  'medinatown' 'north steven' 'west peter' 'west melissastad'
#  'port robertport' 'lake kari' 'west miaside' 'north kennethshire'
#  'west kevin' 'south marthahaven' 'east phillipton' 'sheilaburgh'
#  'leeburgh' 'garciatown' 'blaketown' 'erikatown' 'garciaberg'
#  'port raymondburgh' 'patrickfort' 'east heather' 'port tanyaburgh'
#  'new calebberg' 'lucasmouth' 'jonestown' 'port donnamouth' 'east jesse'
#  'north chase' 'east benjaminland' 'zimmermanton' 'lake richardhaven'
#  'kellytown' 'south allisonburgh' 'new ginaborough' 'anthonyborough'
#  'steveport' 'ramseyfort' 'lisaborough' 'roachhaven' 'hollyhaven'
#  'new monicaside' 'williamsshire' 'port allisonland' 'west stephenside'
#  'lake devon' 'campbellbury' 'tamaraside' 'roystad' 'west lisamouth'
#  'lake deborah' 'south zacharymouth' 'spenceland' 'samueltown'
#  'west abigailtown' 'randallchester' 'wrightville' 'lake lindsey'
#  'south tina' 'lake vanessaland' 'north victoriastad' 'port lance'
#  'alexanderchester' 'east bernard' 'connieside' 'port bryce'
#  'christopherside' 'coleburgh' 'christopherton' 'port christopher'
#  'jeffreybury' 'port daniel' 'port melissa' 'moralesberg' 'east robertton'
#  'davisview' 'south jessicachester' 'flemingport' 'west hunter'
#  'west stevenport' 'westbury' 'herbertbury' 'south edwardtown'
#  'harrisonbury' 'port david' 'south kevinhaven' 'east laura'
#  'north lauren' 'lake latasha' 'stevensborough' 'browninghaven' 'amyport'
#  'manningshire' 'east rossside' 'joshuastad' 'stevenchester' 'brendantown']

# %%
providers.head()
# Out:
#    Provider_ID                        Name           Type  \
# 0            1            gonzales-cochran    Supermarket
# 1            2  nielsen johnson and fuller  Grocery Store
# 2            3                miller-black    Supermarket
# 3            4   clark prince and williams  Grocery Store
# 4            5              coleman-farley  Grocery Store
#
#                                              Address            City  \
# 0  74347 Christopher Extensions\nAndreamouth, OK ...     new jessica
# 1           91228 Hanson Stream\nWelchtown, OR 27136     east sheena
# 2  561 Martinez Point Suite 507\nGuzmanchester, W...  lake jesusview
# 3     467 Bell Trail Suite 409\nPort Jesus, IA 61188     mendezmouth
# 4  078 Matthew Creek Apt. 319\nSaraborough, MA 53978   valentineside
#
#            Contact
# 0  +1-600-220-0480
# 1  +1-838-901-6297
# 2  +1-517-295-2206
# 3  +1-944-893-5401
# 4  +1-193-714-6577

# %%
receivers
# Out:
#      Receiver_ID             Name        Type               City  \
# 0              1     Donald Gomez     Shelter     Port Carlburgh
# 1              2     Laurie Ramos  Individual         Lewisburgh
# 2              3     Ashley Mckee         NGO  South Randalltown
# 3              4       Erika Rose         NGO   South Shaneville
# 4              5      John Romero  Individual          Bakerport
# ..           ...              ...         ...                ...
# 995          996   Matthew Curtis     Shelter        Lanechester
# 996          997      Amanda Cain         NGO         New Steven
# 997          998  Theodore Briggs  Individual       South Sandra
# 998          999  Cheyenne Ramsey         NGO       Lake Jeffery
# 999         1000     April Miller     Shelter      Shelbychester
#
#                     Contact
# 0             (955)922-5295
# 1              761.042.1570
# 2          691-023-0094x856
# 3                8296491111
# 4              067.491.0154
# ..                      ...
# 995       127-889-4442x1289
# 996    +1-001-491-5601x5316
# 997       930-609-9442x5031
# 998  001-326-320-4816x15300
# 999      894-873-2652x23999
#
# [1000 rows x 5 columns]

# %%
print("\nNumber of null values per column:")
print(receivers.isnull().sum())

# On inspection there are no NULL values
# Out:
# Number of null values per column:
# Receiver_ID    0
# Name           0
# Type           0
# City           0
# Contact        0
# dtype: int64

# %%
receivers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Receiver_ID  1000 non-null   int64
#  1   Name         1000 non-null   object
#  2   Type         1000 non-null   object
#  3   City         1000 non-null   object
#  4   Contact      1000 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 39.2+ KB

# %%
# Count duplicate rows
duplicate_count = receivers.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 0

# %%
# Standardized contact column
import re

def standardize_phone(phone):
    # Remove all non-digit characters except 'x' for extension
    digits = re.sub(r'\D', '', phone)

    # Keep only first 10 digits for the main number
    main_number = digits[-10:]

    # Format: +1-XXX-XXX-XXXX
    formatted = f"+1-{main_number[0:3]}-{main_number[3:6]}-{main_number[6:]}"

    return formatted

# Apply to 'contact' column
receivers['Contact'] = receivers['Contact'].astype(str).apply(standardize_phone)

# Check result
print(receivers['Contact'].head())
# Out:
# 0    +1-955-922-5295
# 1    +1-761-042-1570
# 2    +1-023-009-4856
# 3    +1-829-649-1111
# 4    +1-067-491-0154
# Name: Contact, dtype: object

# %%
# Cleaning and standardizing the 'Name' column by removing extra spaces, unwanted characters,
# replacing hyphens with spaces, and converting all text to lowercase for consistency
import re
import pandas as pd

def clean_name_lower(name):
    if pd.isna(name):
        return name
    # Remove leading/trailing spaces
    name = name.strip()
    # Replace hyphens with spaces
    name = name.replace('-', ' ')
    # Collapse multiple spaces
    name = re.sub(r'\s+', ' ', name)
    # Remove digits and special chars except space and apostrophe
    name = re.sub(r"[^a-zA-Z\s']", "", name)
    # Convert to lowercase
    name = name.lower()
    return name

# Apply to Name column
receivers['Name'] = receivers['Name'].apply(clean_name_lower)

# Check results
print(receivers['Name'].head(10))
# Out:
# 0        donald gomez
# 1        laurie ramos
# 2        ashley mckee
# 3          erika rose
# 4         john romero
# 5    mandy sutton phd
# 6       kenneth baker
# 7         james perez
# 8        emily turner
# 9        mary salazar
# Name: Name, dtype: object

# %%
print(receivers['Type'].unique())
# Out:
# ['Shelter' 'Individual' 'NGO' 'Charity']

# %%
# Cleaning and standardizing the 'City' column
import re

def clean_city(name):
    if pd.isna(name):
        return name
    # Remove leading/trailing spaces
    name = name.strip()
    # Collapse multiple spaces
    name = re.sub(r'\s+', ' ', name)
    # Remove unwanted characters except letters, spaces, and hyphens
    name = re.sub(r"[^a-zA-Z\s\-]", "", name)
    # Convert to lowercase for consistency
    name = name.lower()
    return name

# Apply cleaning to the 'City' column
receivers['City'] = receivers['City'].apply(clean_city)

# Check unique values after cleaning
print(receivers['City'].unique())
# Out:
# ['port carlburgh' 'lewisburgh' 'south randalltown' 'south shaneville'
#  'bakerport' 'east sharimouth' 'south edwinborough' 'benjaminburgh'
#  'west robert' 'wrightland' 'south gregorymouth' 'katherineside'
#  'lake matthewstad' 'burkeside' 'port ronald' 'port tara' 'silvaport'
#  'moranhaven' 'north cynthiaberg' 'sandrahaven' 'jonesside' 'lake nicole'
#  'aliciabury' 'monicafort' 'lake elizabeth' 'port matthewmouth'
#  'susanfurt' 'courtneyfurt' 'lake kendra' 'north heather' 'spencermouth'
#  'taylorfort' 'walshfort' 'north robert' 'south rachaelhaven' 'olsonville'
#  'west erik' 'josephview' 'moorechester' 'west carrie' 'port kellyburgh'
#  'port dawntown' 'amberfort' 'davisborough' 'south laurachester'
#  'east teresahaven' 'east saraport' 'south tonyaborough' 'north sarah'
#  'port johnchester' 'hornemouth' 'tomburgh' 'higginsmouth' 'larastad'
#  'jasonshire' 'new mary' 'michaelton' 'lake mary' 'phillipborough'
#  'south kathleenbury' 'north catherinefurt' 'east william'
#  'north darinshire' 'port belinda' 'west jaclyn' 'strongshire'
#  'edwardburgh' 'east dylan' 'gregoryville' 'new gloriaburgh'
#  'west angelatown' 'christineton' 'laurafurt' 'manningtown'
#  'north jenniferside' 'north david' 'marshallton' 'angelaville'
#  'knightburgh' 'port gregoryport' 'evansside' 'davidview' 'east kelli'
#  'lake john' 'smithshire' 'west ronaldland' 'lake daniel' 'robinsonside'
#  'kellybury' 'garrettborough' 'greenton' 'alexatown' 'new jessica'
#  'laurafort' 'carterside' 'south veronicaburgh' 'henryhaven'
#  'russellville' 'robertaborough' 'hollytown' 'north matthewhaven'
#  'west justin' 'north joshuafort' 'north pamela' 'lake rebecca'
#  'port elizabethton' 'east josephstad' 'theresamouth' 'lake michaelton'
#  'west johnny' 'michaeltown' 'georgeborough' 'meganton' 'scottmouth'
#  'port teresa' 'east heatherborough' 'south franciscoport' 'deanview'
#  'kennethberg' 'ayalamouth' 'port patriciachester' 'south alexandraport'
#  'meghanfort' 'campbellchester' 'north lori' 'north roger' 'new benjamin'
#  'drakeburgh' 'marieview' 'jeffhaven' 'south jasonberg' 'west james'
#  'marcusberg' 'huntermouth' 'new elaine' 'bakerfort' 'phillipsbury'
#  'new christopher' 'north christina' 'dawnview' 'wilsonfort' 'nancyshire'
#  'north paul' 'tanyachester' 'joshuamouth' 'new shannonbury'
#  'north amandafort' 'danielfort' 'davidmouth' 'new aimeemouth' 'caseyland'
#  'williamtown' 'lake victoriaport' 'patriciaton' 'jacobsmouth'
#  'charleston' 'south ashley' 'lisaton' 'south jill' 'mcclurestad'
#  'amandaville' 'daleshire' 'heatherfurt' 'east sarahtown' 'ginamouth'
#  'west shawn' 'east timhaven' 'nguyenfurt' 'port erica' 'joanchester'
#  'thomaston' 'west courtneyport' 'smithstad' 'new tiffany' 'nicoleport'
#  'robertsonchester' 'port emilymouth' 'west krystalview' 'peterhaven'
#  'seanside' 'thomasland' 'port melissa' 'lake amanda' 'heathertown'
#  'lake erica' 'angelicatown' 'maxberg' 'north shelby' 'new seanburgh'
#  'toddborough' 'figueroaport' 'shawmouth' 'new jason' 'port dustin'
#  'east tinamouth' 'east teresamouth' 'east sharon' 'east jillian'
#  'corybury' 'north mario' 'allenmouth' 'north lindachester' 'west casey'
#  'ramseystad' 'south kendraville' 'andrewmouth' 'steveberg' 'south anna'
#  'baileyville' 'stevenmouth' 'emilymouth' 'new roseville' 'port stephen'
#  'west amybury' 'ashleyborough' 'new daniel' 'lake austinmouth' 'dantown'
#  'robinsonland' 'west aaronport' 'hallside' 'east jacob' 'west jessica'
#  'fergusonton' 'port maria' 'singletonview' 'bushview' 'poolestad'
#  'port brianville' 'davidshire' 'port ericmouth' 'lake julia' 'rogerburgh'
#  'new derek' 'west josephshire' 'davisburgh' 'north kimberlyport'
#  'edwardsside' 'wilsonfurt' 'garciaview' 'west vickie' 'carolhaven'
#  'new craig' 'lake darrellburgh' 'aaronshire' 'new abigail' 'lake kelli'
#  'jenniferberg' 'martinland' 'new julian' 'west christiantown'
#  'williamsfort' 'new tina' 'christopherland' 'south amy' 'port samantha'
#  'barnesport' 'lake jessicaborough' 'east moniquemouth' 'east john'
#  'west johnmouth' 'west kelly' 'murrayview' 'bauerton' 'dylanton'
#  'monicaton' 'east ashleyshire' 'brianchester' 'autumnbury'
#  'east williamborough' 'longmouth' 'brandonside' 'west christopher'
#  'port jessica' 'port samanthamouth' 'lake christychester'
#  'lake stephenport' 'isaiahtown' 'dustinfurt' 'stephaniechester'
#  'castilloland' 'burnettton' 'susanview' 'lake tina' 'hannahside'
#  'north josephland' 'shermantown' 'east bryan' 'jamesstad' 'east dale'
#  'lake michael' 'aguilarstad' 'marksmouth' 'alexanderbury'
#  'north alexander' 'melissaport' 'port richard' 'millerport'
#  'edwardshaven' 'kellyville' 'calebview' 'north patriciamouth'
#  'cynthiashire' 'new julia' 'new sara' 'geraldchester' 'schaeferfort'
#  'north kimberlyfort' 'haleymouth' 'west aaronberg' 'meganmouth'
#  'lake glenview' 'danielborough' 'andersenfort' 'north williamview'
#  'south bethanyport' 'north ashleymouth' 'new sarahmouth' 'thompsonhaven'
#  'south amybury' 'east gina' 'melissaview' 'new justinhaven' 'edwardfort'
#  'north bruce' 'reidton' 'hammondfort' 'chaseview' 'lake melindaside'
#  'victoriastad' 'east lisafurt' 'south michelleshire' 'thomasberg'
#  'gomezmouth' 'new william' 'murphyfort' 'lake rebeccaton' 'melindaview'
#  'priceborough' 'rushfurt' 'east joseph' 'maryfort' 'jenniferbury'
#  'angelamouth' 'juliastad' 'lake lesliemouth' 'lake dillonborough'
#  'swansonport' 'west jeffrey' 'west dan' 'north nicole' 'johnland'
#  'north jamesfurt' 'new corey' 'south john' 'jaredport'
#  'west matthewborough' 'duncanchester' 'paulmouth' 'port dean'
#  'south barbaraburgh' 'port brandonberg' 'port johnstad'
#  'lake stevenburgh' 'jamieview' 'leeton' 'lawrencechester' 'lake cory'
#  'lake ryan' 'reevestown' 'perezport' 'west tina' 'north michelle'
#  'kellyfurt' 'tiffanyport' 'lisafurt' 'rachelberg' 'lake jonathanchester'
#  'new brandonton' 'lake clinton' 'gordonstad' 'west jorge' 'sarahville'
#  'sherryhaven' 'new amy' 'bergerport' 'port carmen' 'west donnaton'
#  'west randall' 'lake matthew' 'north manuel' 'new deborahville'
#  'new kevin' 'chambersmouth' 'lake crystal' 'clarkhaven' 'morganville'
#  'brandonhaven' 'north abigail' 'west mikayla' 'port dianemouth'
#  'new natalieland' 'christopherchester' 'lake laurenburgh' 'christinaland'
#  'rayfurt' 'north holly' 'port thomasstad' 'josephborough' 'jonathanview'
#  'south tyler' 'south edwardburgh' 'lewisfort' 'chadport' 'rosaleschester'
#  'lake steven' 'lake karen' 'russellburgh' 'pagemouth' 'east douglas'
#  'east melissaport' 'lake kyleside' 'south connorview' 'martinezside'
#  'robertsport' 'west rogerview' 'lake joshuaville' 'north margarethaven'
#  'troyshire' 'west cherylland' 'port sara' 'port michaelmouth'
#  'coreymouth' 'north kathryn' 'port deborahbury' 'mikemouth'
#  'new timothymouth' 'port jenniferborough' 'new rebecca' 'hollyside'
#  'port judith' 'davidport' 'cruzborough' 'port deborah' 'lake christina'
#  'sandratown' 'east andrewhaven' 'powerston' 'west justinberg'
#  'edwardport' 'lake adriennechester' 'north jeffreychester' 'bushbury'
#  'chrisport' 'south william' 'east daniel' 'heatherhaven' 'johnsonberg'
#  'north robinville' 'north kimberlyland' 'port dominique' 'port sarah'
#  'bobbyfort' 'east ginafort' 'castilloshire' 'west aliciaburgh'
#  'lake mitchellbury' 'south davidstad' 'new michaelport' 'andersonview'
#  'port gregory' 'port jason' 'new dustin' 'west jeffreyfurt'
#  'west richard' 'jessicatown' 'port brandon' 'rodriguezborough'
#  'south steven' 'lake rachelburgh' 'brooksmouth' 'christophertown'
#  'langburgh' 'proctorville' 'port derekland' 'port chaseport' 'huynhmouth'
#  'gilbertborough' 'connerland' 'lewismouth' 'matthewhaven' 'bradleyland'
#  'port margaretport' 'carlosfurt' 'susanville' 'huffmouth' 'lake gloria'
#  'pittsville' 'sarahaven' 'olsonland' 'robertview' 'turnerhaven'
#  'new travisland' 'stephanieberg' 'paynestad' 'lisaborough' 'carolinebury'
#  'east cynthiahaven' 'port angelafurt' 'ramirezhaven' 'rebeccaview'
#  'darinland' 'east peter' 'new robert' 'west jacquelineland' 'diazshire'
#  'paulaburgh' 'south michaelfurt' 'new michael' 'anthonyport'
#  'christinahaven' 'phillipston' 'port michaelport' 'carterton'
#  'vasquezberg' 'east davidbury' 'shelbyland' 'ashleeside' 'jacobmouth'
#  'port traci' 'port kristinechester' 'lake lance' 'south donaldshire'
#  'gonzalezstad' 'new alexismouth' 'south eric' 'west alexandra'
#  'shaneport' 'adamland' 'ortizmouth' 'woodsfurt' 'kingville' 'rayberg'
#  'brownville' 'south meganland' 'hallton' 'west kevin' 'randyville'
#  'pottertown' 'east jordanborough' 'east kimberlymouth'
#  'north michaelville' 'roberttown' 'south yolanda' 'port todd'
#  'north hollyland' 'murrayside' 'port courtneyland' 'barreratown'
#  'hollandburgh' 'east stephenton' 'lake cody' 'south elizabeth'
#  'port paulaton' 'north sherribury' 'hunterbury' 'lake gregory'
#  'whiteside' 'lisaview' 'north nathanville' 'north raymond' 'mooreburgh'
#  'beckville' 'south gabrielmouth' 'north lisaburgh' 'north christopher'
#  'west mariashire' 'west carrieberg' 'jonesland' 'ariasbury'
#  'south yvettestad' 'new tammyhaven' 'biancaton' 'kinghaven'
#  'new christopherburgh' 'butlerborough' 'east nathan' 'nicoleside'
#  'mcfarlandhaven' 'south nicoleberg' 'new carrie' 'mcdanielmouth'
#  'patriciamouth' 'north tiffanyfort' 'south waynefurt' 'robertside'
#  'new kellytown' 'shelleyburgh' 'andersonland' 'nguyenview'
#  'west danielview' 'mendozabury' 'kimberlyview' 'keithstad'
#  'east heatherbury' 'stephenchester' 'port david' 'east nicole'
#  'morenoborough' 'vancebury' 'new daryl' 'north marcusbury' 'perezhaven'
#  'robertton' 'johnville' 'blakehaven' 'west garretthaven' 'moralesfort'
#  'cameronfurt' 'anthonystad' 'east antoniobury' 'new ryanmouth'
#  'melaniehaven' 'fowlerburgh' 'robertfurt' 'west juanchester' 'josephton'
#  'south lucasview' 'johnsonville' 'west troyview' 'port timothymouth'
#  'north michael' 'port mariemouth' 'fernandezberg' 'michealstad'
#  'port peggyshire' 'port maryshire' 'south anthonyside' 'kempstad'
#  'kenthaven' 'petersonmouth' 'port shannonhaven' 'toddstad' 'markfurt'
#  'jensenland' 'davidland' 'rogersfort' 'sharpfurt' 'chenview'
#  'port seanshire' 'goodmanfort' 'brooksborough' 'new mark'
#  'south jasminechester' 'south shirleymouth' 'richardton' 'jeanshire'
#  'karenfort' 'taylorport' 'ellisborough' 'port joshua' 'east sheenahaven'
#  'north erikhaven' 'east tiffanyview' 'lake sheilaland' 'wardshire'
#  'christinehaven' 'joshuahaven' 'nelsonbury' 'new james' 'west amandaport'
#  'changview' 'davidtown' 'new shauntown' 'east emily' 'west monica'
#  'south marymouth' 'west brittany' 'bruceburgh' 'sarahside'
#  'east nathanstad' 'lake kevinport' 'new frederickfort' 'south jason'
#  'new stephanie' 'nicholsonland' 'lovestad' 'mercerport' 'port terry'
#  'north amanda' 'lake douglas' 'lake tracytown' 'shortfort'
#  'port amberfurt' 'east stephaniefort' 'nicoleberg' 'heatherburgh'
#  'south mark' 'new brandyhaven' 'east tasha' 'new matthewton' 'victorton'
#  'port marc' 'kimberlymouth' 'port curtisside' 'east michael'
#  'south jenniferburgh' 'south richard' 'perryton' 'reedview'
#  'cummingschester' 'lake catherine' 'west bradley' 'east jamesmouth'
#  'garciashire' 'west david' 'danielsview' 'lake heatherberg'
#  'south lindsay' 'wilsonshire' 'south williamview' 'moralesburgh'
#  'north vanessamouth' 'south edward' 'leahchester' 'aguilarbury'
#  'new sean' 'south samanthaburgh' 'lake michelle' 'north danielchester'
#  'south theresaberg' 'hardyberg' 'brittanyborough' 'deanstad'
#  'east stevenborough' 'sandovalmouth' 'oliverberg' 'buchananton'
#  'grahambury' 'east julietown' 'lake kimberlyton' 'cookhaven' 'new jesus'
#  'wagnerburgh' 'danielfurt' 'west victoriaberg' 'south jessicaburgh'
#  'donnamouth' 'ronaldmouth' 'diazbury' 'melissaberg' 'north mallorystad'
#  'jeffreyland' 'reginaburgh' 'east janetstad' 'new phillipfurt'
#  'josephfurt' 'brownport' 'port gabrielleborough' 'zacharyview'
#  'hansonfurt' 'west carrieport' 'port caleb' 'deanfort' 'princehaven'
#  'andersonfort' 'north andresport' 'south jamesfort' 'danielland'
#  'westport' 'east josephview' 'brownbury' 'west meganmouth'
#  'lake lindseystad' 'theresabury' 'south michelleport' 'lisabury'
#  'josephside' 'harrisfurt' 'east daisybury' 'westshire' 'shawhaven'
#  'comptonside' 'maryside' 'north dawn' 'south sheryl' 'martinchester'
#  'andreaberg' 'delgadofort' 'west jacob' 'davisport' 'east mark'
#  'east amandaberg' 'cruzland' 'new olivia' 'west jacquelinefort'
#  'north tanner' 'michaelside' 'scottbury' 'lake christian' 'new kimberly'
#  'ginaview' 'west josephland' 'lauratown' 'south lisa' 'west john'
#  'west michaelton' 'north kelly' 'south mirandamouth' 'amandaburgh'
#  'new laura' 'halltown' 'lake dustin' 'ramosberg' 'johnsonchester'
#  'meganburgh' 'taraside' 'ellisshire' 'bradfurt' 'wyattton'
#  'port williamtown' 'crawfordchester' 'lorifurt' 'collierburgh'
#  'new larryshire' 'lake kaylamouth' 'lake stephenchester' 'cookstad'
#  'kirkfort' 'poolebury' 'new erikamouth' 'billyland' 'south craigborough'
#  'lake joshuabury' 'pooleside' 'new dakotahaven' 'west lindseyside'
#  'north shawnastad' 'north amy' 'natalieside' 'annaborough'
#  'port philipmouth' 'east shirley' 'new donnahaven' 'jamesview'
#  'north nicholasborough' 'port robertmouth' 'south emily' 'north ricardo'
#  'tylermouth' 'rodneyport' 'new jeffreyhaven' 'north josephmouth'
#  'east robert' 'allenborough' 'fernandezchester' 'birdview' 'west sara'
#  'jamesborough' 'north haleyhaven' 'lake williamhaven' 'jarvisshire'
#  'new adrian' 'west barry' 'new loriberg' 'east michaelview' 'grossport'
#  'east kevinberg' 'dawsonberg' 'new juliaton' 'franklinview' 'east travis'
#  'payneland' 'new melanie' 'lake shawn' 'rubioborough' 'lake brandibury'
#  'jessicaland' 'williamsborough' 'kennethmouth' 'woodardview'
#  'south alanville' 'ianland' 'east kevin' 'jenkinsfurt' 'west davidview'
#  'lake victoriaton' 'kelleystad' 'darinview' 'north janetland'
#  'west donaldmouth' 'east sheriton' 'gloriaview' 'carlostown' 'mathistown'
#  'dunnbury' 'south michael' 'south mary' 'west paulfort' 'erikashire'
#  'riverafort' 'port douglasland' 'port jonathanton' 'hayesfort'
#  'lake brandonborough' 'elizabethberg' 'south heather' 'rodneyborough'
#  'new jessicabury' 'new melindashire' 'caitlynhaven' 'north lawrence'
#  'east debramouth' 'west ashleymouth' 'north lydiaberg' 'delacruzborough'
#  'robertville' 'gilbertfurt' 'port jonathanhaven' 'nathanstad'
#  'jacquelineshire' 'kennethside' 'greenville' 'oneillland' 'suzanneton'
#  'myerstown' 'west dustinberg' 'north stephanieborough' 'johnhaven'
#  'davisfort' 'port thomas' 'lake larryborough' 'port cindyberg'
#  'mariefurt' 'bennettton' 'south benjamin' 'mayburgh' 'lauraport'
#  'patrickfort' 'north joshua' 'amandafurt' 'clarkton' 'south paul'
#  'lake sonya' 'teresastad' 'carrborough' 'port cody' 'gutierrezmouth'
#  'north jacobhaven' 'travishaven' 'rodneyfurt' 'south jamie' 'east renee'
#  'nielsenberg' 'north laura' 'thomasport' 'jessicaburgh' 'port johnside'
#  'matthewmouth' 'port kellifort' 'andrewsport' 'lanechester' 'new steven'
#  'south sandra' 'lake jeffery' 'shelbychester']

# %%
food_listings
# Out:
#      Food_ID Food_Name  Quantity Expiry_Date  Provider_ID     Provider_Type  \
# 0          1     Bread        43   3/17/2025          110     Grocery Store
# 1          2      Soup        22   3/24/2025          791     Grocery Store
# 2          3    Fruits        46   3/28/2025          478  Catering Service
# 3          4    Fruits        15   3/16/2025          930        Restaurant
# 4          5      Soup        14   3/19/2025          279        Restaurant
# ..       ...       ...       ...         ...          ...               ...
# 995      996      Fish        15   3/30/2025          467  Catering Service
# 996      997      Fish        22   3/18/2025           35     Grocery Store
# 997      998    Fruits         6   3/22/2025          444        Restaurant
# 998      999     Pasta        15   3/30/2025          702       Supermarket
# 999     1000     Salad        18   3/19/2025          155       Supermarket
#
#              Location       Food_Type  Meal_Type
# 0    South Kellyville  Non-Vegetarian  Breakfast
# 1          West James  Non-Vegetarian     Dinner
# 2         Lake Regina           Vegan  Breakfast
# 3           Kellytown           Vegan      Lunch
# 4          Garciaport           Vegan     Dinner
# ..                ...             ...        ...
# 995      Phillipsfort           Vegan  Breakfast
# 996     Andersonmouth      Vegetarian  Breakfast
# 997         New Billy  Non-Vegetarian     Dinner
# 998     Lake Mistyton  Non-Vegetarian      Lunch
# 999       Charlesview  Non-Vegetarian     Dinner
#
# [1000 rows x 9 columns]

# %%
print("\nNumber of null values per column:")
print(food_listings.isnull().sum())

# On inspection there are no NULL values
# Out:
# Number of null values per column:
# Food_ID          0
# Food_Name        0
# Quantity         0
# Expiry_Date      0
# Provider_ID      0
# Provider_Type    0
# Location         0
# Food_Type        0
# Meal_Type        0
# dtype: int64

# %%
food_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Food_ID        1000 non-null   int64
#  1   Food_Name      1000 non-null   object
#  2   Quantity       1000 non-null   int64
#  3   Expiry_Date    1000 non-null   object
#  4   Provider_ID    1000 non-null   int64
#  5   Provider_Type  1000 non-null   object
#  6   Location       1000 non-null   object
#  7   Food_Type      1000 non-null   object
#  8   Meal_Type      1000 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 70.4+ KB

# %%
# Count duplicate rows
duplicate_count = food_listings.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 0

# %%
print(food_listings['Food_Name'].unique())
# Out:
# ['Bread' 'Soup' 'Fruits' 'Vegetables' 'Dairy' 'Rice' 'Pasta' 'Salad'
#  'Chicken' 'Fish']

# %%
print(food_listings['Food_Type'].unique())
# Out:
# ['Non-Vegetarian' 'Vegan' 'Vegetarian']

# %%
print(food_listings['Meal_Type'].unique())
# Out:
# ['Breakfast' 'Dinner' 'Lunch' 'Snacks']

# %%
print(food_listings['Provider_Type'].unique())
# Out:
# ['Grocery Store' 'Catering Service' 'Restaurant' 'Supermarket']

# %%
print(food_listings.columns.tolist())
# Out:
# ['Food_ID', 'Food_Name', 'Quantity', 'Expiry_Date', 'Provider_ID', 'Provider_Type', 'Location', 'Food_Type', 'Meal_Type']

# %%
food_listings['Expiry_Date']
# Out:
# 0      3/17/2025
# 1      3/24/2025
# 2      3/28/2025
# 3      3/16/2025
# 4      3/19/2025
#          ...
# 995    3/30/2025
# 996    3/18/2025
# 997    3/22/2025
# 998    3/30/2025
# 999    3/19/2025
# Name: Expiry_Date, Length: 1000, dtype: object

# %%
food_listings['Expiry_Date']= pd.to_datetime(food_listings['Expiry_Date'], errors='coerce').dt.strftime('%Y-%m-%d')

print(food_listings['Expiry_Date'].head())
# Out:
# 0    2025-03-17
# 1    2025-03-24
# 2    2025-03-28
# 3    2025-03-16
# 4    2025-03-19
# Name: Expiry_Date, dtype: object

# %%
claims
# Out:
#      Claim_ID  Food_ID  Receiver_ID     Status        Timestamp
# 0           1      164          908    Pending    3/5/2025 5:26
# 1           2      353          391  Cancelled  3/11/2025 10:24
# 2           3      626          492  Completed   3/21/2025 0:59
# 3           4       61          933  Cancelled    3/4/2025 9:08
# 4           5      345          229    Pending  3/14/2025 15:17
# ..        ...      ...          ...        ...              ...
# 995       996      855          211  Completed  3/13/2025 19:40
# 996       997      980          746  Cancelled  3/17/2025 22:04
# 997       998      832          967  Cancelled  3/13/2025 18:00
# 998       999      917           90  Completed   3/1/2025 15:31
# 999      1000      596          950  Cancelled  3/13/2025 12:51
#
# [1000 rows x 5 columns]

# %%
print("\nNumber of null values per column:")
print(claims.isnull().sum())

# On inspection there are no NULL values
# Out:
# Number of null values per column:
# Claim_ID       0
# Food_ID        0
# Receiver_ID    0
# Status         0
# Timestamp      0
# dtype: int64

# %%
claims.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Claim_ID     1000 non-null   int64
#  1   Food_ID      1000 non-null   int64
#  2   Receiver_ID  1000 non-null   int64
#  3   Status       1000 non-null   object
#  4   Timestamp    1000 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 39.2+ KB

# %%
# Count duplicate rows
duplicate_count = claims.duplicated().sum()
print(f"Number of duplicate rows: {duplicate_count}")
# Out:
# Number of duplicate rows: 0

# %%
print(claims['Status'].unique())
# Out:
# ['Pending' 'Cancelled' 'Completed']

# %%
# Convert Timestamp column in claims to standardized datetime
claims['Timestamp'] = pd.to_datetime(claims['Timestamp'], errors='coerce')

# Optional: format as string YYYY-MM-DD HH:MM:SS
claims['Timestamp'] = claims['Timestamp'].dt.strftime('%Y-%m-%d %H:%M:%S')

print(claims['Timestamp'].head())
# Out:
# 0    2025-03-05 05:26:00
# 1    2025-03-11 10:24:00
# 2    2025-03-21 00:59:00
# 3    2025-03-04 09:08:00
# 4    2025-03-14 15:17:00
# Name: Timestamp, dtype: object

# %%
claims
# Out:
#      Claim_ID  Food_ID  Receiver_ID     Status            Timestamp
# 0           1      164          908    Pending  2025-03-05 05:26:00
# 1           2      353          391  Cancelled  2025-03-11 10:24:00
# 2           3      626          492  Completed  2025-03-21 00:59:00
# 3           4       61          933  Cancelled  2025-03-04 09:08:00
# 4           5      345          229    Pending  2025-03-14 15:17:00
# ..        ...      ...          ...        ...                  ...
# 995       996      855          211  Completed  2025-03-13 19:40:00
# 996       997      980          746  Cancelled  2025-03-17 22:04:00
# 997       998      832          967  Cancelled  2025-03-13 18:00:00
# 998       999      917           90  Completed  2025-03-01 15:31:00
# 999      1000      596          950  Cancelled  2025-03-13 12:51:00
#
# [1000 rows x 5 columns]

# %% [markdown]
# # 2. Database Creation

# %%
import sqlite3

conn = sqlite3.connect("food_wastage.db")
cursor = conn.cursor()

# Drop tables if they exist
cursor.execute("DROP TABLE IF EXISTS providers")
cursor.execute("DROP TABLE IF EXISTS receivers")
cursor.execute("DROP TABLE IF EXISTS food_listings")
cursor.execute("DROP TABLE IF EXISTS claims")

# Recreate tables
cursor.execute('''
CREATE TABLE providers (
    Provider_ID INTEGER PRIMARY KEY,
    Name TEXT,
    Type TEXT,
    Address TEXT,
    City TEXT,
    Contact TEXT
)
''')

cursor.execute('''
CREATE TABLE receivers (
    Receiver_ID INTEGER PRIMARY KEY,
    Name TEXT,
    Type TEXT,
    City TEXT,
    Contact TEXT
)
''')

cursor.execute('''
CREATE TABLE food_listings (
    Food_ID INTEGER PRIMARY KEY,
    Food_Name TEXT,
    Quantity INTEGER,
    Expiry_Date DATE,
    Provider_ID INTEGER,
    Provider_Type TEXT,
    Location TEXT,
    Food_Type TEXT,
    Meal_Type TEXT,
    FOREIGN KEY (Provider_ID) REFERENCES providers (Provider_ID)
)
''')

cursor.execute('''
CREATE TABLE claims (
    Claim_ID INTEGER PRIMARY KEY,
    Food_ID INTEGER,
    Receiver_ID INTEGER,
    Status TEXT,
    Timestamp DATETIME,
    FOREIGN KEY (Food_ID) REFERENCES food_listings (Food_ID),
    FOREIGN KEY (Receiver_ID) REFERENCES receivers (Receiver_ID)
)
''')

conn.commit()

# %%
providers.to_sql("providers", conn, if_exists="append", index=False)
receivers.to_sql("receivers", conn, if_exists="append", index=False)
food_listings.to_sql("food_listings", conn, if_exists="append", index=False)
claims.to_sql("claims", conn, if_exists="append", index=False)
# Out:
# 1000

# %%
import sqlite3

# Connect to local database file
conn = sqlite3.connect("food_wastage.db")
cursor = conn.cursor()

# %%
# Show all tables
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

print("Tables in database:")
for table in tables:
    print(table[0])
# Out:
# Tables in database:
# providers
# receivers
# food_listings
# claims

# %%
# Display all data from a table
cursor.execute("SELECT * FROM providers;")
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (1, 'gonzales-cochran', 'Supermarket', '74347 Christopher Extensions\nAndreamouth, OK 91839', 'new jessica', '+1-600-220-0480')
# (2, 'nielsen johnson and fuller', 'Grocery Store', '91228 Hanson Stream\nWelchtown, OR 27136', 'east sheena', '+1-838-901-6297')
# (3, 'miller-black', 'Supermarket', '561 Martinez Point Suite 507\nGuzmanchester, WA 94320', 'lake jesusview', '+1-517-295-2206')
# (4, 'clark prince and williams', 'Grocery Store', '467 Bell Trail Suite 409\nPort Jesus, IA 61188', 'mendezmouth', '+1-944-893-5401')
# (5, 'coleman-farley', 'Grocery Store', '078 Matthew Creek Apt. 319\nSaraborough, MA 53978', 'valentineside', '+1-193-714-6577')
# (6, 'lawson-walters', 'Grocery Store', '1889 Barnes Gateway\nAdamview, ID 87971', 'shannonside', '+1-060-746-0544')
# (7, 'ortiz-lee', 'Restaurant', '1842 Villarreal Shores\nWilliamfort, CT 44529', 'lake christopherburgh', '+1-563-889-7190')
# (8, 'curtis-lewis', 'Supermarket', '4770 Miller Light Suite 260\nNew Charlesville, AR 97075', 'washingtonville', '+1-278-120-3301')
# (9, 'nguyen inc', 'Supermarket', '169 Scott Keys Suite 000\nEast Michelle, HI 57025', 'tinamouth', '+1-609-260-9844')
# (10, 'hall nguyen and martinez', 'Catering Service', '71458 Mark Field Apt. 252\nNorth Alexland, TX 02693', 'west cherylfort', '+1-924-804-0566')
# (11, 'flores jackson and ford', 'Supermarket', '0663 Paul Field\nSouth Haileyshire, AL 19652', 'south robert', '+1-276-527-4329')
# (12, 'miller ltd', 'Supermarket', '508 White Mission Apt. 893\nBryantborough, WV 79111', 'east williamburgh', '+1-909-021-4559')
# (13, 'parker flores and jennings', 'Restaurant', '117 Jasmine Isle Apt. 604\nSouth Ryanville, MN 41933', 'nicolefort', '+1-516-626-8840')
# (14, 'nguyen-tran', 'Catering Service', '65833 Anthony Ridges\nWilliamsmouth, IA 42157', 'garciamouth', '+1-945-576-2932')
# (15, 'valdez-diaz', 'Grocery Store', '03142 Jones Trail Suite 601\nWalkerton, AL 61502', 'west theresaberg', '+1-046-544-9977')
# (16, 'brown and sons', 'Catering Service', '1745 Chan Ridges\nGinaville, OK 07163', 'west vanessafort', '+1-105-501-6593')
# (17, 'miller ltd', 'Catering Service', '355 Rogers Ferry Suite 116\nEast Stevenburgh, MD 93961', 'west dawn', '+1-798-619-3433')
# (18, 'edwards-turner', 'Restaurant', '277 Ashley Wall Suite 063\nKimberlyshire, SC 60998', 'cassandraville', '+1-668-894-2826')
# (19, 'davis ltd', 'Supermarket', 'USCGC Taylor\nFPO AA 68109', 'south melanieshire', '+1-249-394-3533')
# (20, 'drake-martinez', 'Catering Service', '22920 Carpenter Turnpike Apt. 652\nNew Steven, AR 33177', 'east samantha', '+1-123-510-6135')
# (21, 'cross group', 'Grocery Store', '802 Daniel Highway\nLake Sabrinamouth, DE 52427', 'port corystad', '+1-899-040-1296')
# (22, 'miller-carter', 'Catering Service', '44329 Hendrix Land\nPort Christine, AL 43242', 'port lisamouth', '+1-868-016-4774')
# (23, 'johnson ltd', 'Supermarket', '32366 Kathy Fall\nRodriguezton, NH 27984', 'bradleyborough', '+1-091-396-4499')
# (24, 'black collins and richard', 'Supermarket', '643 Galvan Burgs\nFletcherhaven, AZ 86988', 'hestermouth', '+1-096-640-8185')
# (25, 'gutierrez-palmer', 'Grocery Store', '019 Avila Station\nLake Dennisborough, AZ 84988', 'anitashire', '+1-927-832-2085')
# (26, 'hansen inc', 'Grocery Store', '9402 Corey Avenue\nJamesland, AL 54220', 'west adammouth', '+1-464-311-2342')
# (27, 'lester inc', 'Supermarket', '3187 Brittany Overpass Suite 160\nLake Elizabeth, CO 63236', 'new natasha', '+1-315-899-7076')
# (28, 'wright ltd', 'Restaurant', '69921 Sullivan Manor Apt. 996\nRussellport, ME 99724', 'jessestad', '+1-850-175-4730')
# (29, 'andrews-wiley', 'Grocery Store', '37741 Edward Green Apt. 840\nWhiteport, WY 68558', 'patrickmouth', '+1-460-130-8444')
# (30, 'rodriguez plc', 'Catering Service', '88798 Dustin Lane Suite 892\nPort Jessicaville, KY 16461', 'west pamelaborough', '+1-080-491-8858')
# (31, 'thompson-kerr', 'Grocery Store', '123 Barber Divide\nNew Stephanie, KY 35738', 'south kellyberg', '+1-786-641-7043')
# (32, 'lawrence plc', 'Catering Service', '35759 Baker Center\nEast Allisonville, WA 47206', 'jameschester', '+1-401-127-4461')
# (33, 'miranda wilcox and short', 'Restaurant', '208 Williams Fields Suite 324\nNew Robert, MN 13700', 'janetborough', '+1-711-136-4426')
# (34, 'cooper smith and king', 'Grocery Store', '439 Barnes Courts Apt. 349\nSouth Gregory, MO 73315', 'north garybury', '+1-307-046-1726')
# (35, 'nguyen-parsons', 'Grocery Store', '23683 Paul Groves Suite 174\nVegaville, IA 58578', 'andersonmouth', '+1-638-668-6852')
# (36, 'powell inc', 'Restaurant', '7278 Jesse Fall\nMitchellfort, SD 79576', 'cindyshire', '+1-668-319-5716')
# (37, 'phelps-schmidt', 'Catering Service', '689 Riley Villages\nSouth Jose, LA 55827', 'new amanda', '+1-048-886-1039')
# (38, 'lawrence llc', 'Supermarket', 'USNS Decker\nFPO AE 46703', 'perkinsbury', '+1-580-888-5964')
# (39, 'fernandez-bridges', 'Supermarket', '77717 Amanda Plains Apt. 231\nDanielberg, CA 13392', 'brittanyville', '+1-175-027-7076')
# (40, 'robinson plc', 'Restaurant', '59437 Schneider Villages Suite 050\nSouth Derek, NM 07539', 'jennifertown', '+1-925-882-9055')
# (41, 'kelly-ware', 'Catering Service', '482 Bush Island\nWrightburgh, MI 64397', 'bentleyburgh', '+1-969-744-5782')
# (42, 'austin-yu', 'Grocery Store', '482 Lisa Viaduct\nShirleyberg, IL 95427', 'east nicholasbury', '+1-806-669-4428')
# (43, 'martinez johnson and torres', 'Supermarket', '66956 Carter Lakes Apt. 029\nNew Matthewview, OK 90573', 'south karen', '+1-250-919-8579')
# (44, 'torres-perez', 'Supermarket', '9114 Becky Junctions\nHillhaven, WV 14750', 'jamesville', '+1-004-780-3197')
# (45, 'butler kennedy and cowan', 'Catering Service', 'Unit 7100 Box 9890\nDPO AP 52163', 'east deniseborough', '+1-367-607-2290')
# (46, 'fisher hernandez and webster', 'Grocery Store', '8490 Valdez Ports Suite 007\nPort Jeremy, NV 85800', 'south lisaberg', '+1-183-979-9626')
# (47, 'wong-reese', 'Supermarket', '9078 Jeffrey Drive Suite 439\nLake Jasonberg, RI 48655', 'east andrewland', '+1-483-625-4097')
# (48, 'conway-barr', 'Restaurant', '597 Contreras Roads\nSouth Hannah, RI 04553', 'timothyview', '+1-339-516-2911')
# (49, 'miller braun and graham', 'Supermarket', 'USS Roberts\nFPO AE 04254', 'lake traceyburgh', '+1-015-818-1702')
# (50, 'perez-williams', 'Catering Service', '956 Joseph Ford Apt. 098\nMoorestad, LA 74730', 'west danielborough', '+1-021-919-1055')
# (51, 'shaw inc', 'Restaurant', '163 Kenneth Lake\nGentrystad, IN 23606', 'rebeccabury', '+1-705-901-1779')
# (52, 'buck-carey', 'Supermarket', '3155 Strickland Lakes\nNelsonview, MN 90401', 'port dianaberg', '+1-836-195-8525')
# (53, 'wolfe and sons', 'Supermarket', '5146 Robbins Spring\nDanielshire, NY 94988', 'lake allen', '+1-914-372-3273')
# (54, 'bennett phillips and green', 'Supermarket', 'Unit 0882 Box 8764\nDPO AE 00627', 'lake rachael', '+1-580-038-2854')
# (55, 'wilson-brown', 'Grocery Store', '220 Rachel Trace\nPort Mark, AK 17083', 'danachester', '+1-636-196-2386')
# (56, 'morris ltd', 'Catering Service', '03207 Paul Shoals\nThomasshire, AR 89205', 'michaelview', '+1-751-253-1515')
# (57, 'cook group', 'Grocery Store', '6432 Guzman Estates\nLake Rebeccaborough, CA 35184', 'port robin', '+1-983-295-7995')
# (58, 'martin tyler and wilkerson', 'Grocery Store', '334 Bishop Fort Suite 958\nPort Jorge, NM 10652', 'north kevinhaven', '+1-959-331-7852')
# (59, 'warner white and morris', 'Grocery Store', '92097 Simmons Cape\nArthurchester, AL 44273', 'marissaville', '+1-947-280-2490')
# (60, 'parker-campbell', 'Restaurant', 'USNS Williams\nFPO AE 15960', 'wilsonport', '+1-958-882-9497')
# (61, 'arnold russo and foster', 'Supermarket', 'PSC 8521, Box 0417\nAPO AP 22766', 'lake joelshire', '+1-649-426-4690')
# (62, 'mitchell campbell and jones', 'Grocery Store', '760 Hall Dam\nJenniferstad, MI 28752', 'marymouth', '+1-024-156-0512')
# (63, 'fuller vincent and fernandez', 'Supermarket', 'Unit 8327 Box 2560\nDPO AP 34781', 'mcclainfurt', '+1-268-645-8829')
# (64, 'mullen llc', 'Supermarket', '373 Moody Manor\nJohnfurt, CT 63966', 'south michaelhaven', '+1-811-584-0300')
# (65, 'fletcher inc', 'Grocery Store', '5294 William Underpass\nNorth Angelaborough, TN 26906', 'lake raymondton', '+1-445-003-6513')
# (66, 'lambert-wilson', 'Restaurant', '2162 Johnson Field\nEast Caroline, AZ 13953', 'lake michaelfurt', '+1-690-151-2083')
# (67, 'shannon ltd', 'Restaurant', '8692 Adam Passage\nDavidland, WI 15372', 'kentland', '+1-412-366-8513')
# (68, 'sherman-wolfe', 'Supermarket', '0312 Garcia Ferry\nPort Deannaberg, DC 72769', 'north elizabeth', '+1-628-168-1740')
# (69, 'williams plc', 'Grocery Store', 'Unit 6990 Box 6326\nDPO AA 08563', 'cummingstown', '+1-842-107-7233')
# (70, 'cook stanley and wallace', 'Supermarket', '1492 Thomas Route\nEast Hannah, HI 37830', 'lake kyle', '+1-416-322-9367')
# (71, 'jones-edwards', 'Restaurant', '861 Martinez Junctions\nSmithburgh, WA 68091', 'ruizmouth', '+1-077-105-8283')
# (72, 'ward shepherd and krause', 'Catering Service', '224 Burns Camp\nChristopherborough, VA 76601', 'jasonstad', '+1-454-823-5622')
# (73, 'walker-richards', 'Grocery Store', '082 Nancy Summit Apt. 187\nHurleychester, PA 09363', 'west benjamin', '+1-862-704-7597')
# (74, 'johnston ltd', 'Catering Service', '58406 Pamela Mission\nLeestad, OH 88592', 'belindaville', '+1-563-075-3213')
# (75, 'douglas plc', 'Supermarket', '130 Lowe Cove Suite 161\nSouth John, LA 62264', 'rodneystad', '+1-765-070-1698')
# (76, 'clark-estes', 'Restaurant', '1854 Michael Locks Suite 076\nShaneland, AZ 73210', 'port amandamouth', '+1-201-261-9146')
# (77, 'golden-phillips', 'Catering Service', '25069 Ramirez Springs Suite 233\nWest Jamestown, IL 50100', 'new rhonda', '+1-113-900-7657')
# (78, 'frazier llc', 'Restaurant', '115 Danielle Oval Apt. 679\nPort Jessica, AZ 21218', 'north susan', '+1-588-327-0069')
# (79, 'holmes inc', 'Restaurant', 'USS Le\nFPO AP 30394', 'west danieltown', '+1-742-399-9900')
# (80, 'miller-moore', 'Grocery Store', '1920 Jody Burg\nDanaview, NY 16941', 'lake dennischester', '+1-347-177-6277')
# (81, 'harris ltd', 'Grocery Store', '70117 Danielle Plaza\nBartonview, NV 38788', 'north michelle', '+1-499-473-8541')
# (82, 'carey-richardson', 'Supermarket', '352 Moore Greens Suite 745\nDeborahtown, NV 83580', 'west lauraborough', '+1-607-559-2529')
# (83, 'owens-williams', 'Grocery Store', 'USCGC Farrell\nFPO AA 90914', 'west julianburgh', '+1-090-048-7482')
# (84, 'atkins group', 'Restaurant', '2205 Sharp Junction Suite 771\nDrakefurt, KY 14437', 'marthaside', '+1-969-856-3710')
# (85, 'larson ltd', 'Catering Service', '335 Roberts Neck Apt. 867\nSamanthaborough, RI 60340', 'christopherstad', '+1-105-128-9954')
# (86, 'murphy-boyd', 'Catering Service', '7105 James Overpass\nWilsonberg, NC 47111', 'new michelle', '+1-962-739-9435')
# (87, 'young townsend and mccarthy', 'Grocery Store', '4577 Shannon Tunnel Suite 786\nJamesview, CT 96322', 'west adam', '+1-792-810-1913')
# (88, 'oliver williams and rich', 'Restaurant', '2297 Dunlap Plains\nSouth Shannon, MT 97282', 'salastown', '+1-559-684-4064')
# (89, 'stewart-page', 'Restaurant', '8433 Villegas Tunnel Suite 183\nLake Sarahview, UT 79121', 'new richard', '+1-752-744-0258')
# (90, 'miller group', 'Supermarket', '8851 Powell Cliffs Apt. 635\nSouth Michael, MO 83778', 'lake kristentown', '+1-600-983-7361')
# (91, 'rivera llc', 'Supermarket', '4769 Mark Curve\nSparksstad, OR 98308', 'north ronaldburgh', '+1-838-612-9912')
# (92, 'cruz-day', 'Catering Service', '98104 Goodman Extension\nSmithport, PA 37878', 'east melissa', '+1-266-982-5975')
# (93, 'davis vaughan and shepherd', 'Supermarket', '89992 Quinn Plain Apt. 912\nNorth Laura, IN 05742', 'new daniel', '+1-512-023-6618')
# (94, 'cuevas smith and rowe', 'Grocery Store', '7503 Mclaughlin Crescent Suite 498\nDavismouth, DE 08450', 'brennanstad', '+1-286-671-0956')
# (95, 'orr inc', 'Supermarket', '5940 Klein Junctions\nJenniferborough, PA 44116', 'christinaland', '+1-415-991-8966')
# (96, 'pierce walsh and rogers', 'Grocery Store', '8840 Edwards Square Suite 343\nKimside, NE 41307', 'deborahland', '+1-024-525-1529')
# (97, 'king-snyder', 'Supermarket', '615 Barnett Circles\nJamesfort, CT 76455', 'reyesshire', '+1-705-201-7816')
# (98, 'hogan-johnston', 'Supermarket', '00006 Amy Wall Apt. 134\nZimmermanborough, PA 57869', 'gardnerfort', '+1-184-472-6932')
# (99, 'walsh-day', 'Supermarket', '815 Mary Via\nAllenborough, LA 80578', 'south louis', '+1-385-387-5081')
# (100, 'greene-garcia', 'Catering Service', 'USS Smith\nFPO AE 39123', 'mooreview', '+1-155-846-6299')
# (101, 'chambers-waters', 'Restaurant', '56762 Kimberly Light Suite 474\nMatthewmouth, UT 45275', 'east angelafort', '+1-234-483-8934')
# (102, 'hester bowers and carpenter', 'Grocery Store', '913 Jennifer Mountain Suite 645\nBurnsborough, VT 02798', 'west samantha', '+1-911-550-0712')
# (103, 'russell-summers', 'Catering Service', '84247 Emily Fords Apt. 478\nNorth Michael, RI 76457', 'port michaelshire', '+1-239-360-8469')
# (104, 'jackson llc', 'Catering Service', '254 Brandon Lodge\nMichaelton, NE 66307', 'lake theresa', '+1-488-905-7389')
# (105, 'carr-schaefer', 'Restaurant', '67643 Matthews Club\nEast Jennifer, ID 54291', 'davidchester', '+1-951-399-6201')
# (106, 'moreno group', 'Catering Service', '6631 Guerra Ramp Apt. 479\nValeriefort, SC 39501', 'lopezmouth', '+1-153-291-3530')
# (107, 'pollard tyler and davis', 'Restaurant', '120 Johnson Mountains\nNew Daniel, WI 58864', 'west lauraborough', '+1-759-976-6878')
# (108, 'williams-cox', 'Supermarket', '400 Ross Radial\nFrancomouth, MT 80264', 'east austin', '+1-082-114-2329')
# (109, 'powell norton and james', 'Catering Service', '0621 Nixon Ridge\nNew Ryanton, WV 87834', 'north carmen', '+1-607-662-2957')
# (110, 'figueroa-soto', 'Grocery Store', '113 Donna Pass\nPort Michaelchester, NE 39187', 'south kellyville', '+1-599-442-0494')
# (111, 'ball-church', 'Supermarket', '096 Robin Walks Suite 454\nFoxburgh, NC 51501', 'south davidside', '+1-352-764-4709')
# (112, 'webb graves and harrison', 'Restaurant', '3538 Fields Vista Suite 058\nWest Sonya, IN 53745', 'east courtneymouth', '+1-491-343-4359')
# (113, 'anderson nicholson and bruce', 'Catering Service', '8546 James Fields Apt. 534\nHallborough, AL 55990', 'east elizabethberg', '+1-200-033-1795')
# (114, 'barnett-graves', 'Restaurant', '748 Reilly Mission Apt. 036\nAguilarfurt, NM 08053', 'lake katherinechester', '+1-279-923-1761')
# (115, 'wells-davis', 'Grocery Store', '16029 Lisa Junctions\nPort Mary, AZ 64519', 'floresville', '+1-106-198-9960')
# (116, 'mcdaniel-morales', 'Grocery Store', '683 Damon Groves\nPort Michael, NE 84293', 'moseshaven', '+1-702-836-3122')
# (117, 'morales wood and cox', 'Restaurant', '046 Madeline Plain Apt. 669\nSmithbury, MS 53261', 'amberton', '+1-507-217-2227')
# (118, 'evans-harrison', 'Supermarket', '2430 Michael Branch\nLake Brian, CA 67262', 'lake joseph', '+1-271-896-5581')
# (119, 'yates-mills', 'Restaurant', 'PSC 9917, Box 2733\nAPO AE 68445', 'port kathleen', '+1-954-085-0479')
# (120, 'burns-davis', 'Restaurant', '100 Jill Trail Suite 664\nDanielmouth, TX 62651', 'new lisa', '+1-424-826-4065')
# (121, 'glover inc', 'Grocery Store', '75912 Brett Parks\nWest Lawrenceburgh, TN 53383', 'south kelly', '+1-959-642-0301')
# (122, 'mosley-hernandez', 'Catering Service', '02866 John Causeway\nMarkberg, RI 91177', 'tyronebury', '+1-159-244-3576')
# (123, 'stephens-stephens', 'Grocery Store', '794 Horne Track Apt. 542\nEast Mariaport, AK 95122', 'east meganfort', '+1-818-809-8124')
# (124, 'allen zimmerman and harrington', 'Supermarket', 'PSC 7915, Box 6921\nAPO AE 81937', 'lake shelby', '+1-611-148-6947')
# (125, 'brown-grimes', 'Supermarket', '71570 Jason Spurs Apt. 697\nMelissaton, ID 56125', 'lake april', '+1-290-285-3479')
# (126, 'jackson gonzalez and smith', 'Supermarket', '99197 Jensen Inlet\nJuliaside, AK 27283', 'new rodneyville', '+1-520-264-4365')
# (127, 'vasquez llc', 'Restaurant', '70060 Chelsea Trace Suite 180\nLopezburgh, AR 16869', 'jasonland', '+1-731-947-3123')
# (128, 'martinez-downs', 'Catering Service', '38440 Jonathan Pine Suite 612\nMillshaven, CO 77071', 'port mariefort', '+1-853-103-7942')
# (129, 'hicks ltd', 'Restaurant', '4349 Michael Fort\nSouth Melissa, ND 26423', 'port emily', '+1-799-814-9819')
# (130, 'nelson-tran', 'Catering Service', 'Unit 6111 Box 7557\nDPO AA 52174', 'new daniel', '+1-167-627-3706')
# (131, 'spencer martin and romero', 'Restaurant', '42751 Jose Junction Suite 390\nNew Johnnyberg, MS 26952', 'scottton', '+1-947-494-5469')
# (132, 'walker-knox', 'Catering Service', '353 Donald Tunnel Apt. 330\nFisherview, IA 09906', 'huntermouth', '+1-557-790-5551')
# (133, 'baker llc', 'Catering Service', '881 Thomas Valleys Apt. 842\nSouth Danielleland, OR 09264', 'south michaelberg', '+1-423-570-5106')
# (134, 'cook ltd', 'Supermarket', '15130 Parker Hill\nAdkinsville, MN 48860', 'west melissa', '+1-597-188-4581')
# (135, 'dyer group', 'Catering Service', '601 Kent Mills Apt. 098\nNew Robertstad, NY 73393', 'east candace', '+1-906-900-1026')
# (136, 'gordon davis and gonzalez', 'Grocery Store', '48332 Richard Radial\nSouth Christinafurt, MS 38651', 'lamberttown', '+1-177-006-7763')
# (137, 'pena and sons', 'Supermarket', '48061 Thomas Mission\nStephensmouth, NC 22128', 'east alexisberg', '+1-351-759-9512')
# (138, 'jones rojas and brown', 'Grocery Store', '3671 Hansen Loaf\nPort Nicholas, VT 97420', 'north sherrimouth', '+1-934-900-3679')
# (139, 'johnson-ray', 'Supermarket', '3639 Jones Brooks\nSouth Matthew, VA 33223', 'port connie', '+1-927-978-3473')
# (140, 'zhang llc', 'Restaurant', '6343 Sanders Park Suite 844\nPort Brendaton, FL 49650', 'watsonstad', '+1-798-869-4358')
# (141, 'rodriguez plc', 'Grocery Store', '03072 Stephen Terrace Suite 003\nLake Brandon, TX 93484', 'port manuel', '+1-962-943-3726')
# (142, 'myers kelley and riley', 'Catering Service', '374 Murray Run\nPort Sarahview, CA 10295', 'mitchellmouth', '+1-655-943-9580')
# (143, 'luna padilla and torres', 'Grocery Store', '7550 Kevin Inlet Suite 004\nRoweton, CT 19578', 'samuelville', '+1-736-312-6794')
# (144, 'johnson harris and white', 'Catering Service', 'PSC 5814, Box 9023\nAPO AA 76560', 'bellport', '+1-703-464-6698')
# (145, 'rice-woods', 'Grocery Store', '802 Young Ramp Suite 344\nPort Amy, HI 07296', 'kayleefort', '+1-785-370-4622')
# (146, 'hampton-lee', 'Supermarket', '994 Maxwell Squares Apt. 136\nBrowninghaven, IA 33077', 'jonathanhaven', '+1-119-262-3961')
# (147, 'nguyen-shaffer', 'Catering Service', '538 Charles Unions\nPort Jessica, MD 31072', 'west trevorview', '+1-040-258-9118')
# (148, 'perry cabrera and owens', 'Grocery Store', '97775 Rice Forks\nJohnsontown, RI 35006', 'annahaven', '+1-100-401-8014')
# (149, 'lee llc', 'Grocery Store', '0886 Smith Glen\nDuncanmouth, AL 18583', 'north amber', '+1-908-061-7359')
# (150, 'powers clark and snyder', 'Grocery Store', '8675 Reed Crest Suite 904\nWest Wendyborough, ID 45874', 'north jamesberg', '+1-152-200-2539')
# (151, 'butler-newman', 'Restaurant', '531 Christine Plains Apt. 814\nNew Randall, GA 19091', 'anthonyshire', '+1-258-620-8585')
# (152, 'rogers-shaw', 'Catering Service', '39253 David Common\nWest Tyler, NC 21196', 'south jacobport', '+1-055-977-0080')
# (153, 'wu llc', 'Restaurant', '439 Oscar Mountains Suite 426\nLake Markmouth, MI 84788', 'hawkinsmouth', '+1-191-513-9454')
# (154, 'smith-turner', 'Supermarket', '574 Jamie Mountains Apt. 480\nNorth Timothy, CA 92067', 'new john', '+1-709-070-6311')
# (155, 'bennett-parker', 'Supermarket', '17497 Michelle Path\nNew Mariamouth, UT 32031', 'charlesview', '+1-773-966-1784')
# (156, 'johnson-thompson', 'Catering Service', '920 Todd Points Apt. 224\nElliottstad, ID 85406', 'west carolyn', '+1-239-163-9415')
# (157, 'rodriguez walker and singleton', 'Restaurant', '3006 Fernandez Ferry\nJamesview, KS 30878', 'bairdfort', '+1-998-166-5324')
# (158, 'shepherd group', 'Catering Service', '922 Nicole Neck\nLake Danaton, ID 65819', 'north crystal', '+1-796-831-6588')
# (159, 'wagner cole and thompson', 'Grocery Store', '201 Hopkins Lakes\nJohnberg, ND 15611', 'north brooke', '+1-595-628-8290')
# (160, 'baker warren and kirk', 'Supermarket', 'PSC 7617, Box 0188\nAPO AP 36602', 'port loganberg', '+1-776-746-1515')
# (161, 'campbell llc', 'Supermarket', '8423 Karen Trace Apt. 648\nJohnland, IA 21810', 'perezport', '+1-633-157-4760')
# (162, 'moore perez and young', 'Restaurant', '48313 Taylor Junctions Apt. 845\nPetersborough, VT 51814', 'penabury', '+1-053-372-9178')
# (163, 'jackson-bishop', 'Restaurant', '1596 Romero Ports\nLake Jennifermouth, ME 52335', 'annetteburgh', '+1-584-660-8591')
# (164, 'yu-rodriguez', 'Grocery Store', '144 Armstrong Viaduct Apt. 561\nEast Ericchester, UT 19438', 'sylviabury', '+1-017-590-2372')
# (165, 'silva group', 'Grocery Store', '1541 Tara Forge\nMathisshire, DE 61123', 'copelandchester', '+1-005-724-8175')
# (166, 'king smith and mullen', 'Grocery Store', '9022 Harrington Path\nSusanport, SD 73387', 'lake donaldmouth', '+1-369-598-5778')
# (167, 'thompson-turner', 'Catering Service', '995 Campbell Mount Suite 129\nGraytown, MN 23216', 'davidport', '+1-897-925-4252')
# (168, 'miller williams and lewis', 'Catering Service', '69419 Michele Trail Apt. 911\nValdezville, NY 53308', 'wardton', '+1-358-798-7950')
# (169, 'hines-green', 'Grocery Store', '121 Monica Loaf\nCharlesshire, MO 59196', 'lindseyland', '+1-626-598-6842')
# (170, 'peters chase and davis', 'Catering Service', '015 Steven Crossing Suite 882\nLake Brendaborough, WV 97596', 'north brentbury', '+1-008-888-9184')
# (171, 'jones delgado and marquez', 'Catering Service', '67180 Christopher Parks Suite 702\nWhitestad, MI 84109', 'williammouth', '+1-186-605-0066')
# (172, 'parker macdonald and espinoza', 'Grocery Store', '708 Jones Estates Suite 598\nLake Samuel, RI 75975', 'garciaside', '+1-066-730-6648')
# (173, 'greene group', 'Supermarket', '645 Acosta Circle Suite 351\nStaceyburgh, TN 64114', 'myerschester', '+1-231-565-5057')
# (174, 'gillespie foster and boyd', 'Grocery Store', 'Unit 1730 Box 5566\nDPO AA 26190', 'north carolfurt', '+1-020-221-7258')
# (175, 'olson ltd', 'Catering Service', '45318 Delgado Junctions Apt. 756\nJamesburgh, IA 92476', 'katherinefurt', '+1-446-162-1060')
# (176, 'allen-mccullough', 'Restaurant', '3715 White Gardens Apt. 568\nSouth Sarah, AK 76176', 'east john', '+1-892-199-4982')
# (177, 'turner-ramirez', 'Supermarket', '53362 Woods Viaduct Apt. 059\nRonaldview, SC 94816', 'south nicholasville', '+1-679-699-5497')
# (178, 'mcbride-rogers', 'Catering Service', '4742 Fischer Club Apt. 161\nWest Carrieview, WA 33065', 'scottchester', '+1-572-650-1138')
# (179, 'lucas bush and miller', 'Supermarket', '4664 Debra Row Apt. 580\nLake Stephen, TX 87375', 'north michelle', '+1-333-477-4489')
# (180, 'deleon guzman and porter', 'Grocery Store', '94721 Schultz Neck Apt. 864\nSouth Evanland, WI 88166', 'south jeffrey', '+1-342-496-7540')
# (181, 'black montgomery and hernandez', 'Restaurant', '118 Karen Fields\nWest Angelaport, GA 22035', 'taylormouth', '+1-668-011-0211')
# (182, 'wilson-ortiz', 'Grocery Store', 'Unit 2603 Box 7875\nDPO AP 30589', 'port jeffrey', '+1-345-889-2010')
# (183, 'elliott-stephens', 'Grocery Store', '240 Brian Circle Apt. 335\nMorrowfurt, KS 49845', 'south anne', '+1-071-361-1991')
# (184, 'norris-townsend', 'Grocery Store', '1117 Doyle Locks\nWest Aaron, MO 08423', 'velazquezview', '+1-119-965-9800')
# (185, 'horn johnson and moore', 'Restaurant', '886 Tammy Mills\nStevensshire, VA 03285', 'shirleyland', '+1-329-694-7891')
# (186, 'garner plc', 'Grocery Store', '90840 Edgar Light Suite 091\nLake Caseyberg, IA 64520', 'evansmouth', '+1-112-902-8389')
# (187, 'collins williams and fernandez', 'Catering Service', '947 Sara Heights\nNorth Brandi, CO 23438', 'port robert', '+1-294-358-2246')
# (188, 'brown ltd', 'Catering Service', '3165 Luis Heights\nPort Brandonview, OK 04929', 'courtneychester', '+1-977-617-4564')
# (189, 'blackwell ltd', 'Supermarket', '829 Allen Bridge\nWest Karenburgh, ND 61533', 'brianside', '+1-057-144-4583')
# (190, 'elliott-mcguire', 'Grocery Store', '447 Haynes Causeway Suite 347\nSmithburgh, WA 40545', 'barkerborough', '+1-409-311-5468')
# (191, 'grant-davis', 'Grocery Store', '6946 Shaffer Viaduct Apt. 909\nLisabury, LA 90232', 'lake jessicamouth', '+1-949-762-1738')
# (192, 'hunter ballard and caldwell', 'Catering Service', '60550 Fleming Branch Suite 560\nJessicashire, UT 62403', 'leslieville', '+1-922-116-9925')
# (193, 'chung morris and craig', 'Restaurant', '310 Steven Overpass Apt. 402\nPaulside, NM 92478', 'north lisaland', '+1-892-013-6674')
# (194, 'lambert-gonzalez', 'Restaurant', '77389 Flores Fort\nScottchester, ME 77945', 'lake josephton', '+1-549-757-0704')
# (195, 'williams-strong', 'Supermarket', '712 Johnson Squares\nJohnburgh, IN 34833', 'justinhaven', '+1-935-536-1144')
# (196, 'owens-taylor', 'Restaurant', '553 Emily Mountains Suite 339\nEast Mary, MI 74272', 'bartonborough', '+1-699-906-1607')
# (197, 'dodson and sons', 'Restaurant', '390 Ramirez Port\nPort Julieton, LA 28323', 'new david', '+1-655-612-2732')
# (198, 'bowman llc', 'Restaurant', '70033 Katie Walk\nSouth Joshuaport, NY 57110', 'port karen', '+1-877-421-8852')
# (199, 'clark evans and navarro', 'Catering Service', '1567 Rice Route\nMcbrideton, SD 00586', 'christinamouth', '+1-408-763-3914')
# (200, 'turner-woods', 'Supermarket', '413 Abigail Park Suite 737\nNorth Heather, VA 59882', 'bradleyport', '+1-276-905-7873')
# (201, 'ramirez llc', 'Catering Service', '1488 Cook Ports\nSouth Lindsay, WI 06937', 'sandrastad', '+1-437-452-1821')
# (202, 'graham-peters', 'Supermarket', '72444 Dennis Centers Apt. 058\nEast Sarahton, NM 90794', 'vazquezshire', '+1-817-193-8393')
# (203, 'bass-sellers', 'Grocery Store', '807 Brewer Highway Suite 080\nChristophermouth, MO 25526', 'port christina', '+1-990-604-7456')
# (204, 'lyons inc', 'Supermarket', '0820 Christopher Dale\nAngelamouth, GA 29905', 'lake lauraton', '+1-595-462-8745')
# (205, 'thompson group', 'Grocery Store', '81499 Baker Valley Suite 876\nWheelerview, CT 20385', 'carlbury', '+1-563-752-6624')
# (206, 'yoder-murray', 'Catering Service', 'Unit 6112 Box 2655\nDPO AP 68074', 'port emilyburgh', '+1-304-216-5945')
# (207, 'walters jackson and webster', 'Grocery Store', '88321 William Glens Apt. 368\nNew Anthony, IN 56413', 'north ronaldmouth', '+1-482-753-6693')
# (208, 'miller johnson and fernandez', 'Restaurant', '228 Kathryn Mountains Suite 986\nCortezmouth, IA 90538', 'east garyton', '+1-900-081-8718')
# (209, 'hubbard clark and hicks', 'Catering Service', '77599 Ruiz Stream\nSouth Brianburgh, DC 12695', 'south cassandra', '+1-272-502-0028')
# (210, 'jones-miller', 'Grocery Store', '8892 Patrick Shoals\nTristanfort, OH 00576', 'paulmouth', '+1-455-164-3547')
# (211, 'anderson patrick and scott', 'Restaurant', '03198 Washington Ferry Suite 086\nSouth Amberside, GA 92116', 'lake james', '+1-886-931-4697')
# (212, 'dennis parker and sanchez', 'Supermarket', '456 Nelson Street\nEricside, NH 82097', 'port markview', '+1-065-587-3078')
# (213, 'anderson robinson and phillips', 'Grocery Store', '687 Bell Knoll Suite 015\nWest Bryan, OR 07413', 'andersonville', '+1-780-953-1647')
# (214, 'kelley plc', 'Catering Service', 'Unit 3990 Box 8289\nDPO AE 64562', 'jamesview', '+1-961-374-8773')
# (215, 'simmons ltd', 'Grocery Store', '6249 Michelle Islands Apt. 374\nWest Heather, VT 67074', 'new curtis', '+1-219-975-7084')
# (216, 'potter brown and torres', 'Supermarket', '54122 Wayne Ville Suite 760\nEast Kellyview, OH 61069', 'tylerburgh', '+1-991-136-5369')
# (217, 'williams ltd', 'Supermarket', '89168 Fisher Brooks Suite 220\nNorth Kevinville, TN 96538', 'mooremouth', '+1-417-492-1015')
# (218, 'aguilar and sons', 'Catering Service', '68882 Rebecca Islands\nEast Virginiamouth, SD 49728', 'lake chloeshire', '+1-793-316-0706')
# (219, 'rivera-nelson', 'Supermarket', '141 Ingram Ferry\nCarlsonport, SC 09759', 'east stephanie', '+1-588-545-4314')
# (220, 'robinson and sons', 'Supermarket', '95830 Watts Isle\nTraviston, WA 96014', 'west stephaniemouth', '+1-879-163-6908')
# (221, 'richardson group', 'Supermarket', '48378 Morris Pines Apt. 216\nPort Williamville, MD 62944', 'walterborough', '+1-924-099-7995')
# (222, 'tran douglas and harvey', 'Catering Service', '5607 Ernest Summit\nSouth Petertown, MS 89142', 'stephanieberg', '+1-114-687-4992')
# (223, 'hodges and sons', 'Restaurant', '7970 Robinson Field\nSalinaschester, CT 85213', 'longland', '+1-504-107-9130')
# (224, 'hughes-jackson', 'Restaurant', '66899 Johnson Crescent\nNew Gregoryland, CO 53101', 'east lindsayville', '+1-998-292-0906')
# (225, 'stevens-rogers', 'Grocery Store', '59277 Adam Station\nWest Justin, DE 07549', 'west kenneth', '+1-348-420-0729')
# (226, 'hart plc', 'Grocery Store', '47794 Mccoy Shores\nJacksonfort, OR 28670', 'south thomas', '+1-576-507-9307')
# (227, 'morse-hoffman', 'Grocery Store', '677 Jenna Village\nPort Rhonda, OK 56596', 'derekport', '+1-148-820-3017')
# (228, 'stewart-soto', 'Supermarket', '71892 Robinson Common\nHarrisfurt, DC 31479', 'andrewsmouth', '+1-400-224-5412')
# (229, 'thompson ltd', 'Restaurant', '213 Mitchell Port\nEast Craig, IA 36277', 'gonzalesport', '+1-582-643-7944')
# (230, 'phelps-robbins', 'Grocery Store', '00248 Hamilton Ferry Suite 310\nNew Larry, DE 83903', 'north melanie', '+1-564-855-6923')
# (231, 'jackson-robinson', 'Supermarket', '2416 Gray Route Apt. 246\nBoydland, AL 93137', 'north tom', '+1-341-741-8533')
# (232, 'snyder caldwell and campbell', 'Supermarket', '652 Williams Mount\nJonesstad, WI 51744', 'muellermouth', '+1-401-615-9495')
# (233, 'jones-wu', 'Restaurant', 'PSC 9721, Box 2253\nAPO AA 34031', 'south morganfurt', '+1-951-023-9344')
# (234, 'sherman-baker', 'Catering Service', '07362 Kimberly Village Suite 643\nAndersonton, VA 24172', 'new joel', '+1-301-017-1427')
# (235, 'gutierrez llc', 'Catering Service', '310 Myers Neck\nRichardtown, WA 29671', 'gutierrezshire', '+1-924-884-1926')
# (236, 'singleton andrews and bell', 'Grocery Store', '431 John Coves\nMariaside, WA 13977', 'jeffreyburgh', '+1-773-180-8829')
# (237, 'white crawford and pearson', 'Supermarket', '4785 Felicia Circle Suite 239\nNorth Melissa, KY 96802', 'frederickside', '+1-167-653-7393')
# (238, 'decker group', 'Grocery Store', '4464 Charles Creek\nSanchezborough, GA 09107', 'north julieburgh', '+1-185-664-8137')
# (239, 'simpson thomas and smith', 'Grocery Store', '204 Charles Viaduct\nPerezfurt, WV 57676', 'south bradleyburgh', '+1-117-114-7043')
# (240, 'marshall ltd', 'Catering Service', '30050 Christine Square Apt. 097\nKingfort, KS 26841', 'andreaborough', '+1-903-575-3136')
# (241, 'harper blake and alexander', 'Catering Service', '882 Smith Heights\nEast Cherylborough, DC 06299', 'devinmouth', '+1-144-381-3923')
# (242, 'aguilar-frederick', 'Restaurant', '6353 Chad Circles\nBrewerland, NM 53897', 'michaelport', '+1-057-752-7548')
# (243, 'davis-hurley', 'Catering Service', '687 Sparks Forks\nEast Patricia, NC 25546', 'west catherine', '+1-902-398-7614')
# (244, 'chan-elliott', 'Supermarket', '16644 Kelli Spur\nGregoryville, SC 80630', 'toddberg', '+1-239-334-6620')
# (245, 'williams and sons', 'Restaurant', '8921 Juan Ville\nNew Monicashire, MD 92426', 'lake heather', '+1-072-137-9870')
# (246, 'robinson group', 'Grocery Store', '212 Kelly Station Apt. 790\nNorth Amandafurt, MA 37113', 'east stephanieview', '+1-430-311-0414')
# (247, 'shepherd-yates', 'Catering Service', '973 Garner Mews\nPeggymouth, MO 33680', 'port aaron', '+1-819-125-7990')
# (248, 'oliver cross and gilbert', 'Restaurant', 'USS Mcintyre\nFPO AA 76857', 'south michellechester', '+1-144-871-9620')
# (249, 'davis sanchez and hernandez', 'Catering Service', '61204 Christopher Springs\nNorth Kathy, SD 81291', 'johnsonside', '+1-496-461-5610')
# (250, 'lewis-peters', 'Grocery Store', '965 Jesse Course Suite 126\nAnnabury, RI 51241', 'south jasmineville', '+1-246-512-8059')
# (251, 'carter-jones', 'Restaurant', '26720 Candace Inlet Suite 052\nHendersonton, MA 30678', 'east terrancemouth', '+1-892-412-5796')
# (252, 'blair llc', 'Grocery Store', '084 Alejandro Ports Apt. 820\nSarahton, LA 54906', 'phillipsfort', '+1-522-329-8866')
# (253, 'gonzales-keith', 'Catering Service', '4934 Mitchell Lake\nSharonchester, NJ 09163', 'sharonton', '+1-491-714-9656')
# (254, 'huber group', 'Restaurant', '36361 Roger Trail Apt. 099\nAshleybury, MD 98039', 'reidland', '+1-948-011-4394')
# (255, 'chapman barrett and lopez', 'Supermarket', '1402 Kimberly Plaza Apt. 787\nKatherinetown, OK 71945', 'crystalborough', '+1-809-083-1158')
# (256, 'hayes ltd', 'Grocery Store', '581 Michael Fields Suite 491\nEast Meganburgh, TX 89090', 'north nicoleport', '+1-942-811-8158')
# (257, 'james group', 'Supermarket', '27163 Jennifer Roads\nWilliamsside, ID 07654', 'lake coryhaven', '+1-215-096-3215')
# (258, 'gonzales-moore', 'Restaurant', '326 Parker Crescent\nSouth Hailey, SD 72035', 'lake anthonyport', '+1-926-230-2026')
# (259, 'lewis pierce and wilson', 'Restaurant', '2950 Daniel Center Suite 368\nDanieltown, NJ 69910', 'north briannabury', '+1-507-712-6410')
# (260, 'rice-dawson', 'Grocery Store', '9152 John Roads Apt. 986\nCurtiston, ID 14419', 'new samuel', '+1-177-339-0321')
# (261, 'lopez davis and duncan', 'Grocery Store', '1779 Zachary Island Suite 743\nSantosmouth, IL 00898', 'south richardhaven', '+1-424-107-9020')
# (262, 'bradford-martinez', 'Supermarket', '366 Wheeler Fields\nHarringtonchester, WY 86540', 'new carol', '+1-199-451-0254')
# (263, 'lutz smith and martin', 'Grocery Store', '8964 Reed Valleys Suite 413\nDavidborough, MA 78474', 'chambersfort', '+1-647-023-6085')
# (264, 'holland and sons', 'Catering Service', '430 Tyler View Apt. 166\nSouth Katherine, TX 04269', 'new richard', '+1-012-586-9344')
# (265, 'simmons-mcdaniel', 'Catering Service', '237 Jason Trail\nEast Jacobborough, VT 07794', 'new douglas', '+1-175-617-1876')
# (266, 'thomas-carpenter', 'Grocery Store', '0891 Martin Shore Apt. 596\nMcdonaldstad, PA 01987', 'port ronaldshire', '+1-908-032-2164')
# (267, 'sherman-garza', 'Catering Service', '044 Johnson Brook\nVelazquezville, IA 66365', 'port kevinburgh', '+1-590-029-4117')
# (268, 'white hutchinson and williams', 'Grocery Store', '6135 Michael Extension Apt. 708\nBrendaborough, MN 18905', 'nolanmouth', '+1-056-478-8798')
# (269, 'jackson and sons', 'Restaurant', 'Unit 2891 Box 0702\nDPO AP 62264', 'east caseyfort', '+1-381-458-8455')
# (270, 'harrison-wilson', 'Catering Service', '904 Christopher Station\nLake Patriciaborough, AR 56947', 'cunninghambury', '+1-269-475-2515')
# (271, 'barrera jenkins and boyd', 'Restaurant', '0939 Meyer Wells\nLake Jeanne, PA 23420', 'new jeremyberg', '+1-684-221-3941')
# (272, 'holland parks and scott', 'Supermarket', '031 Sydney Freeway\nCynthiaton, PA 51451', 'lake christinaborough', '+1-583-922-7932')
# (273, 'hammond llc', 'Supermarket', '7396 Patrick Row\nEast Roy, UT 18983', 'new carol', '+1-324-482-4894')
# (274, 'shields-moore', 'Supermarket', '922 Bailey Overpass Suite 885\nNew William, VA 50509', 'new dawnborough', '+1-933-291-1651')
# (275, 'floyd jones and alvarado', 'Supermarket', '55399 Bullock Cove Apt. 326\nEast Latoya, KY 21621', 'brittanyport', '+1-707-000-2344')
# (276, 'hodge-leblanc', 'Supermarket', '2243 John Squares\nJohnburgh, TX 33271', 'port eric', '+1-369-248-1031')
# (277, 'ramos and sons', 'Catering Service', '6378 Kendra Greens\nEast Jacob, IN 59852', 'west aliciabury', '+1-591-869-0343')
# (278, 'edwards-ryan', 'Restaurant', '259 Valerie Pike Apt. 290\nCoffeychester, WV 02293', 'beasleyhaven', '+1-265-938-2103')
# (279, 'greene wood and hernandez', 'Restaurant', '69618 Jacob Stravenue\nSouth Jacobton, OH 42099', 'garciaport', '+1-238-551-4657')
# (280, 'peck george and klein', 'Supermarket', '481 Bowman Isle\nMichaelbury, CO 60876', 'coopermouth', '+1-748-249-2553')
# (281, 'davis inc', 'Grocery Store', '83459 Allen Causeway Suite 409\nOlsonborough, GA 85285', 'lake nicolebury', '+1-725-411-1981')
# (282, 'baker gardner and callahan', 'Supermarket', '18439 Amanda Field Apt. 333\nMccartymouth, MO 88867', 'port gregton', '+1-520-919-5240')
# (283, 'russell-graham', 'Supermarket', '7757 Roy Mountain\nPort Emily, KS 36318', 'andrewstad', '+1-191-210-2684')
# (284, 'cruz inc', 'Supermarket', '96242 Luis Mill\nSouth Jeffrey, PA 65606', 'north julieburgh', '+1-242-471-4335')
# (285, 'sanchez-fisher', 'Restaurant', '77514 Todd Creek Apt. 870\nEast Ashley, ND 47642', 'west corey', '+1-803-623-3098')
# (286, 'watson-west', 'Restaurant', '864 Martinez Valleys Apt. 859\nByrdland, OH 05345', 'williamschester', '+1-789-619-8079')
# (287, 'carr-wells', 'Catering Service', '202 Castillo Course Suite 667\nNew Joshua, OK 47311', 'jefferyside', '+1-179-013-9281')
# (288, 'carlson-mathis', 'Supermarket', '98491 Matthews Mall\nLake Juantown, NY 51580', 'maynardstad', '+1-257-318-9434')
# (289, 'jenkins-carpenter', 'Supermarket', '9447 Dixon Orchard\nPort Jacob, DE 27747', 'toddstad', '+1-144-812-2181')
# (290, 'webb phillips and garcia', 'Supermarket', '09931 Snyder Station Apt. 218\nRitterborough, IL 82418', 'bradleyport', '+1-401-943-3400')
# (291, 'bass-gay', 'Grocery Store', 'USCGC Perez\nFPO AP 05466', 'west margaretfort', '+1-064-805-9663')
# (292, 'lopez-duffy', 'Supermarket', 'PSC 0689, Box 6828\nAPO AP 21295', 'mooneybury', '+1-349-737-9978')
# (293, 'ibarra and sons', 'Catering Service', 'Unit 2034 Box 3584\nDPO AE 66830', 'joneshaven', '+1-385-305-0223')
# (294, 'fitzgerald group', 'Grocery Store', '3303 Smith Gardens Suite 639\nJonesberg, WY 23098', 'south kendra', '+1-630-381-7780')
# (295, 'patterson harris and kelly', 'Restaurant', '887 Martinez Spurs\nThorntonshire, WV 04210', 'meghanfurt', '+1-845-701-9148')
# (296, 'martin plc', 'Grocery Store', '3517 Dalton Pike Apt. 053\nMeghanside, MT 10430', 'port linda', '+1-728-834-7500')
# (297, 'butler-cook', 'Grocery Store', '561 Schmidt Estate\nRobertsonton, OK 26803', 'markberg', '+1-651-122-4812')
# (298, 'mills osborne and dickson', 'Restaurant', '05338 Karina Village\nBoyerfurt, TX 92321', 'new steven', '+1-180-045-1358')
# (299, 'riley plc', 'Supermarket', '4036 Scott Course Apt. 174\nNew Elizabeth, SD 35504', 'robertton', '+1-643-573-2130')
# (300, 'clarke-farley', 'Supermarket', '9050 Jacob Cape\nEast Donaldfurt, NY 58115', 'lake michaelview', '+1-723-262-1740')
# (301, 'smith glover and mcintyre', 'Supermarket', '183 Jessica Island Suite 755\nRebeccafurt, ID 61131', 'east laurashire', '+1-291-239-4085')
# (302, 'robertson plc', 'Grocery Store', '23699 Garcia Villages Suite 124\nSouth Williamhaven, MT 23890', 'south tammy', '+1-100-131-6521')
# (303, 'wright ltd', 'Catering Service', 'PSC 7619, Box 8525\nAPO AE 61072', 'tammystad', '+1-261-859-3237')
# (304, 'douglas-colon', 'Catering Service', '30465 Latoya Haven\nHartville, NC 48753', 'port marcland', '+1-439-020-2351')
# (305, 'wolfe garner and jones', 'Grocery Store', '88370 Harris Lock Apt. 882\nSouth Catherine, DE 56707', 'fullerborough', '+1-758-774-8038')
# (306, 'evans wright and mitchell', 'Catering Service', '73725 Anthony Way Apt. 971\nWest Pamela, OH 61366', 'north keith', '+1-726-568-9224')
# (307, 'gonzalez-parrish', 'Catering Service', '600 Sanchez Meadow\nJessicaview, KY 72375', 'heathborough', '+1-623-623-8847')
# (308, 'doyle llc', 'Catering Service', '8157 Tammy Road\nWest Stephenchester, NC 16381', 'brittanyside', '+1-031-215-4595')
# (309, 'bell davis and hickman', 'Catering Service', '4454 Jackson Plaza Apt. 447\nThomasburgh, CT 44776', 'ambertown', '+1-724-353-7063')
# (310, 'sullivan thornton and peterson', 'Grocery Store', '1679 John Court\nKatherineberg, ID 45885', 'saraburgh', '+1-688-116-5399')
# (311, 'fleming ltd', 'Grocery Store', '080 Powell Rapid\nSouth John, CO 90063', 'west amanda', '+1-653-368-3676')
# (312, 'garcia-hunter', 'Restaurant', '019 Amy Station\nSouth Daniel, MD 51890', 'north ianbury', '+1-150-729-4411')
# (313, 'maldonado-davis', 'Supermarket', '51547 Desiree Cape Suite 175\nPort Benjaminfurt, RI 95290', 'boylechester', '+1-953-826-1424')
# (314, 'wright-mcclure', 'Restaurant', '569 Laurie Lake\nLake Erikview, WY 06966', 'rodriguezfurt', '+1-943-609-2407')
# (315, 'nelson llc', 'Restaurant', '773 Frazier Ranch\nKellerbury, GA 32205', 'lake andrewmouth', '+1-939-113-4890')
# (316, 'johnson group', 'Supermarket', '0019 Gray Trafficway\nNorth Sara, NC 74122', 'williamsfort', '+1-443-653-4610')
# (317, 'parker jordan and thompson', 'Grocery Store', '536 Steven Isle\nBoyleborough, MA 13719', 'south brandiberg', '+1-367-658-3630')
# (318, 'briggs-stewart', 'Catering Service', '86658 Rachael Drive\nPort Jennifer, MO 54683', 'martinezfort', '+1-398-927-0621')
# (319, 'davila green and avila', 'Restaurant', '28646 Tiffany Meadow Apt. 469\nLyonshaven, IA 48088', 'lake amymouth', '+1-238-610-4312')
# (320, 'shah group', 'Supermarket', '1654 Singh Roads\nPaynehaven, RI 22772', 'lake jeffreytown', '+1-953-840-3880')
# (321, 'williams-boyle', 'Restaurant', '09025 Callahan Club\nRamosport, WY 36155', 'north edwinchester', '+1-235-324-6627')
# (322, 'mayo plc', 'Catering Service', '15094 Kennedy Highway Suite 900\nSouth Michael, MT 31746', 'mckinneymouth', '+1-646-258-2814')
# (323, 'peters-johnson', 'Restaurant', '6383 Gomez Islands\nSanchezport, IA 35229', 'jasmineberg', '+1-503-989-9566')
# (324, 'roberts group', 'Grocery Store', '160 Sheri Course\nMossfurt, MO 13285', 'east elizabeth', '+1-467-755-8957')
# (325, 'allen and sons', 'Supermarket', '17628 David Plain Suite 137\nPort Michaelton, AZ 66272', 'west tammy', '+1-552-546-9768')
# (326, 'bender jordan and bennett', 'Supermarket', '635 Herrera Trafficway\nHuynhside, CT 11395', 'lake alicia', '+1-975-998-3421')
# (327, 'miller conner and clark', 'Restaurant', '4464 Shaun Plain Suite 161\nSandraview, TN 76190', 'villaborough', '+1-524-197-5821')
# (328, 'walker brennan and townsend', 'Grocery Store', 'Unit 9379 Box 7124\nDPO AP 65325', 'port rubenville', '+1-194-900-2168')
# (329, 'davidson group', 'Restaurant', '1894 Harvey Pike Apt. 102\nDavisfort, NE 43626', 'port lauraville', '+1-729-788-7288')
# (330, 'holloway-koch', 'Restaurant', '2889 Jorge Fields\nSouth Thomasland, AR 38794', 'jamesport', '+1-323-974-7052')
# (331, 'edwards johnson and cross', 'Catering Service', '5969 Burke Ridges\nNorth Kevinborough, MT 75005', 'south jeffreyburgh', '+1-227-851-5888')
# (332, 'cox llc', 'Restaurant', '406 Lucero Mountain Apt. 736\nMollyport, RI 14316', 'west whitneymouth', '+1-140-206-8875')
# (333, 'herrera fritz and banks', 'Restaurant', 'USCGC Adams\nFPO AP 17515', 'port heidiland', '+1-698-599-5415')
# (334, 'cox-mcintyre', 'Grocery Store', '85337 King Junction Suite 272\nEast Nicoleshire, ID 63161', 'south jillshire', '+1-422-450-8076')
# (335, 'newman pearson and mccarthy', 'Grocery Store', '4719 Darryl Isle\nNew Rebecca, GA 13003', 'north gary', '+1-905-549-7068')
# (336, 'mckinney llc', 'Supermarket', '52072 Rhonda Flats\nLake Brandon, VA 43437', 'east sandra', '+1-059-663-6909')
# (337, 'hogan-oliver', 'Restaurant', '03856 Garcia Course Suite 618\nNew Patriciamouth, DC 05462', 'new ricky', '+1-892-559-0683')
# (338, 'ibarra llc', 'Catering Service', '064 Andrea Land Suite 946\nLake Melody, ME 49581', 'adambury', '+1-670-338-0260')
# (339, 'palmer and sons', 'Restaurant', '4079 Kathleen Tunnel\nLisastad, NE 35010', 'south thomas', '+1-218-970-3762')
# (340, 'barry powers and white', 'Grocery Store', '1145 Justin Light\nRichardside, CT 45760', 'murrayborough', '+1-023-817-1166')
# (341, 'jenkins-carrillo', 'Grocery Store', '656 Denise Spurs Suite 112\nJoshuaborough, NY 66307', 'lake ryanbury', '+1-332-678-1596')
# (342, 'smith inc', 'Catering Service', '00691 Joseph Parks\nMatthewville, CO 02023', 'matthewbury', '+1-340-986-4095')
# (343, 'harris perez and willis', 'Catering Service', '549 Moody Road Suite 873\nJacobshire, VT 80966', 'south christopherborough', '+1-581-281-6112')
# (344, 'mcmillan gallegos and perry', 'Catering Service', '4963 Decker Loop Apt. 710\nWest Karen, MO 17141', 'north nicholas', '+1-973-341-5155')
# (345, 'mitchell-watson', 'Catering Service', '2215 Jacob Valleys Suite 115\nGarcialand, SC 12573', 'north tracy', '+1-366-677-9015')
# (346, 'phillips wolfe and martin', 'Grocery Store', 'Unit 1376 Box 6294\nDPO AE 62072', 'thomasville', '+1-548-413-4962')
# (347, 'hood hoffman and wright', 'Supermarket', '783 Gonzales Valleys Apt. 115\nAlexandrialand, NH 52248', 'louismouth', '+1-739-063-1622')
# (348, 'may and sons', 'Restaurant', '76603 Heather View Apt. 463\nEast Maureenberg, MI 77494', 'west ashleytown', '+1-214-577-9133')
# (349, 'walker wong and norris', 'Supermarket', '6246 Smith Drives Suite 621\nJamesfurt, CO 01830', 'valenzuelaville', '+1-955-670-0410')
# (350, 'scott johnson and villa', 'Restaurant', '265 Williams Canyon Suite 869\nPort Joseph, AR 44255', 'port dustin', '+1-564-957-2650')
# (351, 'berry-mack', 'Grocery Store', '188 Tamara Crossroad\nLake Melissa, FL 63621', 'south stefanietown', '+1-769-872-1659')
# (352, 'strickland llc', 'Grocery Store', '2522 Marissa Brook Suite 849\nAndersonberg, IL 05110', 'lake kyle', '+1-872-958-7902')
# (353, 'rose-pearson', 'Grocery Store', '48119 Luna Villages\nCherylfurt, HI 56512', 'north aaron', '+1-009-718-9331')
# (354, 'rowe-arias', 'Catering Service', '8041 Joseph Shoal Suite 878\nNorth Robertfurt, KY 43667', 'south alicia', '+1-090-649-4737')
# (355, 'bowman llc', 'Restaurant', '64024 Hunter Plaza Apt. 997\nGrantstad, NM 06478', 'port patrick', '+1-263-278-6611')
# (356, 'espinoza plc', 'Supermarket', '410 White Heights\nNorth Todd, ID 25520', 'west michael', '+1-410-539-3296')
# (357, 'carey plc', 'Supermarket', '77230 Nicole Row Suite 887\nEast Joshua, KS 15916', 'donnaborough', '+1-038-060-0959')
# (358, 'cole-ochoa', 'Restaurant', '832 Richards Lakes Suite 950\nAdambury, MS 43653', 'south crystalberg', '+1-997-512-7129')
# (359, 'gonzalez tapia and stewart', 'Catering Service', 'USS Jacobson\nFPO AE 77920', 'north ashley', '+1-206-007-4668')
# (360, 'clay llc', 'Catering Service', '58290 Keith Hills\nWest Danielle, UT 38692', 'butlerview', '+1-346-521-6955')
# (361, 'fleming group', 'Supermarket', '491 Stafford Harbors Apt. 774\nReyesburgh, ID 82774', 'east lauren', '+1-218-201-2221')
# (362, 'snyder-gordon', 'Grocery Store', '952 Browning Port Apt. 921\nSarahhaven, UT 94085', 'anthonychester', '+1-134-622-9488')
# (363, 'henry-terry', 'Catering Service', '94883 Silva Plaza Apt. 966\nNorth Ericborough, WY 57244', 'east brittanyland', '+1-205-168-6653')
# (364, 'reid ltd', 'Grocery Store', '94855 Gardner Union Suite 670\nLake Diana, OK 96757', 'lake ethanview', '+1-880-332-3175')
# (365, 'bray nguyen and christensen', 'Restaurant', '27009 Sheri Forges\nHeidiview, AK 10251', 'west robert', '+1-135-215-7984')
# (366, 'harrell-hanson', 'Restaurant', '660 Anthony Canyon Suite 057\nArnoldchester, MA 72162', 'devinton', '+1-495-726-5323')
# (367, 'patel and sons', 'Grocery Store', '7364 Green Wall Suite 340\nFisherbury, VA 78253', 'deckermouth', '+1-829-645-4440')
# (368, 'smith-villegas', 'Grocery Store', '5916 Craig Courts\nNew Kevinfurt, MS 57479', 'north lindseychester', '+1-467-901-7553')
# (369, 'weeks wood and sharp', 'Catering Service', '4812 Paul Plaza\nNorth Amanda, WI 89597', 'brownton', '+1-200-440-3875')
# (370, 'cox-richmond', 'Supermarket', 'USNS Ingram\nFPO AA 14461', 'williamsland', '+1-572-551-8798')
# (371, 'montgomery dominguez and hopkins', 'Grocery Store', '565 Davis Shoals\nNew James, ND 98971', 'solisburgh', '+1-394-823-0121')
# (372, 'elliott-jones', 'Restaurant', 'Unit 8546 Box 6518\nDPO AE 36672', 'lewisberg', '+1-690-272-6499')
# (373, 'avila group', 'Grocery Store', '099 Rodriguez Creek\nRonaldport, RI 02598', 'aprilberg', '+1-594-301-2252')
# (374, 'pollard yoder and martin', 'Grocery Store', '3352 Willis Junctions Apt. 432\nLake Pamelaborough, NV 36555', 'steeleport', '+1-612-026-7787')
# (375, 'anderson-stevens', 'Supermarket', '82308 Richard Mall Apt. 824\nJoshuafurt, UT 33812', 'new ryanbury', '+1-303-422-7712')
# (376, 'wilkins-boyle', 'Catering Service', '907 Shawn Lakes Apt. 626\nWest Benjaminton, AK 55564', 'lake sarah', '+1-296-372-4350')
# (377, 'cooper-gill', 'Catering Service', '94711 Tracy Court Apt. 437\nTammyborough, ME 89430', 'west omar', '+1-221-854-5570')
# (378, 'foster ltd', 'Supermarket', '5394 Laura Cliffs\nEast Angela, NH 01271', 'south johnshire', '+1-704-504-1352')
# (379, 'payne-pena', 'Supermarket', '6560 Jesse Brooks Suite 699\nNorth Rebeccafort, ID 49869', 'millerstad', '+1-370-216-0851')
# ...
# (876, 'rosario-porter', 'Grocery Store', '538 Ramsey Trace\nRomeroland, MA 69729', 'brookeland', '+1-867-595-3131')
# (877, 'hughes-hart', 'Grocery Store', '0824 Ronald Branch\nWest Rogerstad, NM 76134', 'campbellchester', '+1-176-065-8790')
# (878, 'richardson-jones', 'Supermarket', '4052 Brown Gateway\nPort Susan, MT 01391', 'tracyfort', '+1-172-899-7285')
# (879, 'hughes ltd', 'Supermarket', 'Unit 7379 Box 0879\nDPO AP 36544', 'lake michael', '+1-543-742-7158')
# (880, 'johnson-brown', 'Catering Service', '06136 Jessica Parkways\nLittletown, CA 68113', 'sheenashire', '+1-252-571-8129')
# (881, 'hall taylor and anderson', 'Restaurant', '22046 Barry Turnpike Apt. 458\nWilsonshire, GA 77403', 'new jenniferbury', '+1-595-456-3203')
# (882, 'freeman allen and castaneda', 'Supermarket', '58124 Reeves Stream Suite 880\nDayfurt, IA 16577', 'jenniferville', '+1-162-139-2884')
# (883, 'lewis wagner and solis', 'Supermarket', '250 Chloe Common\nSouth Elizabethbury, NH 23690', 'new jacob', '+1-094-480-8706')
# (884, 'hill-anderson', 'Grocery Store', '500 Jones Circles Apt. 341\nBrendaside, NJ 13591', 'robinsonfort', '+1-645-245-9145')
# (885, 'spears anderson and huffman', 'Restaurant', '4257 Roberto Squares\nNew Timothyhaven, NY 01630', 'lake stephen', '+1-190-627-7080')
# (886, 'gentry and sons', 'Restaurant', '913 Katrina Mountains Apt. 164\nEast Thomas, NJ 59999', 'new tiffanystad', '+1-845-076-7276')
# (887, 'preston-smith', 'Supermarket', '18358 Moore Spring Suite 713\nGordonshire, MT 45298', 'strongmouth', '+1-632-777-5776')
# (888, 'schmidt-alexander', 'Supermarket', '96966 Smith Expressway\nLauraburgh, MD 50475', 'west sharonview', '+1-290-456-6126')
# (889, 'bass llc', 'Restaurant', '7188 Zachary Views\nLake Nicolehaven, AL 24903', 'owensstad', '+1-963-933-0141')
# (890, 'simpson mcguire and brown', 'Restaurant', '950 Dawn Mountains\nNew Robert, MI 58996', 'pereztown', '+1-412-013-4627')
# (891, 'walter-stevens', 'Supermarket', '32820 Lozano Fork\nEmilybury, HI 03708', 'charlesland', '+1-760-908-2031')
# (892, 'flores-wade', 'Grocery Store', '43443 Campbell Highway\nRicetown, MA 95006', 'russellfurt', '+1-525-492-4716')
# (893, 'cooper harvey and jordan', 'Restaurant', '241 Ethan Gardens Suite 016\nKevinshire, MD 90518', 'gomezfurt', '+1-119-434-3757')
# (894, 'fowler-morgan', 'Restaurant', '684 Mike Mission Suite 131\nEast Sharonmouth, ME 61479', 'cannonside', '+1-711-303-0408')
# (895, 'greer-frye', 'Grocery Store', '424 Ryan Circle\nKellymouth, MT 70307', 'padillamouth', '+1-767-407-0399')
# (896, 'marquez reid and kramer', 'Grocery Store', '8981 William Extension Apt. 848\nNew Jenniferport, RI 49072', 'weberfurt', '+1-843-389-9156')
# (897, 'stephens-braun', 'Catering Service', '657 Charles Streets\nNorth Carolineberg, AR 77518', 'villastad', '+1-744-282-3182')
# (898, 'wilson group', 'Restaurant', 'Unit 6637 Box 3119\nDPO AP 06435', 'medinatown', '+1-494-353-9272')
# (899, 'jackson lee and hodge', 'Catering Service', '5326 Christian Trail\nPort Hectorstad, NH 21079', 'north steven', '+1-445-982-1954')
# (900, 'campbell peterson and nixon', 'Catering Service', 'USCGC Sullivan\nFPO AE 70797', 'west peter', '+1-509-405-3327')
# (901, 'galvan ltd', 'Supermarket', '053 Richard Glens\nPort Tanya, AR 46804', 'west melissastad', '+1-637-914-9942')
# (902, 'parsons ltd', 'Supermarket', '13271 Michael Way Apt. 244\nSouth Jennifer, AK 74009', 'port robertport', '+1-827-879-2329')
# (903, 'galloway hall and oconnell', 'Catering Service', '08907 Paige Canyon Suite 640\nWest Michaelborough, RI 85483', 'lake kari', '+1-699-918-8092')
# (904, 'smith-morales', 'Grocery Store', '92861 Megan Extension Apt. 163\nJacobsburgh, MD 32991', 'west miaside', '+1-622-452-4959')
# (905, 'ayers llc', 'Restaurant', '901 Pacheco Dale\nRobertport, OK 20674', 'north kennethshire', '+1-336-516-1067')
# (906, 'wright llc', 'Supermarket', 'PSC 1473, Box 2158\nAPO AE 95836', 'west kevin', '+1-383-602-9214')
# (907, 'sanchez plc', 'Supermarket', '48910 Gordon Pike Apt. 720\nQuinnshire, AK 79288', 'south marthahaven', '+1-697-679-9956')
# (908, 'martinez-young', 'Supermarket', '1821 Davis Estates\nDawnstad, ND 73249', 'east phillipton', '+1-448-182-4708')
# (909, 'gibbs green and krause', 'Restaurant', '9340 Dalton Junctions Suite 998\nTiffanymouth, SD 76155', 'sheilaburgh', '+1-782-471-8530')
# (910, 'lee plc', 'Restaurant', '886 Mark Plain Suite 687\nLake Nicholashaven, MN 43931', 'leeburgh', '+1-517-790-1471')
# (911, 'alexander plc', 'Restaurant', '28329 Gary Courts\nEast Jonathan, KS 04105', 'garciatown', '+1-599-601-7460')
# (912, 'morrison llc', 'Catering Service', 'Unit 7525 Box 7976\nDPO AA 30814', 'blaketown', '+1-776-420-3183')
# (913, 'crosby group', 'Grocery Store', '81218 Peter Rest Apt. 173\nEast Caitlinport, NV 39150', 'erikatown', '+1-535-303-7456')
# (914, 'whitaker group', 'Catering Service', '59776 Perry Turnpike Apt. 615\nSouth Howard, HI 48266', 'garciaberg', '+1-008-463-7894')
# (915, 'morton perry and lopez', 'Grocery Store', '61563 Hendrix Viaduct Suite 566\nLake Harryton, MA 17987', 'port raymondburgh', '+1-610-934-3633')
# (916, 'davis and sons', 'Catering Service', '551 Huynh Trail Apt. 373\nLake Kevinton, KS 39284', 'patrickfort', '+1-965-266-3582')
# (917, 'moore peck and cox', 'Supermarket', '827 Pace Unions Apt. 620\nPaulhaven, RI 85075', 'new john', '+1-403-232-7921')
# (918, 'wilson-medina', 'Grocery Store', 'PSC 7795, Box 8364\nAPO AE 31123', 'east heather', '+1-020-704-0308')
# (919, 'cruz-davis', 'Supermarket', '032 Suarez Pine Apt. 241\nPort Anthonyborough, IN 97036', 'port tanyaburgh', '+1-126-595-1397')
# (920, 'hudson spence and perez', 'Restaurant', '52439 April Lodge\nTimothyburgh, MS 86772', 'new calebberg', '+1-232-944-7078')
# (921, 'oliver-orr', 'Grocery Store', '56629 Tara Alley Apt. 226\nSouth Adrianchester, NE 12389', 'lucasmouth', '+1-291-397-0048')
# (922, 'villegas inc', 'Restaurant', '648 Maria Gardens\nNew Charles, NM 12489', 'lake michael', '+1-338-721-0560')
# (923, 'rodriguez inc', 'Supermarket', '937 Murray Turnpike\nLorrainestad, RI 37088', 'jonestown', '+1-138-331-2143')
# (924, 'rosales-dillon', 'Supermarket', '462 Nicole Common\nWheelermouth, VA 10670', 'port donnamouth', '+1-259-371-8249')
# (925, 'white ltd', 'Restaurant', '04589 Cole Highway Suite 011\nSheltonbury, MN 56672', 'east jesse', '+1-870-515-3806')
# (926, 'perkins ltd', 'Grocery Store', '6749 Stewart Trace\nNew Thomas, KY 96239', 'north chase', '+1-701-674-2402')
# (927, 'clark-miranda', 'Catering Service', '54388 John Bypass Suite 842\nNew Kimberly, AL 69199', 'east benjaminland', '+1-808-109-1808')
# (928, 'larson and sons', 'Catering Service', '5591 Kathleen Route Apt. 687\nSouth Paul, NC 69885', 'zimmermanton', '+1-152-836-4864')
# (929, 'allen llc', 'Catering Service', '11055 Hayes Island Suite 805\nCynthiatown, ME 65521', 'lake richardhaven', '+1-474-088-6934')
# (930, 'cannon-garcia', 'Restaurant', '18680 Krystal Inlet Apt. 200\nEast Janettown, MO 64497', 'kellytown', '+1-942-150-8200')
# (931, 'phillips-bradley', 'Supermarket', '6479 Beverly Club\nEast Karen, IN 38784', 'south allisonburgh', '+1-645-494-2603')
# (932, 'jones allison and ellison', 'Supermarket', '95536 Hunt Harbor Apt. 227\nNorth Alexisbury, AR 45373', 'new ginaborough', '+1-243-942-4267')
# (933, 'jimenez-ramirez', 'Catering Service', '29016 Patricia Turnpike\nNorth Jeffreymouth, VT 07661', 'anthonyborough', '+1-145-547-4878')
# (934, 'nelson and sons', 'Grocery Store', '8015 Meyer View\nSouth Bobby, MN 09536', 'steveport', '+1-687-855-4731')
# (935, 'frazier-sanders', 'Grocery Store', '5099 Campbell Falls\nPort Paulmouth, AK 72465', 'ramseyfort', '+1-837-720-4562')
# (936, 'velazquez mitchell and mcintyre', 'Supermarket', '64520 Joshua Parks\nSouth Johnfurt, TN 61990', 'lisaborough', '+1-576-993-8436')
# (937, 'taylor group', 'Restaurant', '14689 Scott Gateway\nNorth Curtis, RI 22825', 'roachhaven', '+1-301-846-7005')
# (938, 'barker llc', 'Restaurant', '5999 Brenda Trail Apt. 807\nAmberstad, VT 22034', 'hollyhaven', '+1-020-722-5507')
# (939, 'reyes and sons', 'Catering Service', '2706 Samantha Ferry Suite 785\nKevinborough, SC 54085', 'new monicaside', '+1-960-863-4637')
# (940, 'bradley-martin', 'Grocery Store', '145 Diana Circle Suite 342\nNorth Michelle, AZ 40121', 'williamsshire', '+1-105-293-8557')
# (941, 'george group', 'Catering Service', '20833 Huffman Plaza\nEast Kevin, MN 53076', 'port allisonland', '+1-470-487-6955')
# (942, 'miller llc', 'Grocery Store', '7974 Matthew Hill Suite 293\nLake Christopherstad, MN 36854', 'west stephenside', '+1-870-001-4338')
# (943, 'york-ferguson', 'Supermarket', '157 Woods Cliffs\nEast Arthur, MS 76614', 'lake devon', '+1-737-949-6948')
# (944, 'miller-bennett', 'Supermarket', '141 Benjamin Inlet\nCisneroston, VA 34027', 'campbellbury', '+1-018-142-9732')
# (945, 'young-wu', 'Grocery Store', '6293 Higgins Viaduct Apt. 488\nElizabethmouth, MA 47397', 'tamaraside', '+1-158-746-0724')
# (946, 'brock newton and mccormick', 'Catering Service', '3043 Aguilar Mission\nColtonbury, KS 26858', 'roystad', '+1-493-966-8395')
# (947, 'melton olson and foster', 'Catering Service', '886 Griffin Ports Apt. 205\nPort Hayden, OH 11566', 'lake regina', '+1-655-121-1214')
# (948, 'house-bates', 'Supermarket', '48407 Hall Cliffs\nLake Traceymouth, MD 10524', 'west lisamouth', '+1-289-837-9304')
# (949, 'jackson howe and gentry', 'Supermarket', 'Unit 6067 Box 3679\nDPO AA 63953', 'lake deborah', '+1-071-338-9174')
# (950, 'robinson-gibson', 'Supermarket', '699 Brenda Landing\nPetersstad, NH 95795', 'south zacharymouth', '+1-313-085-7612')
# (951, 'hodge lee and washington', 'Grocery Store', '2730 Shannon Mall Apt. 069\nOwensburgh, MO 32097', 'spenceland', '+1-232-156-9552')
# (952, 'harris mcdonald and taylor', 'Grocery Store', '0039 Alexander Terrace Apt. 565\nAprilborough, MI 33494', 'samueltown', '+1-648-160-9304')
# (953, 'obrien-zhang', 'Supermarket', '29928 Hawkins Glens Suite 830\nMillerfort, AK 35617', 'west abigailtown', '+1-766-455-6356')
# (954, 'herrera llc', 'Catering Service', '03238 Singh Mill Apt. 542\nDonaldburgh, IL 63546', 'randallchester', '+1-841-290-1538')
# (955, 'williams plc', 'Catering Service', '0627 Keith Ferry Apt. 778\nNorth Melaniechester, NY 94824', 'wrightville', '+1-730-287-3289')
# (956, 'haynes barnett and wiley', 'Supermarket', '70012 Lucero Stravenue\nFloresbury, CA 62305', 'lake lindsey', '+1-980-273-6877')
# (957, 'rice and sons', 'Grocery Store', '06266 Roberts Corner\nJamiemouth, ME 21665', 'south tina', '+1-988-144-1190')
# (958, 'patel ltd', 'Restaurant', '892 Brandy Village\nDeborahshire, AK 22864', 'lake vanessaland', '+1-694-214-7175')
# (959, 'stanley plc', 'Grocery Store', '3255 Steven Falls Apt. 575\nSouth Ashleyton, NM 59651', 'north victoriastad', '+1-158-581-9231')
# (960, 'jackson shelton and mayer', 'Supermarket', '6472 Michelle Drives\nLake Robert, VA 54017', 'port lance', '+1-910-616-7900')
# (961, 'davis sanchez and mendez', 'Restaurant', '78391 Susan Landing Apt. 690\nCheyennefort, WI 89189', 'new amanda', '+1-696-690-2244')
# (962, 'galloway-henderson', 'Catering Service', 'Unit 2168 Box 9786\nDPO AA 06880', 'alexanderchester', '+1-280-212-3211')
# (963, 'johnson plc', 'Supermarket', '38009 Oconnor Prairie\nJanicemouth, MS 31632', 'east bernard', '+1-089-899-0152')
# (964, 'graham and sons', 'Catering Service', '379 Thomas Roads\nHarrisport, DC 76335', 'connieside', '+1-443-618-9629')
# (965, 'oconnor ltd', 'Restaurant', '49967 Victoria Union Suite 176\nWatkinsport, NC 14235', 'port bryce', '+1-168-241-0667')
# (966, 'rivers pena and davies', 'Restaurant', 'Unit 9564 Box 1583\nDPO AA 18894', 'christopherside', '+1-392-087-3295')
# (967, 'miller inc', 'Grocery Store', '97290 Stephanie Mountains Apt. 247\nLindseyburgh, WY 63235', 'coleburgh', '+1-869-945-8729')
# (968, 'robinson schaefer and foster', 'Restaurant', '83418 Joshua Place Suite 333\nNathanielborough, IN 28904', 'christopherton', '+1-607-055-3247')
# (969, 'hayden plc', 'Catering Service', '51093 Richard Corners Apt. 086\nRossmouth, MS 72720', 'port christopher', '+1-619-534-3215')
# (970, 'lewis preston and price', 'Catering Service', '6974 Paul Estate\nLake Jacob, NV 24380', 'jeffreybury', '+1-668-591-3720')
# (971, 'scott davis and mcbride', 'Restaurant', '89161 Christine Track Suite 497\nAndreachester, MD 90839', 'port daniel', '+1-797-318-7062')
# (972, 'hurst lee and sims', 'Supermarket', '20729 Martinez Locks\nWest Katie, KS 29229', 'port melissa', '+1-521-004-0816')
# (973, 'watson llc', 'Supermarket', '29574 Scott Flats\nJamestown, ME 66124', 'new larry', '+1-859-114-8922')
# (974, 'jackson llc', 'Grocery Store', '61454 Ryan Well Suite 025\nEast Aprilside, IL 12106', 'moralesberg', '+1-589-951-5870')
# (975, 'lowe ltd', 'Catering Service', '234 John Rue\nHendrixport, AZ 46361', 'east robertton', '+1-145-649-1608')
# (976, 'robinson rodriguez and reilly', 'Restaurant', '53064 Danny Centers Apt. 116\nNew Nicole, WY 40193', 'davisview', '+1-522-377-3348')
# (977, 'anderson and sons', 'Restaurant', '1110 Martin Square Suite 965\nWest Anthony, VT 13086', 'south jessicachester', '+1-596-119-0656')
# (978, 'lewis-anderson', 'Catering Service', '29974 Becker Hill Apt. 666\nPattonfurt, NJ 66040', 'flemingport', '+1-704-625-9654')
# (979, 'gray plc', 'Restaurant', '536 Joyce Locks Suite 818\nEast Catherine, DE 59565', 'west hunter', '+1-149-065-6397')
# (980, 'baker group', 'Restaurant', '82725 Walker Parkway\nKarimouth, VA 07630', 'port melissa', '+1-838-102-2168')
# (981, 'glenn-york', 'Restaurant', '96371 Owens Mountains\nNorth Daniellestad, WI 11685', 'west stevenport', '+1-839-093-3019')
# (982, 'martinez plc', 'Grocery Store', '93509 Solomon Station\nSarahview, NH 55581', 'westbury', '+1-292-371-8219')
# (983, 'munoz stone and wallace', 'Grocery Store', '739 Adams Alley\nVangborough, IN 50041', 'herbertbury', '+1-135-309-5826')
# (984, 'gamble-davis', 'Catering Service', '6516 Natalie Parkway Apt. 359\nPort Angelicaville, OK 74292', 'south edwardtown', '+1-868-079-8375')
# (985, 'frey plc', 'Restaurant', '4394 William Island\nWest Beth, OR 77721', 'harrisonbury', '+1-890-661-5455')
# (986, 'wilson harris and mayo', 'Supermarket', '075 Kim Vista Suite 910\nSouth Natashaberg, WA 02431', 'port david', '+1-178-362-1117')
# (987, 'harris santos and roberts', 'Supermarket', '6861 Steven Isle Apt. 138\nSouth Blake, KS 26018', 'south kevinhaven', '+1-664-346-8788')
# (988, 'morris serrano and roberson', 'Grocery Store', '29137 Williams Summit Apt. 780\nFullerton, WA 63589', 'east laura', '+1-103-614-2052')
# (989, 'williams-aguirre', 'Grocery Store', '6861 Tiffany Junction Apt. 176\nFarleyfurt, HI 39406', 'north lauren', '+1-205-999-3497')
# (990, 'jones plc', 'Catering Service', '2646 Hull Wall Apt. 985\nValenciamouth, TN 58725', 'lake latasha', '+1-614-929-4353')
# (991, 'spencer llc', 'Supermarket', '63770 Jessica Falls Apt. 397\nChadton, VT 61248', 'stevensborough', '+1-041-072-1937')
# (992, 'miller-sanders', 'Grocery Store', '896 Karen Island Apt. 800\nJohnsontown, NJ 75055', 'browninghaven', '+1-648-599-6844')
# (993, 'mckinney ltd', 'Restaurant', '179 Fernandez Rapids\nCampbellport, MA 31352', 'east stephanie', '+1-225-959-2378')
# (994, 'porter hernandez and pace', 'Catering Service', '3564 Hutchinson Shore\nSouth Danielle, DC 15667', 'amyport', '+1-802-340-0771')
# (995, 'moore group', 'Supermarket', '46915 Maynard Dam Suite 320\nNorth Alyssa, CA 48762', 'manningshire', '+1-387-755-1762')
# (996, 'vasquez ruiz and flowers', 'Restaurant', '84308 Justin Stravenue\nNew Amberside, NE 53447', 'williamview', '+1-787-627-0682')
# (997, 'garza-williams', 'Catering Service', '08864 Figueroa Radial Suite 948\nJennaberg, AZ 21207', 'east rossside', '+1-441-396-3746')
# (998, 'novak group', 'Grocery Store', '934 Zachary Run\nMelissamouth, WY 02729', 'joshuastad', '+1-421-969-3300')
# (999, 'moody ltd', 'Grocery Store', '17580 Ernest Hills\nLake Michaelmouth, OR 56416', 'stevenchester', '+1-003-664-4880')
# (1000, 'jenkins-brooks', 'Restaurant', '53390 Evans Rapids Suite 982\nLake Meghan, MO 44235', 'brendantown', '+1-434-589-5775')

# %%
# Loop through tables and get structure
for table in tables:
    table_name = table[0]
    print(f"\n=== Structure of '{table_name}' ===")
    cursor.execute(f"PRAGMA table_info({table_name});")
    columns = cursor.fetchall()
    for col in columns:
        # col[1] = column name, col[2] = column type
        print(f"{col[1]} ({col[2]})")

conn.close()
# Out:
# === Structure of 'providers' ===
# Provider_ID (INTEGER)
# Name (TEXT)
# Type (TEXT)
# Address (TEXT)
# City (TEXT)
# Contact (TEXT)
#
# === Structure of 'receivers' ===
# Receiver_ID (INTEGER)
# Name (TEXT)
# Type (TEXT)
# City (TEXT)
# Contact (TEXT)
#
# === Structure of 'food_listings' ===
# Food_ID (INTEGER)
# Food_Name (TEXT)
# Quantity (INTEGER)
# Expiry_Date (DATE)
# Provider_ID (INTEGER)
# Provider_Type (TEXT)
# Location (TEXT)
# Food_Type (TEXT)
# Meal_Type (TEXT)
#
# === Structure of 'claims' ===
# Claim_ID (INTEGER)
# Food_ID (INTEGER)
# Receiver_ID (INTEGER)
# Status (TEXT)
# Timestamp (DATETIME)

# %% [markdown]
# # 3. Data Analysis

# %% [markdown]
# ## SQL Queries

# %%
import sqlite3

# Open database connection
conn = sqlite3.connect("food_wastage.db")
cursor = conn.cursor()

# %% [markdown]
# ### Food Providers & Receivers

# %% [markdown]
# #### Query 1: How many food providers and receivers are there in each city?

# %%
cursor = conn.cursor()

cursor.execute("""
SELECT p.City,
       COUNT(DISTINCT p.Provider_ID) AS Providers,
       COUNT(DISTINCT r.Receiver_ID) AS Receivers
FROM providers p
LEFT JOIN receivers r ON p.City = r.City
GROUP BY p.City;
""")

print("1. Providers & Receivers per city:", cursor.fetchall())
# Out:
# 1. Providers & Receivers per city: [('adambury', 1, 0), ('adamsview', 1, 0), ('adamsville', 1, 0), ('aguirreville', 1, 0), ('alexanderchester', 1, 0), ('alexanderstad', 1, 0), ('allenborough', 1, 1), ('allenton', 1, 0), ('amandaborough', 1, 0), ('amandashire', 1, 0), ('amberton', 1, 0), ('ambertown', 1, 0), ('amyport', 1, 0), ('andersonmouth', 1, 0), ('andersonville', 1, 0), ('andreaborough', 1, 0), ('andrewsmouth', 1, 0), ('andrewstad', 1, 0), ('anitashire', 1, 0), ('annahaven', 1, 0), ('annetteburgh', 1, 0), ('anneville', 1, 0), ('anthonyborough', 1, 0), ('anthonychester', 1, 0), ('anthonyfort', 1, 0), ('anthonyhaven', 1, 0), ('anthonyshire', 1, 0), ('anthonyton', 1, 0), ('aprilberg', 1, 0), ('arnoldmouth', 1, 0), ('ashleyhaven', 1, 0), ('ashleyton', 1, 0), ('bairdfort', 1, 0), ('baldwinshire', 1, 0), ('barkerborough', 1, 0), ('barryside', 1, 0), ('bartonborough', 1, 0), ('basstown', 1, 0), ('batesstad', 1, 0), ('beasleyhaven', 1, 0), ('belindaville', 1, 0), ('bellport', 1, 0), ('benjaminstad', 1, 0), ('bentleyburgh', 1, 0), ('bentonfurt', 1, 0), ('blaketown', 1, 0), ('bonillahaven', 1, 0), ('boylechester', 1, 0), ('bradleyborough', 1, 0), ('bradleyport', 2, 0), ('bradleyview', 1, 0), ('brandyberg', 1, 0), ('brendantown', 1, 0), ('brennanstad', 1, 0), ('brewerfort', 1, 0), ('brianside', 1, 0), ('bridgetside', 1, 0), ('brittanyland', 1, 0), ('brittanyport', 1, 0), ('brittanyside', 1, 0), ('brittanyville', 1, 0), ('brookeland', 1, 0), ('brownberg', 1, 0), ('brownchester', 1, 0), ('browninghaven', 1, 0), ('brownshire', 1, 0), ('brownton', 1, 0), ('browntown', 1, 0), ('bryantton', 1, 0), ('butlerview', 1, 0), ('cabreraberg', 1, 0), ('callahanside', 1, 0), ('cameronside', 1, 0), ('campbellbury', 1, 0), ('campbellchester', 1, 1), ('cannonside', 1, 0), ('carlborough', 1, 0), ('carlbury', 1, 0), ('carolchester', 1, 0), ('carrport', 1, 0), ('cassandraville', 1, 0), ('castilloport', 1, 0), ('chadview', 1, 0), ('chambersfort', 1, 0), ('charlesland', 1, 0), ('charlesmouth', 1, 0), ('charlesview', 1, 0), ('chelseaside', 1, 0), ('chelseyfort', 1, 0), ('christianfurt', 1, 0), ('christinaland', 1, 1), ('christinamouth', 1, 0), ('christinetown', 1, 0), ('christopherchester', 1, 2), ('christopherside', 1, 0), ('christopherstad', 1, 0), ('christopherton', 1, 0), ('cindyshire', 1, 0), ('cisnerostown', 1, 0), ('clarkberg', 1, 0), ('codyview', 1, 0), ('coleburgh', 1, 0), ('colemanton', 1, 0), ('collinsmouth', 1, 0), ('collinston', 1, 0), ('connieside', 1, 0), ('contrerasberg', 1, 0), ('coopermouth', 1, 0), ('copelandchester', 1, 0), ('cordovaborough', 1, 0), ('courtneychester', 1, 0), ('crystalborough', 1, 0), ('cummingstown', 1, 0), ('cunninghambury', 1, 0), ('danachester', 1, 0), ('danaville', 1, 0), ('dannybury', 1, 0), ('darrellfurt', 1, 0), ('darrylchester', 1, 0), ('davidborough', 1, 0), ('davidchester', 1, 0), ('davidland', 1, 1), ('davidport', 1, 1), ('davidville', 2, 0), ('davisshire', 1, 0), ('davisview', 1, 0), ('deanport', 1, 0), ('deborahfurt', 1, 0), ('deborahland', 1, 0), ('deckermouth', 1, 0), ('derekland', 1, 0), ('derekport', 1, 0), ('derekshire', 1, 0), ('devinmouth', 1, 0), ('devinton', 1, 0), ('donnaborough', 1, 0), ('drakeville', 1, 0), ('durhamchester', 1, 0), ('east aaron', 1, 0), ('east alexisberg', 1, 0), ('east amyfurt', 1, 0), ('east amymouth', 1, 0), ('east andrea', 1, 0), ('east andrewland', 1, 0), ('east angela', 1, 0), ('east angelafort', 1, 0), ('east annshire', 1, 0), ('east anthony', 2, 0), ('east ashleyshire', 1, 1), ('east austin', 1, 0), ('east benjaminland', 1, 0), ('east bernard', 1, 0), ('east brittanyland', 1, 0), ('east candace', 1, 0), ('east caseyfort', 1, 0), ('east christophertown', 1, 0), ('east courtneymouth', 1, 0), ('east craig', 1, 0), ('east cynthia', 1, 0), ('east darrell', 1, 0), ('east deborah', 1, 0), ('east deniseborough', 1, 0), ('east donnafort', 1, 0), ('east edwinburgh', 1, 0), ('east elizabeth', 1, 0), ('east elizabethberg', 1, 0), ('east emily', 1, 1), ('east emilyburgh', 1, 0), ('ea ...

# %% [markdown]
# #### Query 2:  Which type of food provider contributes the most food?

# %%
cursor.execute("""
SELECT p.Type, SUM(f.Quantity) AS Total_Quantity
FROM providers p
JOIN food_listings f ON p.Provider_ID = f.Provider_ID
GROUP BY p.Type
ORDER BY Total_Quantity DESC
LIMIT 1;
""")
print("2. Top provider type by contribution:", cursor.fetchall())
# Out:
# 2. Top provider type by contribution: [('Restaurant', 6923)]

# %% [markdown]
# #### Query 3: Contact info of food providers in a specific city

# %%
cursor.execute("PRAGMA table_info(providers);")
columns = cursor.fetchall()
for col in columns:
    print(col)
# Out:
# (0, 'Provider_ID', 'INTEGER', 0, None, 1)
# (1, 'Name', 'TEXT', 0, None, 0)
# (2, 'Type', 'TEXT', 0, None, 0)
# (3, 'Address', 'TEXT', 0, None, 0)
# (4, 'City', 'TEXT', 0, None, 0)
# (5, 'Contact', 'TEXT', 0, None, 0)

# %%
city_name = "adambury"
cursor.execute("""
SELECT Name, Contact
FROM providers
WHERE City = ?;
""", (city_name,))
print(f"3. Provider contacts in {city_name}:", cursor.fetchall())
# Out:
# 3. Provider contacts in adambury: [('ibarra llc', '+1-670-338-0260')]

# %% [markdown]
# #### Query 4: Which receivers have claimed the most food?

# %%
cursor.execute("""
WITH claim_counts AS (
    SELECT r.Name, COUNT(c.Claim_ID) AS Total_Claims
    FROM receivers r
    JOIN claims c ON r.Receiver_ID = c.Receiver_ID
    GROUP BY r.Name
)
SELECT Name, Total_Claims
FROM claim_counts
WHERE Total_Claims = (SELECT MAX(Total_Claims) FROM claim_counts);
""")

print("Receivers with the highest number of claims:", cursor.fetchall())
# Out:
# Receivers with the highest number of claims: [('anthony garcia', 5), ('matthew webb', 5), ('scott hunter', 5), ('william frederick', 5)]

# %% [markdown]
# ### Food Listings & Availability

# %% [markdown]
# #### Query 5: What is the total quantity of food available from all providers?

# %%
cursor.execute("""
SELECT SUM(Quantity) FROM food_listings;
""")
print("5. Total available food quantity:", cursor.fetchall())
# Out:
# 5. Total available food quantity: [(25794,)]

# %% [markdown]
# #### Query 6: Which city has the highest number of food listings?

# %%
cursor.execute("""
SELECT p.City, COUNT(f.Food_ID) AS Listings
FROM providers p
JOIN food_listings f ON p.Provider_ID = f.Provider_ID
GROUP BY p.City
ORDER BY Listings DESC
LIMIT 1;
""")
print("6. City with most food listings:", cursor.fetchall())
# Out:
# 6. City with most food listings: [('south kathryn', 6)]

# %% [markdown]
# #### Query 7: What are the most commonly available food types?

# %%
cursor.execute("""
SELECT Food_Type, COUNT(*) AS Count
FROM food_listings
GROUP BY Food_Type
ORDER BY Count DESC;
""")
print("7. Common food types:", cursor.fetchall())
# Out:
# 7. Common food types: [('Vegetarian', 336), ('Vegan', 334), ('Non-Vegetarian', 330)]

# %% [markdown]
# ### Claims & Distribution

# %% [markdown]
# #### Query 8: How many food claims for each food item?

# %%
cursor.execute("""
SELECT f.Food_Name, COUNT(c.Claim_ID) AS Claim_Count
FROM food_listings f
JOIN claims c ON f.Food_ID = c.Food_ID
GROUP BY f.Food_Name;
""")
print("8. Claims per food item:", cursor.fetchall())
# Out:
# 8. Claims per food item: [('Bread', 94), ('Chicken', 102), ('Dairy', 110), ('Fish', 108), ('Fruits', 71), ('Pasta', 87), ('Rice', 122), ('Salad', 106), ('Soup', 114), ('Vegetables', 86)]

# %% [markdown]
# #### Query 9: Provider with the highest number of successful food claims

# %%
cursor.execute("""
SELECT p.Name, COUNT(c.Claim_ID) AS Successful_Claims
FROM providers p
JOIN food_listings f ON p.Provider_ID = f.Provider_ID
JOIN claims c ON f.Food_ID = c.Food_ID
WHERE c.Status = 'Completed'
GROUP BY p.Name
ORDER BY Successful_Claims DESC
LIMIT 1;
""")
print("9. Top provider by successful claims:", cursor.fetchall())
# Out:
# 9. Top provider by successful claims: [('barry group', 5)]

# %% [markdown]
# #### Query 10: Percentage of claims by status

# %%
cursor.execute("""
SELECT Status,
       ROUND((COUNT(*) * 100.0 / (SELECT COUNT(*) FROM claims)), 2) AS Percentage
FROM claims
GROUP BY Status;
""")
print("10. Claims percentage by status:", cursor.fetchall())
# Out:
# 10. Claims percentage by status: [('Cancelled', 33.6), ('Completed', 33.9), ('Pending', 32.5)]

# %% [markdown]
# ### Analysis & Insights

# %% [markdown]
# #### Query 11: Average quantity of food claimed per receiver

# %%
cursor.execute("""
SELECT r.Name, AVG(f.Quantity) AS Avg_Claimed
FROM receivers r
JOIN claims c ON r.Receiver_ID = c.Receiver_ID
JOIN food_listings f ON c.Food_ID = f.Food_ID
GROUP BY r.Name;
""")

print("11. Average quantity claimed per receiver:", cursor.fetchall())
# Out:
# 11. Average quantity claimed per receiver: [('aaron keller', 39.0), ('aaron rios', 21.0), ('aaron scott', 45.0), ('abigail crawford', 25.666666666666668), ('adam browning', 5.0), ('adam moore', 27.333333333333332), ('aimee stone', 27.5), ('alan campbell', 6.0), ('alex leon', 14.0), ('alex rogers', 23.0), ('alex white', 18.0), ('alexander dean', 30.0), ('alexander mullins', 49.0), ('alexander walsh', 27.666666666666668), ('alexandra owens', 20.25), ('alexandra rogers', 30.0), ('alexis hayes', 12.0), ('alexis rodriguez', 8.0), ('alicia porter', 18.666666666666668), ('alicia thomas', 26.666666666666668), ('allison bray', 22.666666666666668), ('allison martinez', 10.0), ('allison pennington', 31.0), ('alvin day jr', 21.0), ('alvin west', 24.75), ('amanda brown', 8.0), ('amanda cain', 25.5), ('amanda kline', 1.0), ('amber arellano', 31.0), ('amber cruz', 18.0), ('amber hobbs', 26.0), ('amy barker', 41.0), ('amy brown', 34.0), ('amy perez', 32.5), ('amy thomas', 40.0), ('andrea hansen', 25.0), ('andrea meyer', 23.5), ('andrea morris', 33.0), ('andrew gray', 42.0), ('andrew lawson', 35.0), ('angel adams', 49.0), ('angela cortez', 37.0), ('angela hall', 40.5), ('angela knight', 21.0), ('angela wyatt', 49.0), ('angelica simmons', 26.0), ('anita kerr', 26.0), ('ann odonnell', 30.5), ('anna buckley', 35.333333333333336), ('anne stone', 19.0), ('anthony cochran', 34.5), ('anthony garcia', 32.4), ('anthony guerra', 11.0), ('antonio murphy', 12.0), ('april miller', 19.0), ('arthur thomas', 26.0), ('ashley bell', 4.0), ('ashley clark', 45.0), ('ashley harris', 34.666666666666664), ('ashley martinez', 30.0), ('ashley mckee', 26.0), ('ashley rivers', 40.0), ('ashley silva', 11.5), ('audrey perez', 45.0), ('austin smith', 6.0), ('autumn reed', 16.0), ('barbara velasquez', 35.0), ('becky hernandez', 22.0), ('benjamin soto', 35.0), ('beth phillips', 14.0), ('betty reid', 23.25), ('bobby perry', 17.0), ('brady lopez', 42.0), ('brandi buckley', 14.0), ('brandon rice', 20.5), ('brandon riley', 26.0), ('brenda green', 38.0), ('brendan farley', 29.0), ('brendan vargas', 31.0), ('brent anderson', 30.0), ('brian blankenship', 10.0), ('brian cowan', 47.0), ('brian davis', 20.0), ('brian fischer', 28.0), ('brian gonzales', 26.0), ('brian hardy', 35.0), ('brian hill', 23.5), ('brian hoffman', 3.0), ('brian johnson', 5.0), ('brian morales', 34.0), ('brian reed', 38.0), ('bridget hill', 9.0), ('bridget williams', 14.0), ('brittany taylor', 35.0), ('brittany williams', 17.0), ('bruce alexander', 17.666666666666668), ('caitlin bennett', 39.5), ('caitlin cobb', 17.0), ('calvin lucas', 13.0), ('carl brewer', 33.0), ('carlos lawrence', 15.0), ('carmen barker', 29.0), ('carrie hess', 2.5), ('cassandra foster', 4.0), ('cassandra mendoza', 21.666666666666668), ('cassandra owens', 5.0), ('cassandra yoder', 49.0), ('cathy adams', 40.0), ('chad vaughn', 23.0), ('charles davidson', 25.333333333333332), ('charles martin', 9.0), ('charles morris', 29.0), ('chelsea powell', 33.5), ('cheryl dillon', 25.5), ('cheyenne ramsey', 42.0), ('christina caldwell', 23.0), ('christina potter', 45.0), ('christine bell', 24.666666666666668), ('christine davis', 20.333333333333332), ('christine patterson', 21.5), ('christopher diaz', 30.0), ('christopher garcia', 14.0), ('christopher gonzalez', 49.0), ('christopher lozano', 16.0), ('christopher sellers', 15.0), ('christopher wright', 50.0), ('cindy green phd', 17.0), ('cindy robinson dds', 15.0), ('cody gardner', 15.5), ('cody martin', 28.0), ('cody meyer', 43.0), ('corey lamb', 13.0), ('corey mitchell', 46.0), ('corey rodriguez', 2.0), ('cory johnson', 7.0), ('cory schmidt md', 43.0), ('courtney whitney', 16.333333333333332), ('cynthia horton', 12.0), ('dana williams', 36.0), ('daniel burton', 38.0), ('daniel kerr', 27.0), ('daniel moore', 34.5), ('daniel williams', 50.0), ('danielle bullock', 14.0), ('danny brown', 17.0), ('danny palmer', 15.0), ('danny randolph', 30.0), ('darius reid', 27.0), ('david carney', 28.5), ('david castro', 2 ...

# %% [markdown]
# #### Query 12: Which meal type is claimed the most?

# %%
cursor.execute("""
SELECT f.Meal_Type, COUNT(c.Claim_ID) AS Claim_Count
FROM food_listings f
JOIN claims c ON f.Food_ID = c.Food_ID
GROUP BY f.Meal_Type
ORDER BY Claim_Count DESC;
""")
print("12. Most claimed meal type:", cursor.fetchall())
# Out:
# 12. Most claimed meal type: [('Breakfast', 278), ('Lunch', 250), ('Snacks', 240), ('Dinner', 232)]

# %% [markdown]
# #### Query 13: Total quantity of food donated by each provider

# %%
cursor.execute("""
SELECT p.Name, SUM(f.Quantity) AS Total_Donated
FROM providers p
JOIN food_listings f ON p.Provider_ID = f.Provider_ID
GROUP BY p.Name
ORDER BY Total_Donated DESC;
""")
print("13. Total food donated per provider:", cursor.fetchall())
# Out:
# 13. Total food donated per provider: [('miller inc', 217), ('barry group', 179), ('evans wright and mitchell', 158), ('smith group', 150), ('campbell llc', 145), ('nelson llc', 142), ('ruiz-oneal', 140), ('blankenship-lewis', 124), ('kelly-ware', 123), ('bradford-martinez', 121), ('shepherd and sons', 116), ('hampton-lee', 116), ('jones ortega and rubio', 115), ('ortiz-lee', 114), ('johnson-ray', 113), ('barker llc', 110), ('moore group', 106), ('hill davis and stewart', 106), ('steele ltd', 104), ('butler-richardson', 104), ('lopez roach and roach', 102), ('hunter ballard and caldwell', 101), ('carter-jones', 101), ('hogan-johnston', 99), ('cox llc', 99), ('baker-mcdonald', 99), ('wong-reese', 98), ('jackson ltd', 98), ('aguilar-frederick', 98), ('schmidt-alexander', 97), ('phillips wolfe and martin', 97), ('garcia-hunter', 97), ('rogers harmon and gordon', 96), ('jones rojas and brown', 96), ('flores-wade', 96), ('clark prince and williams', 96), ('brown-stephens', 96), ('carey plc', 95), ('wilson group', 94), ('lambert ltd', 94), ('miller ltd', 93), ('hudson spence and perez', 93), ('doyle llc', 93), ('schneider-suarez', 92), ('miller johnson and fernandez', 92), ('coleman-farley', 92), ('white crawford and pearson', 91), ('kelly cummings and ward', 90), ('daniels-kim', 90), ('cooper llc', 90), ('rogers-warren', 89), ('mckinney ltd', 88), ('jones-miller', 88), ('davis-kennedy', 88), ('allen-mccullough', 88), ('young townsend and mccarthy', 87), ('torres-dunlap', 87), ('rogers robbins and cook', 87), ('davis hughes and leblanc', 87), ('glover wilson and hudson', 86), ('cooper osborn and clark', 86), ('barnes castro and curtis', 84), ('bowman llc', 83), ('smith lynch and anderson', 82), ('rios group', 82), ('webb phillips and garcia', 81), ('pollard collins and watson', 81), ('thompson group', 80), ('mcmillan gallegos and perry', 80), ('todd group', 79), ('maynard llc', 79), ('lee plc', 79), ('cook group', 79), ('butler-phillips', 79), ('wilson harris and mayo', 78), ('sanders-hale', 78), ('pierce group', 78), ('petersen morrison and woods', 78), ('munoz stone and wallace', 78), ('gonzales-cochran', 78), ('zhang llc', 76), ('nelson-white', 75), ('jones-edwards', 75), ('barnes and sons', 75), ('rowe-arias', 74), ('montgomery dominguez and hopkins', 74), ('douglas and sons', 74), ('oliver ross and johnson', 73), ('gonzales-keith', 73), ('dixon llc', 73), ('baird plc', 73), ('anderson nicholson and bruce', 73), ('thompson-kerr', 72), ('henry-terry', 72), ('crane llc', 71), ('jackson-robinson', 70), ('bray nguyen and christensen', 70), ('smith-paul', 69), ('porter inc', 69), ('wilkerson-woods', 68), ('snyder caldwell and campbell', 68), ('scott and sons', 68), ('holland and sons', 68), ('carr-wells', 68), ('owens-taylor', 67), ('simpson mcguire and brown', 66), ('aguilar group', 66), ('smith-villegas', 65), ('roberts howard and bender', 65), ('lewis preston and price', 65), ('cole llc', 65), ('richardson group', 64), ('morrison llc', 64), ('mitchell campbell and jones', 64), ('johnson-mejia', 64), ('hood hoffman and wright', 64), ('davis sanchez and mendez', 64), ('davila green and avila', 64), ('bennett phillips and green', 64), ('barrera-ward', 64), ('rodriguez thomas and foster', 63), ('moore perez and young', 63), ('cooper smith and king', 63), ('bruce inc', 63), ('stephens-braun', 62), ('long-alexander', 62), ('glass inc', 62), ('brown ltd', 62), ('baker group', 62), ('phelps graham and hayes', 61), ('mueller savage and hudson', 60), ('chambers-waters', 60), ('ayers llc', 60), ('wright llc', 59), ('smith-turner', 59), ('holloway-koch', 59), ('caldwell plc', 59), ('austin griffin and ward', 59), ('hodge-leblanc', 58), ('moody ltd', 57), ('lambert-wilson', 57), ('gray plc', 57), ('rogers-maldonado', 56), ('ramirez llc', 56), ('nguyen chan and brown', 56), ('wilson watkins and moore', 55), ('smith-morales', 55), ('rojas-cook', 55), ('phelps-schmidt', 55), ('meyer and sons', 55), ('martin tyler and wilkerson', 55), ('gutierrez a ...

# %% [markdown]
# ## Business Insights Using SQL Queries

# %% [markdown]
# #### Query 14: Which providers have donated the highest total quantity of food?

# %%
cursor.execute("""
SELECT p.Name, SUM(f.Quantity) AS Total_Donated
FROM providers p
JOIN food_listings f ON p.Provider_ID = f.Provider_ID
GROUP BY p.Name
ORDER BY Total_Donated DESC;
""")
print("14. Providers with highest total quantity donated:\n", cursor.fetchall())
# Out:
# 14. Providers with highest total quantity donated:
#  [('miller inc', 217), ('barry group', 179), ('evans wright and mitchell', 158), ('smith group', 150), ('campbell llc', 145), ('nelson llc', 142), ('ruiz-oneal', 140), ('blankenship-lewis', 124), ('kelly-ware', 123), ('bradford-martinez', 121), ('shepherd and sons', 116), ('hampton-lee', 116), ('jones ortega and rubio', 115), ('ortiz-lee', 114), ('johnson-ray', 113), ('barker llc', 110), ('moore group', 106), ('hill davis and stewart', 106), ('steele ltd', 104), ('butler-richardson', 104), ('lopez roach and roach', 102), ('hunter ballard and caldwell', 101), ('carter-jones', 101), ('hogan-johnston', 99), ('cox llc', 99), ('baker-mcdonald', 99), ('wong-reese', 98), ('jackson ltd', 98), ('aguilar-frederick', 98), ('schmidt-alexander', 97), ('phillips wolfe and martin', 97), ('garcia-hunter', 97), ('rogers harmon and gordon', 96), ('jones rojas and brown', 96), ('flores-wade', 96), ('clark prince and williams', 96), ('brown-stephens', 96), ('carey plc', 95), ('wilson group', 94), ('lambert ltd', 94), ('miller ltd', 93), ('hudson spence and perez', 93), ('doyle llc', 93), ('schneider-suarez', 92), ('miller johnson and fernandez', 92), ('coleman-farley', 92), ('white crawford and pearson', 91), ('kelly cummings and ward', 90), ('daniels-kim', 90), ('cooper llc', 90), ('rogers-warren', 89), ('mckinney ltd', 88), ('jones-miller', 88), ('davis-kennedy', 88), ('allen-mccullough', 88), ('young townsend and mccarthy', 87), ('torres-dunlap', 87), ('rogers robbins and cook', 87), ('davis hughes and leblanc', 87), ('glover wilson and hudson', 86), ('cooper osborn and clark', 86), ('barnes castro and curtis', 84), ('bowman llc', 83), ('smith lynch and anderson', 82), ('rios group', 82), ('webb phillips and garcia', 81), ('pollard collins and watson', 81), ('thompson group', 80), ('mcmillan gallegos and perry', 80), ('todd group', 79), ('maynard llc', 79), ('lee plc', 79), ('cook group', 79), ('butler-phillips', 79), ('wilson harris and mayo', 78), ('sanders-hale', 78), ('pierce group', 78), ('petersen morrison and woods', 78), ('munoz stone and wallace', 78), ('gonzales-cochran', 78), ('zhang llc', 76), ('nelson-white', 75), ('jones-edwards', 75), ('barnes and sons', 75), ('rowe-arias', 74), ('montgomery dominguez and hopkins', 74), ('douglas and sons', 74), ('oliver ross and johnson', 73), ('gonzales-keith', 73), ('dixon llc', 73), ('baird plc', 73), ('anderson nicholson and bruce', 73), ('thompson-kerr', 72), ('henry-terry', 72), ('crane llc', 71), ('jackson-robinson', 70), ('bray nguyen and christensen', 70), ('smith-paul', 69), ('porter inc', 69), ('wilkerson-woods', 68), ('snyder caldwell and campbell', 68), ('scott and sons', 68), ('holland and sons', 68), ('carr-wells', 68), ('owens-taylor', 67), ('simpson mcguire and brown', 66), ('aguilar group', 66), ('smith-villegas', 65), ('roberts howard and bender', 65), ('lewis preston and price', 65), ('cole llc', 65), ('richardson group', 64), ('morrison llc', 64), ('mitchell campbell and jones', 64), ('johnson-mejia', 64), ('hood hoffman and wright', 64), ('davis sanchez and mendez', 64), ('davila green and avila', 64), ('bennett phillips and green', 64), ('barrera-ward', 64), ('rodriguez thomas and foster', 63), ('moore perez and young', 63), ('cooper smith and king', 63), ('bruce inc', 63), ('stephens-braun', 62), ('long-alexander', 62), ('glass inc', 62), ('brown ltd', 62), ('baker group', 62), ('phelps graham and hayes', 61), ('mueller savage and hudson', 60), ('chambers-waters', 60), ('ayers llc', 60), ('wright llc', 59), ('smith-turner', 59), ('holloway-koch', 59), ('caldwell plc', 59), ('austin griffin and ward', 59), ('hodge-leblanc', 58), ('moody ltd', 57), ('lambert-wilson', 57), ('gray plc', 57), ('rogers-maldonado', 56), ('ramirez llc', 56), ('nguyen chan and brown', 56), ('wilson watkins and moore', 55), ('smith-morales', 55), ('rojas-cook', 55), ('phelps-schmidt', 55), ('meyer and sons', 55), ('martin tyler and wilkerson', 55), ('gutierrez anthony and shannon', 55), ('hunt-lee ...

# %% [markdown]
# #### Query 15: Which cities have the highest number of providers contributing food?

# %%
# Get the maximum number of providers first
cursor.execute("""
SELECT MAX(Num_Providers)
FROM (
    SELECT COUNT(*) AS Num_Providers
    FROM providers
    GROUP BY City
);
""")
max_count = cursor.fetchone()[0]

# Then get all cities with that maximum count
cursor.execute("""
SELECT City, COUNT(*) AS Num_Providers
FROM providers
GROUP BY City
HAVING Num_Providers = ?
""", (max_count,))
print("\n15. Cities with the highest number of providers:\n", cursor.fetchall())
# Out:
# 15. Cities with the highest number of providers:
#  [('new carol', 3), ('south christopherborough', 3)]

# %% [markdown]
# #### Query 16: How many providers have never made a claim?

# %%
cursor.execute("""
SELECT p.Name
FROM providers p
LEFT JOIN food_listings f ON p.Provider_ID = f.Provider_ID
LEFT JOIN claims c ON f.Food_ID = c.Food_ID
WHERE c.Claim_ID IS NULL;
""")
print("\n16. Providers who never had any claims:\n", cursor.fetchall())
# Out:
# 16. Providers who never had any claims:
#  [('nielsen johnson and fuller',), ('miller-black',), ('coleman-farley',), ('coleman-farley',), ('lawson-walters',), ('ortiz-lee',), ('ortiz-lee',), ('curtis-lewis',), ('hall nguyen and martinez',), ('flores jackson and ford',), ('miller ltd',), ('parker flores and jennings',), ('nguyen-tran',), ('valdez-diaz',), ('miller ltd',), ('edwards-turner',), ('davis ltd',), ('cross group',), ('miller-carter',), ('johnson ltd',), ('gutierrez-palmer',), ('lester inc',), ('wright ltd',), ('rodriguez plc',), ('lawrence plc',), ('miranda wilcox and short',), ('cooper smith and king',), ('powell inc',), ('phelps-schmidt',), ('lawrence llc',), ('robinson plc',), ('kelly-ware',), ('martinez johnson and torres',), ('torres-perez',), ('fisher hernandez and webster',), ('wong-reese',), ('shaw inc',), ('wolfe and sons',), ('cook group',), ('arnold russo and foster',), ('mitchell campbell and jones',), ('mullen llc',), ('fletcher inc',), ('shannon ltd',), ('sherman-wolfe',), ('williams plc',), ('cook stanley and wallace',), ('walker-richards',), ('johnston ltd',), ('johnston ltd',), ('douglas plc',), ('golden-phillips',), ('frazier llc',), ('holmes inc',), ('miller-moore',), ('harris ltd',), ('owens-williams',), ('oliver williams and rich',), ('stewart-page',), ('rivera llc',), ('cruz-day',), ('cuevas smith and rowe',), ('orr inc',), ('king-snyder',), ('hogan-johnston',), ('hogan-johnston',), ('walsh-day',), ('chambers-waters',), ('russell-summers',), ('carr-schaefer',), ('moreno group',), ('pollard tyler and davis',), ('pollard tyler and davis',), ('powell norton and james',), ('anderson nicholson and bruce',), ('barnett-graves',), ('mcdaniel-morales',), ('yates-mills',), ('glover inc',), ('mosley-hernandez',), ('jackson gonzalez and smith',), ('vasquez llc',), ('martinez-downs',), ('nelson-tran',), ('spencer martin and romero',), ('walker-knox',), ('baker llc',), ('gordon davis and gonzalez',), ('pena and sons',), ('jones rojas and brown',), ('johnson-ray',), ('johnson-ray',), ('rodriguez plc',), ('luna padilla and torres',), ('johnson harris and white',), ('rice-woods',), ('nguyen-shaffer',), ('perry cabrera and owens',), ('lee llc',), ('powers clark and snyder',), ('wu llc',), ('smith-turner',), ('bennett-parker',), ('johnson-thompson',), ('rodriguez walker and singleton',), ('wagner cole and thompson',), ('baker warren and kirk',), ('campbell llc',), ('campbell llc',), ('moore perez and young',), ('moore perez and young',), ('jackson-bishop',), ('silva group',), ('king smith and mullen',), ('miller williams and lewis',), ('peters chase and davis',), ('jones delgado and marquez',), ('parker macdonald and espinoza',), ('greene group',), ('gillespie foster and boyd',), ('olson ltd',), ('turner-ramirez',), ('mcbride-rogers',), ('lucas bush and miller',), ('deleon guzman and porter',), ('wilson-ortiz',), ('wilson-ortiz',), ('collins williams and fernandez',), ('brown ltd',), ('blackwell ltd',), ('elliott-mcguire',), ('hunter ballard and caldwell',), ('lambert-gonzalez',), ('dodson and sons',), ('turner-woods',), ('ramirez llc',), ('bass-sellers',), ('thompson group',), ('walters jackson and webster',), ('hubbard clark and hicks',), ('kelley plc',), ('potter brown and torres',), ('williams ltd',), ('aguilar and sons',), ('rivera-nelson',), ('robinson and sons',), ('hughes-jackson',), ('stevens-rogers',), ('hart plc',), ('stewart-soto',), ('thompson ltd',), ('snyder caldwell and campbell',), ('jones-wu',), ('sherman-baker',), ('singleton andrews and bell',), ('white crawford and pearson',), ('aguilar-frederick',), ('robinson group',), ('shepherd-yates',), ('davis sanchez and hernandez',), ('lewis-peters',), ('gonzales-keith',), ('chapman barrett and lopez',), ('hayes ltd',), ('gonzales-moore',), ('lewis pierce and wilson',), ('rice-dawson',), ('lopez davis and duncan',), ('bradford-martinez',), ('bradford-martinez',), ('lutz smith and martin',), ('holland and sons',), ('thomas-carpenter',), ('jackson and sons',), ('barrera jenkins and boyd',), ('hol ...

# %% [markdown]
# #### Query 17: Which receivers have not claimed any food yet?

# %%
cursor.execute("""
SELECT r.Name
FROM receivers r
LEFT JOIN claims c ON r.Receiver_ID = c.Receiver_ID
WHERE c.Claim_ID IS NULL;
""")
print("\n17. Receivers who haven’t claimed any food:\n", cursor.fetchall())
# Out:
# 17. Receivers who haven’t claimed any food:
#  [('john romero',), ('james perez',), ('amber pacheco',), ('jamie sutton',), ('melissa castillo',), ('lisa williams',), ('courtney sanders',), ('george palmer',), ('emily davidson',), ('kristina meza',), ('kurt ward',), ('tammy moore',), ('lisa mcclain',), ('nicholas robinson',), ('bruce sanchez',), ('teresa davis',), ('john ramirez',), ('abigail davis',), ('julia elliott',), ('kevin lee',), ('gabriel nicholson',), ('timothy clark',), ('veronica howard',), ('erika rodriguez',), ('jessica rivas',), ('john vazquez',), ('debra sheppard',), ('rodney walker',), ('carolyn whitaker',), ('timothy daniel',), ('kimberly mills',), ('anna lopez',), ('aaron davis',), ('meagan ramirez',), ('eric jackson',), ('theresa ramirez',), ('laura bennett',), ('julie hines',), ('deanna lewis',), ('jeffery mueller',), ('mr david lambert',), ('ashley james',), ('bridget peterson',), ('anthony green',), ('david johnson',), ('suzanne dawson',), ('karla castillo',), ('deanna flores',), ('john chase',), ('anthony carter',), ('kelly pierce',), ('matthew ramos',), ('gavin freeman',), ('teresa williams',), ('robert johnson',), ('jeanne spencer',), ('katherine murphy',), ('james jones',), ('christine gray',), ('melody good',), ('amanda hendricks',), ('john cummings',), ('sara wise',), ('robert simon',), ('jason holmes',), ('christopher kennedy',), ('jason davis',), ('jennifer anderson',), ('danielle bailey',), ('danielle willis',), ('erica fox',), ('jon stanton',), ('stephanie hoffman',), ('tonya lucas',), ('deanna jarvis',), ('adam hodge',), ('troy miller',), ('john massey',), ('tina ingram',), ('deanna james',), ('scott anderson',), ('nicole williams',), ('ashley brooks',), ('nicholas holloway',), ('michael flores',), ('gina payne',), ('tara mcmahon',), ('kelsey holloway dds',), ('franklin kelley',), ('nathaniel moreno',), ('christopher barrett',), ('david smith',), ('keith atkinson',), ('duane burnett',), ('kendra krause',), ('alexis smith',), ('jason ramos',), ('john mitchell',), ('victoria lee',), ('sarah hodges',), ('angela dunlap',), ('adam pittman',), ('david bryant',), ('patricia white',), ('maria lang',), ('ann mcclure',), ('sandra townsend dvm',), ('rebecca may',), ('steven morton jr',), ('darlene fernandez',), ('jonathan soto',), ('austin jones',), ('jay roberts',), ('jesse miller',), ('beth sanchez',), ('travis hughes',), ('christopher larsen',), ('nathan reynolds',), ('karen brennan',), ('dawn thompson',), ('pamela santos',), ('jennifer ayala',), ('logan becker',), ('bryan smith',), ('tina jackson',), ('pamela morales',), ('david marsh',), ('anthony harris',), ('jacob montoya',), ('lawrence owens',), ('douglas jacobs',), ('raymond harris',), ('gabriel vargas',), ('gina wu dds',), ('deborah sexton',), ('patrick zimmerman',), ('john baxter',), ('roberto stanley',), ('mr mark knight dvm',), ('gwendolyn johnson',), ('brian cherry',), ('travis walker',), ('stephanie west',), ('keith gray',), ('melissa green',), ('tony holmes',), ('sherry hall',), ('melissa kennedy',), ('michael proctor',), ('dana simmons',), ('nicholas mosley md',), ('john collins',), ('david evans',), ('eric kaiser',), ('jonathan copeland',), ('tina bean',), ('toni johnson',), ('elizabeth galvan',), ('april johnson',), ('mr gregory thompson',), ('michael dunn',), ('jason alvarez',), ('cynthia johnson',), ('brittany anderson',), ('michael simmons',), ('christopher williams',), ('erika west',), ('russell smith',), ('kristen alvarado',), ('rodney perkins',), ('ryan cole',), ('tonya lewis',), ('frank jackson',), ('richard parsons',), ('makayla davis',), ('christine ashley',), ('steven martinez',), ('edwin osborne',), ('david fuentes',), ('christine lawrence',), ('jennifer baker',), ('benjamin wilson',), ('ronald brown',), ('tiffany smith',), ('molly edwards',), ('kristina park',), ('dennis ford',), ('william davila',), ('carly austin',), ('michael williams',), ('mrs kim blackwell',), ('dr ryan gilbert',), ('misty downs',), ('gary myers',), ('katrina smith',), ('elizabeth salazar',), ('ale ...

# %% [markdown]
# #### Query 18: How many providers have not claimed any food yet?

# %%
cursor.execute("""
SELECT p.Name
FROM providers p
LEFT JOIN food_listings f ON p.Provider_ID = f.Provider_ID
LEFT JOIN claims c ON f.Food_ID = c.Food_ID
WHERE c.Claim_ID IS NULL;
""")
print("\n1. Providers who never made a claim:\n", cursor.fetchall())
# Out:
# 1. Providers who never made a claim:
#  [('nielsen johnson and fuller',), ('miller-black',), ('coleman-farley',), ('coleman-farley',), ('lawson-walters',), ('ortiz-lee',), ('ortiz-lee',), ('curtis-lewis',), ('hall nguyen and martinez',), ('flores jackson and ford',), ('miller ltd',), ('parker flores and jennings',), ('nguyen-tran',), ('valdez-diaz',), ('miller ltd',), ('edwards-turner',), ('davis ltd',), ('cross group',), ('miller-carter',), ('johnson ltd',), ('gutierrez-palmer',), ('lester inc',), ('wright ltd',), ('rodriguez plc',), ('lawrence plc',), ('miranda wilcox and short',), ('cooper smith and king',), ('powell inc',), ('phelps-schmidt',), ('lawrence llc',), ('robinson plc',), ('kelly-ware',), ('martinez johnson and torres',), ('torres-perez',), ('fisher hernandez and webster',), ('wong-reese',), ('shaw inc',), ('wolfe and sons',), ('cook group',), ('arnold russo and foster',), ('mitchell campbell and jones',), ('mullen llc',), ('fletcher inc',), ('shannon ltd',), ('sherman-wolfe',), ('williams plc',), ('cook stanley and wallace',), ('walker-richards',), ('johnston ltd',), ('johnston ltd',), ('douglas plc',), ('golden-phillips',), ('frazier llc',), ('holmes inc',), ('miller-moore',), ('harris ltd',), ('owens-williams',), ('oliver williams and rich',), ('stewart-page',), ('rivera llc',), ('cruz-day',), ('cuevas smith and rowe',), ('orr inc',), ('king-snyder',), ('hogan-johnston',), ('hogan-johnston',), ('walsh-day',), ('chambers-waters',), ('russell-summers',), ('carr-schaefer',), ('moreno group',), ('pollard tyler and davis',), ('pollard tyler and davis',), ('powell norton and james',), ('anderson nicholson and bruce',), ('barnett-graves',), ('mcdaniel-morales',), ('yates-mills',), ('glover inc',), ('mosley-hernandez',), ('jackson gonzalez and smith',), ('vasquez llc',), ('martinez-downs',), ('nelson-tran',), ('spencer martin and romero',), ('walker-knox',), ('baker llc',), ('gordon davis and gonzalez',), ('pena and sons',), ('jones rojas and brown',), ('johnson-ray',), ('johnson-ray',), ('rodriguez plc',), ('luna padilla and torres',), ('johnson harris and white',), ('rice-woods',), ('nguyen-shaffer',), ('perry cabrera and owens',), ('lee llc',), ('powers clark and snyder',), ('wu llc',), ('smith-turner',), ('bennett-parker',), ('johnson-thompson',), ('rodriguez walker and singleton',), ('wagner cole and thompson',), ('baker warren and kirk',), ('campbell llc',), ('campbell llc',), ('moore perez and young',), ('moore perez and young',), ('jackson-bishop',), ('silva group',), ('king smith and mullen',), ('miller williams and lewis',), ('peters chase and davis',), ('jones delgado and marquez',), ('parker macdonald and espinoza',), ('greene group',), ('gillespie foster and boyd',), ('olson ltd',), ('turner-ramirez',), ('mcbride-rogers',), ('lucas bush and miller',), ('deleon guzman and porter',), ('wilson-ortiz',), ('wilson-ortiz',), ('collins williams and fernandez',), ('brown ltd',), ('blackwell ltd',), ('elliott-mcguire',), ('hunter ballard and caldwell',), ('lambert-gonzalez',), ('dodson and sons',), ('turner-woods',), ('ramirez llc',), ('bass-sellers',), ('thompson group',), ('walters jackson and webster',), ('hubbard clark and hicks',), ('kelley plc',), ('potter brown and torres',), ('williams ltd',), ('aguilar and sons',), ('rivera-nelson',), ('robinson and sons',), ('hughes-jackson',), ('stevens-rogers',), ('hart plc',), ('stewart-soto',), ('thompson ltd',), ('snyder caldwell and campbell',), ('jones-wu',), ('sherman-baker',), ('singleton andrews and bell',), ('white crawford and pearson',), ('aguilar-frederick',), ('robinson group',), ('shepherd-yates',), ('davis sanchez and hernandez',), ('lewis-peters',), ('gonzales-keith',), ('chapman barrett and lopez',), ('hayes ltd',), ('gonzales-moore',), ('lewis pierce and wilson',), ('rice-dawson',), ('lopez davis and duncan',), ('bradford-martinez',), ('bradford-martinez',), ('lutz smith and martin',), ('holland and sons',), ('thomas-carpenter',), ('jackson and sons',), ('barrera jenkins and boyd',), ('hol ...

# %% [markdown]
# #### Query 19: Which providers consistently list food items with near-expiry dates?

# %%
cursor.execute("""
SELECT p.Name, f.Food_Name, f.Expiry_Date
FROM food_listings f
JOIN providers p ON f.Provider_ID = p.Provider_ID
WHERE DATE(f.Expiry_Date) <= DATE('now', '+7 days')
ORDER BY f.Expiry_Date ASC;
""")
print("\n19. Providers listing near-expiry items (within 7 days):\n", cursor.fetchall())
# Out:
# 19. Providers listing near-expiry items (within 7 days):
#  [('cannon-garcia', 'Fruits', '2025-03-16'), ('moore-flowers', 'Soup', '2025-03-16'), ('lucas bush and miller', 'Rice', '2025-03-16'), ('powers clark and snyder', 'Rice', '2025-03-16'), ('gillespie foster and boyd', 'Fruits', '2025-03-16'), ('small ltd', 'Bread', '2025-03-16'), ('maldonado-davis', 'Rice', '2025-03-16'), ('ayers llc', 'Pasta', '2025-03-16'), ('jackson ltd', 'Pasta', '2025-03-16'), ('young-luna', 'Rice', '2025-03-16'), ('williams inc', 'Soup', '2025-03-16'), ('fernandez-bridges', 'Rice', '2025-03-16'), ('miller inc', 'Chicken', '2025-03-16'), ('carter-jones', 'Bread', '2025-03-16'), ('wong-reese', 'Rice', '2025-03-16'), ('yoder-murray', 'Vegetables', '2025-03-16'), ('barnes castro and curtis', 'Fruits', '2025-03-16'), ('schmidt-alexander', 'Rice', '2025-03-16'), ('conway-barr', 'Chicken', '2025-03-16'), ('johnson group', 'Bread', '2025-03-16'), ('nichols-barnes', 'Salad', '2025-03-16'), ('lambert ltd', 'Dairy', '2025-03-16'), ('rogers harmon and gordon', 'Salad', '2025-03-16'), ('roberts howard and bender', 'Fruits', '2025-03-16'), ('cooper llc', 'Fruits', '2025-03-16'), ('aguilar-frederick', 'Dairy', '2025-03-16'), ('mitchell-watson', 'Chicken', '2025-03-16'), ('wilson harris and mayo', 'Fruits', '2025-03-16'), ('rojas-cook', 'Rice', '2025-03-16'), ('shepherd and sons', 'Soup', '2025-03-16'), ('callahan-olsen', 'Vegetables', '2025-03-16'), ('hampton-lee', 'Salad', '2025-03-16'), ('henderson group', 'Fish', '2025-03-16'), ('todd group', 'Fish', '2025-03-16'), ('thompson group', 'Bread', '2025-03-16'), ('carlson-mathis', 'Soup', '2025-03-16'), ('ward shepherd and krause', 'Pasta', '2025-03-16'), ('ferguson henderson and watson', 'Dairy', '2025-03-16'), ('maynard llc', 'Fruits', '2025-03-16'), ('giles weiss and brown', 'Salad', '2025-03-16'), ('williams-cox', 'Salad', '2025-03-16'), ('cannon-garcia', 'Fish', '2025-03-16'), ('lee walker and woodward', 'Fish', '2025-03-16'), ('russell and sons', 'Dairy', '2025-03-16'), ('ruiz-oneal', 'Bread', '2025-03-16'), ('mckinney ltd', 'Bread', '2025-03-16'), ('butler-richardson', 'Fish', '2025-03-16'), ('scott and sons', 'Salad', '2025-03-16'), ('house james and miller', 'Dairy', '2025-03-16'), ('mendoza-espinoza', 'Chicken', '2025-03-16'), ('thomas-carpenter', 'Soup', '2025-03-16'), ('olson ltd', 'Chicken', '2025-03-16'), ('hudson spence and perez', 'Rice', '2025-03-16'), ('marshall ltd', 'Rice', '2025-03-16'), ('martinez armstrong and carroll', 'Fish', '2025-03-16'), ('evans-harrison', 'Vegetables', '2025-03-16'), ('stewart cox and tate', 'Fish', '2025-03-16'), ('carey plc', 'Fruits', '2025-03-16'), ('smith james and alvarado', 'Fruits', '2025-03-16'), ('sanders-hale', 'Pasta', '2025-03-16'), ('frazier-sanders', 'Bread', '2025-03-16'), ('figueroa-soto', 'Bread', '2025-03-17'), ('pierce walsh and rogers', 'Pasta', '2025-03-17'), ('evans wright and mitchell', 'Pasta', '2025-03-17'), ('snyder ltd', 'Salad', '2025-03-17'), ('webster and sons', 'Fish', '2025-03-17'), ('smith-villegas', 'Soup', '2025-03-17'), ('miller inc', 'Vegetables', '2025-03-17'), ('anderson and sons', 'Chicken', '2025-03-17'), ('rowe-arias', 'Salad', '2025-03-17'), ('smith-morales', 'Soup', '2025-03-17'), ('martinez plc', 'Rice', '2025-03-17'), ('butler-phillips', 'Bread', '2025-03-17'), ('martin tyler and wilkerson', 'Soup', '2025-03-17'), ('bradley-smith', 'Fruits', '2025-03-17'), ('evans wright and mitchell', 'Pasta', '2025-03-17'), ('shah group', 'Vegetables', '2025-03-17'), ('chan-elliott', 'Vegetables', '2025-03-17'), ('torres ltd', 'Bread', '2025-03-17'), ('elliott-jones', 'Pasta', '2025-03-17'), ('huber group', 'Rice', '2025-03-17'), ('freeman allen and castaneda', 'Salad', '2025-03-17'), ('white crawford and pearson', 'Vegetables', '2025-03-17'), ('wright llc', 'Chicken', '2025-03-17'), ('mcmillan gallegos and perry', 'Soup', '2025-03-17'), ('brown ltd', 'Pasta', '2025-03-17'), ('wright-hogan', 'Rice', '2025-03-17'), ('hancock-jackson', 'Dairy', '2025-03-17'), ('osborne llc', 'Dairy', '2025-03-17'), ...

# %% [markdown]
# #### Query 20: How many food items are expiring within the next 7 days?

# %%
cursor.execute("""
SELECT Food_Name, Expiry_Date
FROM food_listings
WHERE DATE(Expiry_Date) <= DATE('now', '+7 days')
ORDER BY Expiry_Date ASC;
""")
print("\n20. Food items expiring within next 7 days:\n", cursor.fetchall())
# Out:
# 20. Food items expiring within next 7 days:
#  [('Fruits', '2025-03-16'), ('Soup', '2025-03-16'), ('Rice', '2025-03-16'), ('Rice', '2025-03-16'), ('Fruits', '2025-03-16'), ('Bread', '2025-03-16'), ('Rice', '2025-03-16'), ('Pasta', '2025-03-16'), ('Pasta', '2025-03-16'), ('Rice', '2025-03-16'), ('Soup', '2025-03-16'), ('Rice', '2025-03-16'), ('Chicken', '2025-03-16'), ('Bread', '2025-03-16'), ('Rice', '2025-03-16'), ('Vegetables', '2025-03-16'), ('Fruits', '2025-03-16'), ('Rice', '2025-03-16'), ('Chicken', '2025-03-16'), ('Bread', '2025-03-16'), ('Salad', '2025-03-16'), ('Dairy', '2025-03-16'), ('Salad', '2025-03-16'), ('Fruits', '2025-03-16'), ('Fruits', '2025-03-16'), ('Dairy', '2025-03-16'), ('Chicken', '2025-03-16'), ('Fruits', '2025-03-16'), ('Rice', '2025-03-16'), ('Soup', '2025-03-16'), ('Vegetables', '2025-03-16'), ('Salad', '2025-03-16'), ('Fish', '2025-03-16'), ('Fish', '2025-03-16'), ('Bread', '2025-03-16'), ('Soup', '2025-03-16'), ('Pasta', '2025-03-16'), ('Dairy', '2025-03-16'), ('Fruits', '2025-03-16'), ('Salad', '2025-03-16'), ('Salad', '2025-03-16'), ('Fish', '2025-03-16'), ('Fish', '2025-03-16'), ('Dairy', '2025-03-16'), ('Bread', '2025-03-16'), ('Bread', '2025-03-16'), ('Fish', '2025-03-16'), ('Salad', '2025-03-16'), ('Dairy', '2025-03-16'), ('Chicken', '2025-03-16'), ('Soup', '2025-03-16'), ('Chicken', '2025-03-16'), ('Rice', '2025-03-16'), ('Rice', '2025-03-16'), ('Fish', '2025-03-16'), ('Vegetables', '2025-03-16'), ('Fish', '2025-03-16'), ('Fruits', '2025-03-16'), ('Fruits', '2025-03-16'), ('Pasta', '2025-03-16'), ('Bread', '2025-03-16'), ('Bread', '2025-03-17'), ('Pasta', '2025-03-17'), ('Pasta', '2025-03-17'), ('Salad', '2025-03-17'), ('Fish', '2025-03-17'), ('Soup', '2025-03-17'), ('Vegetables', '2025-03-17'), ('Chicken', '2025-03-17'), ('Salad', '2025-03-17'), ('Soup', '2025-03-17'), ('Rice', '2025-03-17'), ('Bread', '2025-03-17'), ('Soup', '2025-03-17'), ('Fruits', '2025-03-17'), ('Pasta', '2025-03-17'), ('Vegetables', '2025-03-17'), ('Vegetables', '2025-03-17'), ('Bread', '2025-03-17'), ('Pasta', '2025-03-17'), ('Rice', '2025-03-17'), ('Salad', '2025-03-17'), ('Vegetables', '2025-03-17'), ('Chicken', '2025-03-17'), ('Soup', '2025-03-17'), ('Pasta', '2025-03-17'), ('Rice', '2025-03-17'), ('Dairy', '2025-03-17'), ('Dairy', '2025-03-17'), ('Pasta', '2025-03-17'), ('Dairy', '2025-03-17'), ('Dairy', '2025-03-17'), ('Dairy', '2025-03-17'), ('Soup', '2025-03-17'), ('Salad', '2025-03-17'), ('Soup', '2025-03-17'), ('Dairy', '2025-03-17'), ('Vegetables', '2025-03-17'), ('Dairy', '2025-03-17'), ('Salad', '2025-03-17'), ('Fruits', '2025-03-17'), ('Salad', '2025-03-17'), ('Fish', '2025-03-17'), ('Vegetables', '2025-03-17'), ('Vegetables', '2025-03-17'), ('Pasta', '2025-03-17'), ('Fruits', '2025-03-17'), ('Salad', '2025-03-17'), ('Vegetables', '2025-03-17'), ('Bread', '2025-03-17'), ('Dairy', '2025-03-17'), ('Pasta', '2025-03-17'), ('Fish', '2025-03-17'), ('Soup', '2025-03-17'), ('Soup', '2025-03-17'), ('Fish', '2025-03-17'), ('Pasta', '2025-03-17'), ('Dairy', '2025-03-17'), ('Chicken', '2025-03-17'), ('Chicken', '2025-03-17'), ('Bread', '2025-03-17'), ('Fruits', '2025-03-17'), ('Bread', '2025-03-17'), ('Fruits', '2025-03-17'), ('Chicken', '2025-03-17'), ('Pasta', '2025-03-17'), ('Fish', '2025-03-17'), ('Bread', '2025-03-17'), ('Dairy', '2025-03-17'), ('Vegetables', '2025-03-17'), ('Rice', '2025-03-17'), ('Chicken', '2025-03-17'), ('Fruits', '2025-03-18'), ('Vegetables', '2025-03-18'), ('Rice', '2025-03-18'), ('Dairy', '2025-03-18'), ('Fish', '2025-03-18'), ('Soup', '2025-03-18'), ('Bread', '2025-03-18'), ('Pasta', '2025-03-18'), ('Soup', '2025-03-18'), ('Dairy', '2025-03-18'), ('Fish', '2025-03-18'), ('Fish', '2025-03-18'), ('Fish', '2025-03-18'), ('Salad', '2025-03-18'), ('Pasta', '2025-03-18'), ('Vegetables', '2025-03-18'), ('Chicken', '2025-03-18'), ('Rice', '2025-03-18'), ('Pasta', '2025-03-18'), ('Vegetables', '2025-03-18'), ('Soup', '2025-03-18'), ('Salad', '2025-03-18'), ('Soup', '2025-03-18'), ('Dairy', '2025-03-18'), ('Fruits', '2025-03-18'), ('Fish' ...

# %% [markdown]
# #### Query 21: Which meal types are most frequently listed in each city?

# %%
cursor.execute("""
SELECT Location, Meal_Type, COUNT(*) AS Count
FROM food_listings
GROUP BY Location, Meal_Type
ORDER BY Location, Count DESC;
""")
print("\n21. Most frequently listed meal types per city:\n", cursor.fetchall())
# Out:
# 21. Most frequently listed meal types per city:
#  [('Adambury', 'Lunch', 1), ('Alexanderchester', 'Dinner', 1), ('Allenborough', 'Dinner', 1), ('Allenton', 'Snacks', 1), ('Allenton', 'Lunch', 1), ('Allenton', 'Breakfast', 1), ('Amandashire', 'Breakfast', 1), ('Amberton', 'Lunch', 1), ('Amberton', 'Dinner', 1), ('Andersonmouth', 'Breakfast', 1), ('Andersonville', 'Snacks', 1), ('Andreaborough', 'Snacks', 1), ('Andreaborough', 'Dinner', 1), ('Andrewsmouth', 'Dinner', 1), ('Annahaven', 'Lunch', 1), ('Anneville', 'Lunch', 3), ('Anthonyborough', 'Snacks', 1), ('Anthonyhaven', 'Snacks', 1), ('Anthonyshire', 'Dinner', 1), ('Anthonyton', 'Snacks', 1), ('Aprilberg', 'Lunch', 1), ('Ashleyhaven', 'Snacks', 1), ('Bairdfort', 'Snacks', 1), ('Bartonborough', 'Snacks', 1), ('Bartonborough', 'Lunch', 1), ('Basstown', 'Lunch', 1), ('Basstown', 'Breakfast', 1), ('Batesstad', 'Snacks', 1), ('Belindaville', 'Lunch', 1), ('Belindaville', 'Breakfast', 1), ('Bellport', 'Snacks', 1), ('Bellport', 'Lunch', 1), ('Benjaminstad', 'Snacks', 1), ('Bentleyburgh', 'Lunch', 3), ('Bentonfurt', 'Breakfast', 1), ('Blaketown', 'Lunch', 1), ('Blaketown', 'Dinner', 1), ('Bonillahaven', 'Breakfast', 1), ('Boylechester', 'Lunch', 1), ('Bradleyport', 'Snacks', 2), ('Bradleyport', 'Lunch', 1), ('Brandyberg', 'Lunch', 2), ('Brendantown', 'Snacks', 1), ('Brianside', 'Lunch', 1), ('Brittanyland', 'Snacks', 1), ('Brittanyland', 'Dinner', 1), ('Brittanyport', 'Breakfast', 1), ('Brittanyside', 'Breakfast', 2), ('Brittanyside', 'Lunch', 1), ('Brittanyville', 'Snacks', 1), ('Brittanyville', 'Dinner', 1), ('Brookeland', 'Snacks', 1), ('Brookeland', 'Dinner', 1), ('Brownberg', 'Lunch', 1), ('Brownchester', 'Breakfast', 1), ('Brownshire', 'Dinner', 1), ('Browntown', 'Snacks', 1), ('Callahanside', 'Breakfast', 1), ('Cameronside', 'Lunch', 1), ('Cameronside', 'Breakfast', 1), ('Cannonside', 'Snacks', 1), ('Carlborough', 'Dinner', 1), ('Carlbury', 'Breakfast', 2), ('Carolchester', 'Dinner', 3), ('Carrport', 'Dinner', 1), ('Castilloport', 'Snacks', 2), ('Castilloport', 'Lunch', 1), ('Chambersfort', 'Dinner', 1), ('Charlesmouth', 'Lunch', 1), ('Charlesview', 'Dinner', 1), ('Chelseaside', 'Snacks', 1), ('Chelseyfort', 'Snacks', 1), ('Chelseyfort', 'Dinner', 1), ('Christinaland', 'Dinner', 1), ('Christinamouth', 'Breakfast', 1), ('Christinetown', 'Dinner', 1), ('Christopherstad', 'Dinner', 1), ('Christopherton', 'Lunch', 1), ('Cisnerostown', 'Snacks', 1), ('Cisnerostown', 'Lunch', 1), ('Cisnerostown', 'Breakfast', 1), ('Clarkberg', 'Dinner', 2), ('Clarkberg', 'Breakfast', 1), ('Coleburgh', 'Snacks', 1), ('Coleburgh', 'Dinner', 1), ('Coleburgh', 'Breakfast', 1), ('Colemanton', 'Dinner', 2), ('Collinsmouth', 'Dinner', 1), ('Connieside', 'Lunch', 1), ('Cordovaborough', 'Dinner', 1), ('Crystalborough', 'Snacks', 1), ('Cunninghambury', 'Lunch', 1), ('Danachester', 'Breakfast', 1), ('Darrylchester', 'Snacks', 1), ('Darrylchester', 'Lunch', 1), ('Davidborough', 'Dinner', 2), ('Davidland', 'Breakfast', 1), ('Davidport', 'Lunch', 1), ('Davidville', 'Breakfast', 4), ('Davisview', 'Snacks', 1), ('Deborahfurt', 'Lunch', 1), ('Deborahland', 'Breakfast', 1), ('Deckermouth', 'Snacks', 1), ('Derekport', 'Lunch', 1), ('Devinmouth', 'Lunch', 2), ('Devinmouth', 'Dinner', 1), ('Donnaborough', 'Snacks', 2), ('Donnaborough', 'Dinner', 1), ('East Aaron', 'Snacks', 1), ('East Aaron', 'Dinner', 1), ('East Amyfurt', 'Lunch', 1), ('East Andrea', 'Breakfast', 2), ('East Andrea', 'Dinner', 1), ('East Andrewland', 'Lunch', 2), ('East Andrewland', 'Snacks', 1), ('East Angela', 'Snacks', 2), ('East Angela', 'Lunch', 1), ('East Angela', 'Dinner', 1), ('East Angela', 'Breakfast', 1), ('East Angelafort', 'Snacks', 1), ('East Angelafort', 'Breakfast', 1), ('East Anthony', 'Snacks', 1), ('East Anthony', 'Lunch', 1), ('East Ashleyshire', 'Snacks', 1), ('East Ashleyshire', 'Breakfast', 1), ('East Austin', 'Breakfast', 2), ('East Austin', 'Snacks', 1), ('East Bernard', 'Lunch', 1), ('East Brittanyland', 'Snacks', 2), ('East Candace', 'Breakfast', 2), ('East Christophertown' ...

# %% [markdown]
# #### Query 22: Which receivers claim the most diverse types of food (variety of Food_Type)?

# %%
cursor.execute("""
SELECT MAX(Food_Variety)
FROM (
    SELECT r.Name, COUNT(DISTINCT f.Food_Type) AS Food_Variety
    FROM receivers r
    JOIN claims c ON r.Receiver_ID = c.Receiver_ID
    JOIN food_listings f ON c.Food_ID = f.Food_ID
    GROUP BY r.Name
);
""")
max_variety = cursor.fetchone()[0]

# Then get all receivers with that maximum variety
cursor.execute("""
SELECT r.Name, COUNT(DISTINCT f.Food_Type) AS Food_Variety
FROM receivers r
JOIN claims c ON r.Receiver_ID = c.Receiver_ID
JOIN food_listings f ON c.Food_ID = f.Food_ID
GROUP BY r.Name
HAVING Food_Variety = ?
""", (max_variety,))
print("\n22. Receivers claiming most diverse food types:\n", cursor.fetchall())
# Out:
# 22. Receivers claiming most diverse food types:
#  [('abigail crawford', 3), ('alexander walsh', 3), ('alexandra rogers', 3), ('alicia porter', 3), ('allison pennington', 3), ('anna buckley', 3), ('arthur thomas', 3), ('bruce alexander', 3), ('christine davis', 3), ('donald caldwell', 3), ('donna hughes', 3), ('james brown', 3), ('james miller', 3), ('jennifer nelson', 3), ('justin powell', 3), ('kimberly nelson', 3), ('matthew tran', 3), ('michael walls', 3), ('oscar bauer', 3), ('samuel lewis', 3), ('sarah carter', 3), ('scott hunter', 3), ('scott schroeder', 3), ('vanessa johnson', 3), ('victor crawford', 3), ('victor diaz', 3), ('william frederick', 3)]

# %% [markdown]
# #### Query 23: What is the ratio of claimed vs. unclaimed food per provider?

# %%
cursor.execute("""
SELECT p.Name,
       SUM(CASE WHEN c.Claim_ID IS NOT NULL THEN 1 ELSE 0 END) AS Claimed,
       SUM(CASE WHEN c.Claim_ID IS NULL THEN 1 ELSE 0 END) AS Unclaimed
FROM providers p
JOIN food_listings f ON p.Provider_ID = f.Provider_ID
LEFT JOIN claims c ON f.Food_ID = c.Food_ID
GROUP BY p.Name;
""")
print("\n23. Claimed vs unclaimed food per provider:\n", cursor.fetchall())
# Out:
# 23. Claimed vs unclaimed food per provider:
#  [('abbott brooks and moreno', 1, 0), ('abbott-robinson', 0, 1), ('adams-meyer', 0, 1), ('adams-young', 0, 1), ('aguilar group', 0, 2), ('aguilar-frederick', 3, 1), ('alexander plc', 2, 0), ('alexander-mendoza', 1, 0), ('allen llc', 0, 1), ('allen ramsey and cortez', 2, 0), ('allen zimmerman and harrington', 2, 0), ('allen-mccullough', 7, 0), ('alvarado llc', 2, 0), ('anderson adams and roberts', 4, 1), ('anderson and sons', 0, 1), ('anderson nicholson and bruce', 3, 1), ('anderson patrick and scott', 1, 0), ('anderson robinson and phillips', 1, 0), ('andrews inc', 0, 1), ('andrews-wiley', 1, 0), ('arroyo-henderson', 1, 0), ('atkins group', 2, 0), ('austin griffin and ward', 2, 0), ('austin-yu', 1, 0), ('avery plc', 1, 0), ('avila group', 2, 0), ('ayala llc', 3, 0), ('ayers llc', 0, 2), ('ayers-lewis', 0, 1), ('baird plc', 1, 2), ('baker gardner and callahan', 1, 0), ('baker group', 2, 0), ('baker llc', 2, 1), ('baker-mcdonald', 2, 2), ('ball-church', 1, 0), ('ballard stanley and hill', 2, 1), ('barber ltd', 3, 0), ('barker gibbs and lopez', 2, 0), ('barker llc', 2, 1), ('barnes and sons', 3, 0), ('barnes castro and curtis', 5, 1), ('barrera-ward', 2, 1), ('barry group', 7, 2), ('barry powers and white', 2, 1), ('bates-johnson', 1, 1), ('beck group', 1, 0), ('beck inc', 4, 0), ('bell-newman', 0, 1), ('bender jordan and bennett', 2, 0), ('bennett inc', 0, 1), ('bennett phillips and green', 2, 0), ('bennett-parker', 0, 1), ('berry-mack', 4, 0), ('bishop martinez and robinson', 0, 1), ('black collins and richard', 3, 0), ('black group', 0, 1), ('black montgomery and hernandez', 2, 0), ('blackwell ltd', 0, 1), ('blair group', 1, 0), ('blair llc', 2, 0), ('blanchard-parsons', 2, 0), ('blankenship-lewis', 3, 1), ('booker ltd', 0, 1), ('bowers gonzalez and simmons', 1, 1), ('bowman llc', 5, 0), ('boyd padilla and simpson', 0, 1), ('bradford-martinez', 5, 2), ('bradley-smith', 0, 1), ('bray nguyen and christensen', 1, 1), ('brock newton and mccormick', 1, 0), ('brooks-mccarty', 1, 0), ('brown and sons', 2, 0), ('brown ltd', 2, 1), ('brown-butler', 0, 1), ('brown-grimes', 3, 0), ('brown-stephens', 2, 1), ('bruce inc', 2, 0), ('bryant jacobson and west', 1, 1), ('buck-carey', 1, 0), ('burke yates and hicks', 0, 1), ('burns-davis', 1, 0), ('butler kennedy and cowan', 1, 0), ('butler-newman', 1, 0), ('butler-phillips', 2, 0), ('butler-richardson', 12, 1), ('calderon-torres', 0, 1), ('caldwell plc', 4, 0), ('callahan-olsen', 1, 0), ('campbell llc', 5, 4), ('cannon-garcia', 0, 2), ('carey plc', 4, 0), ('carey-ramos', 1, 1), ('carey-richardson', 3, 0), ('carlson-mathis', 2, 0), ('carpenter-wright', 2, 0), ('carr-wells', 0, 2), ('carroll-stanley', 2, 0), ('carter-jones', 5, 0), ('chambers-waters', 3, 1), ('chan group', 0, 2), ('chan plc', 0, 1), ('chan-elliott', 3, 0), ('chandler-roberts', 2, 0), ('chapman barrett and lopez', 0, 1), ('chase-gross', 1, 0), ('chung morris and craig', 1, 0), ('clark evans and navarro', 2, 0), ('clark prince and williams', 3, 0), ('clark-estes', 2, 0), ('clark-taylor', 0, 1), ('cole llc', 2, 1), ('cole-ochoa', 0, 1), ('cole-stein', 2, 0), ('coleman williams and nichols', 3, 0), ('coleman-farley', 0, 2), ('combs ltd', 0, 1), ('conway-barr', 1, 0), ('cook group', 4, 1), ('cook jackson and griffith', 1, 0), ('cook ltd', 1, 0), ('cook-rodriguez', 0, 1), ('cooper llc', 1, 2), ('cooper osborn and clark', 5, 0), ('cooper smith and king', 1, 1), ('cox llc', 4, 0), ('cox-mcintyre', 3, 0), ('crane llc', 3, 1), ('crosby group', 3, 0), ('cross and sons', 0, 1), ('cruz inc', 0, 1), ('cruz lee and fernandez', 0, 1), ('cruz murphy and santos', 1, 0), ('cruz-davis', 1, 0), ('cunningham ltd', 0, 1), ('daniel schroeder and morse', 1, 0), ('daniels-kim', 2, 3), ('davies salas and clark', 0, 1), ('davila green and avila', 3, 1), ('davis and sons', 3, 0), ('davis bowen and miller', 4, 1), ('davis cruz and schaefer', 1, 0), ('davis hughes and leblanc', 1, 1), ('davis sanchez and hernandez', 0, 1), ('davis sanchez and mendez', 0, 2), ( ...

# %% [markdown]
# #### Query 24: Which providers have the highest percentage of canceled claims?

# %%
cursor.execute("""
SELECT MAX(Cancelled_Percentage)
FROM (
    SELECT p.Name,
           ROUND(100.0 * SUM(CASE WHEN c.Status = 'Cancelled' THEN 1 ELSE 0 END)/COUNT(c.Claim_ID),2) AS Cancelled_Percentage
    FROM providers p
    JOIN food_listings f ON p.Provider_ID = f.Provider_ID
    JOIN claims c ON f.Food_ID = c.Food_ID
    GROUP BY p.Name
);
""")
max_percentage = cursor.fetchone()[0]

cursor.execute("""
SELECT p.Name,
       COUNT(c.Claim_ID) AS Total_Claims,
       SUM(CASE WHEN c.Status = 'Cancelled' THEN 1 ELSE 0 END) AS Cancelled_Claims,
       ROUND(100.0 * SUM(CASE WHEN c.Status = 'Cancelled' THEN 1 ELSE 0 END)/COUNT(c.Claim_ID),2) AS Cancelled_Percentage
FROM providers p
JOIN food_listings f ON p.Provider_ID = f.Provider_ID
JOIN claims c ON f.Food_ID = c.Food_ID
GROUP BY p.Name
HAVING Cancelled_Percentage = ?
""", (max_percentage,))
print("\n24. Providers with highest percentage of canceled claims:\n", cursor.fetchall())
# Out:
# 24. Providers with highest percentage of canceled claims:
#  [('andrews-wiley', 1, 1, 100.0), ('baird plc', 1, 1, 100.0), ('baker gardner and callahan', 1, 1, 100.0), ('baker group', 2, 2, 100.0), ('barber ltd', 3, 3, 100.0), ('barker gibbs and lopez', 2, 2, 100.0), ('barker llc', 2, 2, 100.0), ('barrera-ward', 2, 2, 100.0), ('beck group', 1, 1, 100.0), ('blair group', 1, 1, 100.0), ('brooks-mccarty', 1, 1, 100.0), ('bryant jacobson and west', 1, 1, 100.0), ('buck-carey', 1, 1, 100.0), ('callahan-olsen', 1, 1, 100.0), ('cole-stein', 2, 2, 100.0), ('cox-mcintyre', 3, 3, 100.0), ('daniel schroeder and morse', 1, 1, 100.0), ('davis hughes and leblanc', 1, 1, 100.0), ('davis-hurley', 1, 1, 100.0), ('davis-kennedy', 1, 1, 100.0), ('foster ltd', 1, 1, 100.0), ('gonzales group', 1, 1, 100.0), ('gonzales-keith', 1, 1, 100.0), ('harris santos and roberts', 1, 1, 100.0), ('henry plc', 3, 3, 100.0), ('house james and miller', 1, 1, 100.0), ('jackson gonzalez and smith', 1, 1, 100.0), ('james group', 1, 1, 100.0), ('jimenez-ramirez', 1, 1, 100.0), ('johnson group', 1, 1, 100.0), ('jones-burnett', 1, 1, 100.0), ('kennedy-johnston', 1, 1, 100.0), ('larson and sons', 1, 1, 100.0), ('larson ltd', 1, 1, 100.0), ('lee llc', 1, 1, 100.0), ('lee plc', 2, 2, 100.0), ('lee walker and woodward', 1, 1, 100.0), ('lopez roach and roach', 2, 2, 100.0), ('martinez plc', 1, 1, 100.0), ('mcmillan gallegos and perry', 2, 2, 100.0), ('mendoza llc', 1, 1, 100.0), ('miller conner and clark', 1, 1, 100.0), ('miller group', 2, 2, 100.0), ('mitchell-watson', 1, 1, 100.0), ('morris ltd', 1, 1, 100.0), ('murray inc', 1, 1, 100.0), ('nelson-white', 2, 2, 100.0), ('nichols-barnes', 1, 1, 100.0), ('nielsen johnson and fuller', 1, 1, 100.0), ('oliver cross and gilbert', 1, 1, 100.0), ('owens-taylor', 2, 2, 100.0), ('page smith and davis', 2, 2, 100.0), ('parker-campbell', 1, 1, 100.0), ('parsons and sons', 1, 1, 100.0), ('parsons ltd', 3, 3, 100.0), ('patel and sons', 2, 2, 100.0), ('patterson inc', 1, 1, 100.0), ('patterson-collins', 1, 1, 100.0), ('pierce walsh and rogers', 1, 1, 100.0), ('pratt ltd', 1, 1, 100.0), ('preston-smith', 1, 1, 100.0), ('randall-wagner', 1, 1, 100.0), ('roberts group', 1, 1, 100.0), ('robinson rodriguez and reilly', 1, 1, 100.0), ('robinson schaefer and foster', 2, 2, 100.0), ('rogers-maldonado', 1, 1, 100.0), ('rojas-cook', 1, 1, 100.0), ('rosario-porter', 1, 1, 100.0), ('ruiz-oneal', 1, 1, 100.0), ('sanders-hale', 1, 1, 100.0), ('schwartz odonnell and padilla', 2, 2, 100.0), ('scott johnson and villa', 1, 1, 100.0), ('smith plc', 1, 1, 100.0), ('smith-paul', 1, 1, 100.0), ('snyder ltd', 1, 1, 100.0), ('spencer gibson and arias', 1, 1, 100.0), ('stephens-braun', 1, 1, 100.0), ('stephens-stephens', 2, 2, 100.0), ('thompson group', 1, 1, 100.0), ('todd group', 2, 2, 100.0), ('west martinez and warren', 1, 1, 100.0), ('williams-strong', 1, 1, 100.0), ('wilson-cook', 2, 2, 100.0), ('woodward-jensen', 3, 3, 100.0), ('wright-hogan', 1, 1, 100.0)]

# %% [markdown]
# #### Query 25: How many food items are claimed multiple times by different receivers?

# %%
cursor.execute("""
SELECT f.Food_Name, COUNT(DISTINCT c.Receiver_ID) AS Num_Receivers
FROM food_listings f
JOIN claims c ON f.Food_ID = c.Food_ID
GROUP BY f.Food_Name
HAVING Num_Receivers > 1
ORDER BY Num_Receivers DESC;
""")
print("\n25. Food items claimed multiple times by different receivers:\n", cursor.fetchall())
# Out:
# 25. Food items claimed multiple times by different receivers:
#  [('Rice', 112), ('Dairy', 107), ('Soup', 105), ('Fish', 102), ('Salad', 99), ('Chicken', 97), ('Bread', 88), ('Vegetables', 84), ('Pasta', 80), ('Fruits', 70)]

# %% [markdown]
# # 4.  Application Development

# %%
# Required packages
# !pip install streamlit pandas sqlite3
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.11/dist-packages (1.48.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# ERROR: Could not find a version that satisfies the requirement sqlite3 (from versions: none)
# ERROR: No matching distribution found for sqlite3
# Requirement already satisfied: streamlit in /usr/local/lib/python3.11/dist-packages (1.48.1)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging<26,>=20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (4.14.1)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2025.8.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.27.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)

# %%
# !pip install pyngrok
# !pip install streamlit
# Out:
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.11/dist-packages (7.3.0)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.11/dist-packages (from pyngrok) (6.0.2)
# Requirement already satisfied: streamlit in /usr/local/lib/python3.11/dist-packages (1.48.1)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging<26,>=20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (25.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (4.14.1)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2025.8.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.27.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)

# %%
# !ngrok authtoken 31HmOZUzJ2dvSKPHfx9VB29Nhu3_5QQiseh7xAGXFWpYmVsxb
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# Install required packages
# !pip install streamlit pyngrok pandas
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.11/dist-packages (1.48.1)
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.11/dist-packages (7.3.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (8.2.1)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging<26,>=20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (25.0)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (11.3.0)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.11/dist-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.11/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /usr/local/lib/python3.11/dist-packages (from streamlit) (4.14.1)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.11/dist-packages (from streamlit) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.11/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.11/dist-packages (from streamlit) (6.4.2)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.11/dist-packages (from pyngrok) (6.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.11/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (4.25.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.27->streamlit) (2025.8.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit) (0.27.0)

# %%
# --- CONNECT TO DATABASE ---
conn = sqlite3.connect("food_wastage.db")
c = conn.cursor()

# %%
# %%writefile food_dashboard.py
import streamlit as st
import pandas as pd
import sqlite3
import datetime

# --- Connect to database ---
conn = sqlite3.connect("food_wastage.db")
c = conn.cursor()

def show_dashboard():
    st.title("🍽️ Food Donation & Claims Dashboard")
    st.write("📊 Dashboard powered by Streamlit & SQLite")

    # --- 1. Providers & Receivers per City ---
    providers_receivers = pd.read_sql("""
    SELECT p.City,
           COUNT(DISTINCT p.Provider_ID) AS Providers,
           COUNT(DISTINCT r.Receiver_ID) AS Receivers
    FROM providers p
    LEFT JOIN receivers r ON p.City = r.City
    GROUP BY p.City;
    """, conn)
    st.subheader("1️⃣ Providers & Receivers per City")
    st.dataframe(providers_receivers)
    st.bar_chart(providers_receivers.set_index('City'))

    # --- 2. Top provider type by contribution ---
    top_provider_type = pd.read_sql("""
    SELECT Provider_Type, SUM(Quantity) AS Total_Quantity
    FROM food_listings
    GROUP BY Provider_Type
    ORDER BY Total_Quantity DESC
    LIMIT 1;
    """, conn)
    st.subheader("2️⃣ Top Provider Type by Contribution")
    st.table(top_provider_type)

    # --- 3. Provider contacts in a city ---
    city_name = st.text_input("Enter city for provider contacts", "adambury")
    provider_contacts = pd.read_sql("""
    SELECT Name, Contact
    FROM providers
    WHERE City = ?;
    """, conn, params=(city_name,))
    st.subheader(f"3️⃣ Provider Contacts in {city_name.title()}")
    st.dataframe(provider_contacts)

    # --- 4. Receivers with highest claims ---
    top_receivers = pd.read_sql("""
    WITH claim_counts AS (
        SELECT r.Name, COUNT(c.Claim_ID) AS Total_Claims
        FROM receivers r
        JOIN claims c ON r.Receiver_ID = c.Receiver_ID
        GROUP BY r.Name
    )
    SELECT Name, Total_Claims
    FROM claim_counts
    WHERE Total_Claims = (SELECT MAX(Total_Claims) FROM claim_counts);
    """, conn)
    st.subheader("4️⃣ Receivers with Highest Number of Claims")
    st.table(top_receivers)

    # --- 5. Total available food quantity ---
    total_food = pd.read_sql("SELECT SUM(Quantity) AS Total_Quantity FROM food_listings;", conn)
    st.subheader("5️⃣ Total Food Available")
    st.metric("Total Quantity", total_food['Total_Quantity'].iloc[0])

    # --- 6. City with most food listings ---
    top_city_listings = pd.read_sql("""
    SELECT Location, COUNT(Food_ID) AS Listings
    FROM food_listings
    GROUP BY Location
    ORDER BY Listings DESC
    LIMIT 1;
    """, conn)
    st.subheader("6️⃣ City with Most Food Listings")
    st.table(top_city_listings)

    # --- 7. Most common food types ---
    food_types = pd.read_sql("""
    SELECT Food_Type, COUNT(*) AS Count
    FROM food_listings
    GROUP BY Food_Type
    ORDER BY Count DESC;
    """, conn)
    st.subheader("7️⃣ Most Common Food Types")
    st.bar_chart(food_types.set_index('Food_Type'))

    # --- 8. Claims per food item ---
    claims_per_item = pd.read_sql("""
    SELECT f.Food_Name, COUNT(c.Claim_ID) AS Claim_Count
    FROM food_listings f
    JOIN claims c ON f.Food_ID = c.Food_ID
    GROUP BY f.Food_Name;
    """, conn)
    st.subheader("8️⃣ Claims Per Food Item")
    st.dataframe(claims_per_item)

    # --- 9. Provider with highest successful claims ---
    top_provider_claims = pd.read_sql("""
    SELECT p.Name, COUNT(c.Claim_ID) AS Successful_Claims
    FROM providers p
    JOIN food_listings f ON p.Provider_ID = f.Provider_ID
    JOIN claims c ON f.Food_ID = c.Food_ID
    WHERE c.Status = 'Completed'
    GROUP BY p.Name
    ORDER BY Successful_Claims DESC
    LIMIT 1;
    """, conn)
    st.subheader("9️⃣ Top Provider by Successful Claims")
    st.table(top_provider_claims)

    # --- 10. Claims percentage by status ---
    claims_status = pd.read_sql("""
    SELECT Status,
           ROUND((COUNT(*) * 100.0 / (SELECT COUNT(*) FROM claims)), 2) AS Percentage
    FROM claims
    GROUP BY Status;
    """, conn)
    st.subheader("🔟 Claims Percentage by Status")
    st.dataframe(claims_status)
    st.bar_chart(claims_status.set_index('Status'))

    # --- 11. Average quantity claimed per receiver ---
    avg_claim_per_receiver = pd.read_sql("""
    SELECT r.Name, AVG(f.Quantity) AS Avg_Claimed
    FROM receivers r
    JOIN claims c ON r.Receiver_ID = c.Receiver_ID
    JOIN food_listings f ON c.Food_ID = f.Food_ID
    GROUP BY r.Name;
    """, conn)
    st.subheader("1️⃣1️⃣ Average Quantity Claimed Per Receiver")
    st.dataframe(avg_claim_per_receiver)

    # --- 12. Most claimed meal type ---
    most_claimed_meal = pd.read_sql("""
    SELECT Meal_Type, COUNT(c.Claim_ID) AS Claim_Count
    FROM food_listings f
    JOIN claims c ON f.Food_ID = c.Food_ID
    GROUP BY Meal_Type
    ORDER BY Claim_Count DESC;
    """, conn)
    st.subheader("1️⃣2️⃣ Most Claimed Meal Type")
    st.bar_chart(most_claimed_meal.set_index('Meal_Type'))

    # --- 13. Total food donated per provider ---
    total_donated = pd.read_sql("""
    SELECT p.Name, SUM(f.Quantity) AS Total_Donated
    FROM providers p
    JOIN food_listings f ON p.Provider_ID = f.Provider_ID
    GROUP BY p.Name
    ORDER BY Total_Donated DESC;
    """, conn)
    st.subheader("1️⃣3️⃣ Total Food Donated Per Provider")
    st.dataframe(total_donated)

    # --- 14. Food Items Near Expiry (Next 3 Days) & 15: Optional additional analysis ---
    near_expiry_items = pd.read_sql("""
    SELECT Food_Name, Expiry_Date, Quantity
    FROM food_listings
    WHERE DATE(Expiry_Date) <= DATE('now', '+3 day');
    """, conn)
    st.subheader("1️⃣4️⃣ Food Items Near Expiry (Next 3 Days)")
    st.dataframe(near_expiry_items)

    # --- 15. Top 10 Cities by Food Claims ---
    top_claiming_cities = pd.read_sql("""
    SELECT Location, COUNT(c.Claim_ID) AS Total_Claims
    FROM food_listings f
    JOIN claims c ON f.Food_ID = c.Food_ID
    GROUP BY Location
    ORDER BY Total_Claims DESC
    LIMIT 10;
    """, conn)
    st.subheader("1️⃣5️⃣ Top 10 Cities by Food Claims")
    st.bar_chart(top_claiming_cities.set_index('Location'))
    st.write("📊 Dashboard powered by Streamlit & SQLite")

def show_list_food():
    st.title("➕ List New Food Surplus")
    st.markdown("---")
    providers = pd.read_sql("SELECT Provider_ID, Name, City, Type FROM providers;", conn)
    provider_names = providers['Name'].tolist()

    with st.form("list_food_form"):
        st.subheader("Food Item Details")
        provider_name = st.selectbox("Select Provider:", provider_names)
        provider_info = providers[providers['Name'] == provider_name]

        if not provider_info.empty:
            provider_id = int(provider_info['Provider_ID'].iloc[0])
            provider_type = provider_info['Type'].iloc[0]
            location = provider_info['City'].iloc[0]

            food_name = st.text_input("Food Name:")
            food_type = st.selectbox("Food Type:", ["Vegetables", "Fruits", "Prepared Meal", "Snacks", "Bakery", "Dairy"])
            quantity = st.number_input("Quantity:", min_value=1, step=1)
            expiry_date = st.date_input("Expiry Date:", min_value=datetime.date.today())
            meal_type = st.selectbox("Meal Type:", ["Breakfast", "Lunch", "Dinner", "Snack", "Any"])

            submitted = st.form_submit_button("List Food")

            if submitted:
                if food_name and quantity:
                    c.execute("""
                        INSERT INTO food_listings (Provider_ID, Provider_Type, Location, Food_Name, Food_Type, Quantity, Expiry_Date, Meal_Type)
                        VALUES (?, ?, ?, ?, ?, ?, ?, ?)
                    """, (provider_id, provider_type, location, food_name, food_type, quantity, str(expiry_date), meal_type))
                    conn.commit()
                    st.success("🎉 Food item listed successfully!")
                else:
                    st.error("Please fill in all the details.")
        else:
            st.info("Please add a provider first using the 'Add Provider' page.")

def show_claim_food():
    st.title("🛒 Claim Available Food")
    st.markdown("---")

    receivers = pd.read_sql("SELECT Receiver_ID, Name FROM receivers;", conn)
    receiver_names = receivers['Name'].tolist()

    available_food = pd.read_sql("""
        SELECT Food_ID, Food_Name, Quantity, Expiry_Date, Provider_Type, Location
        FROM food_listings
        WHERE Food_ID NOT IN (SELECT Food_ID FROM claims WHERE Status IN ('Pending', 'Completed'))
        AND DATE(Expiry_Date) > DATE('now')
    """, conn)

    if available_food.empty:
        st.info("No food items are currently available for claiming.")
        return

    with st.form("claim_food_form"):
        st.subheader("Claim Details")
        receiver_name = st.selectbox("Select Receiver:", receiver_names)
        receiver_id = receivers[receivers['Name'] == receiver_name]['Receiver_ID'].iloc[0]

        food_options = available_food.apply(
            lambda row: f"{row['Food_Name']} from {row['Provider_Type']} in {row['Location']} (Qty: {row['Quantity']})", axis=1
        ).tolist()

        selected_food_str = st.selectbox("Select Food to Claim:", food_options)

        selected_food_id = None
        if selected_food_str:
            selected_food_id = available_food[
                available_food.apply(
                    lambda row: f"{row['Food_Name']} from {row['Provider_Type']} in {row['Location']} (Qty: {row['Quantity']})", axis=1
                ) == selected_food_str
            ]['Food_ID'].iloc[0]

        submitted = st.form_submit_button("Claim Food")

        if submitted:
            if selected_food_id:
                c.execute("""
                    INSERT INTO claims (Food_ID, Receiver_ID, Status, Timestamp)
                    VALUES (?, ?, ?, ?)
                """, (selected_food_id, receiver_id, 'Pending', datetime.datetime.now()))
                conn.commit()
                st.success("✅ Food claimed successfully! Awaiting provider confirmation.")
            else:
                st.error("Please select a food item to claim.")

def show_add_provider():
    st.title("➕ Add New Provider")
    st.markdown("---")
    with st.form("add_provider_form"):
        st.subheader("Provider Details")
        name = st.text_input("Name:")
        contact = st.text_input("Contact:")
        address = st.text_input("Address:")
        city = st.text_input("City:")
        provider_type = st.selectbox("Type:", ["Restaurant", "Bakery", "Supermarket", "Grocery Store", "Catering Service"])

        submitted = st.form_submit_button("Add Provider")

        if submitted:
            if name and contact and city and provider_type:
                c.execute("""
                    INSERT INTO providers (Name, Contact, Address, City, Type)
                    VALUES (?, ?, ?, ?, ?)
                """, (name, contact, address, city, provider_type))
                conn.commit()
                st.success(f"✅ Provider '{name}' added successfully!")
            else:
                st.error("Please fill in all the details.")

def show_add_receiver():
    st.title("➕ Add New Receiver")
    st.markdown("---")
    with st.form("add_receiver_form"):
        st.subheader("Receiver Details")
        name = st.text_input("Name:")
        contact = st.text_input("Contact:")
        city = st.text_input("City:")
        receiver_type = st.selectbox("Type:", ["Non-profit", "Community Center", "Individual", "Other"])

        submitted = st.form_submit_button("Add Receiver")

        if submitted:
            if name and contact and city and receiver_type:
                c.execute("""
                    INSERT INTO receivers (Name, Contact, City, Type)
                    VALUES (?, ?, ?, ?)
                """, (name, contact, city, receiver_type))
                conn.commit()
                st.success(f"✅ Receiver '{name}' added successfully!")
            else:
                st.error("Please fill in all the details.")

# --- Main App Logic ---
st.sidebar.title("Navigation")
page = st.sidebar.radio("Go to:", ["Dashboard", "List Food", "Claim Food", "Add Provider", "Add Receiver"])

if page == "Dashboard":
    show_dashboard()
elif page == "List Food":
    show_list_food()
elif page == "Claim Food":
    show_claim_food()
elif page == "Add Provider":
    show_add_provider()
elif page == "Add Receiver":
    show_add_receiver()

conn.close()
# Out:
# Overwriting food_dashboard.py

# %%
from pyngrok import ngrok
import os
import time

# ngrok authentication token (replace with your actual token)
# ngrok.set_auth_token("YOUR_NGROK_AUTH_TOKEN")

# Kill any existing ngrok tunnels and processes to be sure
try:
    ngrok.kill()
    time.sleep(2) # Wait for a moment to ensure processes are terminated
except Exception as e:
    print(f"Ngrok kill failed: {e}")

# Start Streamlit in the background
os.system("streamlit run food_dashboard.py --server.port=8501 &")

# Create ngrok tunnel
try:
    public_url = ngrok.connect(8501)
    print("ngrok tunnel is live at:", public_url)
except Exception as e:
    print(f"An error occurred while creating the ngrok tunnel: {e}")
# Out:
# ngrok tunnel is live at: NgrokTunnel: "https://d14f7d203bf4.ngrok-free.app" -> "http://localhost:8501"

# %% [markdown]
# # 5. Deployment

# %% [markdown]
# Install Required Packages
# Installed Streamlit, Pandas, and Pyngrok to build the dashboard and expose it publicly while running in Colab.
#
# - Upload Database
# Uploaded the SQLite database food_wastage.db to Colab so the app could access provider, receiver, and food listing data.
#
# - Create Streamlit App
# Developed food_dashboard.py with 15 SQL queries to analyze food donations, claims, and trends. Added tables, charts, and metrics for visualization.
#
# - Run Streamlit in Colab
# Started the Streamlit app in the background and used ngrok to generate a public URL for real-time access and interaction.
#
# - Push to GitHub
# Created a GitHub repository with the app file, database, and requirements.txt to list dependencies.
#
# - Deploy on Streamlit Community Cloud
# Connected Streamlit Cloud to the GitHub repo, selected the main file (food_dashboard.py), and clicked Deploy. Streamlit Cloud installed dependencies and launched the app automatically.
#
# - Access Live Dashboard
# The app became publicly accessible via a URL:
# https://local-food-wastage-management-system-cvpx32dpmxdz4q5rmzzkhy.streamlit.app/
# This allows anyone to view and interact with the dashboard in real-time.
